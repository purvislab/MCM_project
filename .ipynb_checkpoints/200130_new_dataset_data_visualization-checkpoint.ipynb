# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats

# %%
dataFile = r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\new dataset\cellinfo_signals_v3.csv'

# %%
myData=pd.read_csv(dataFile)

# %%
myData['day']=[f"d{x.split('_')[0]}" for x in myData.file]
myData = myData.astype({"day": 'object'})
set(myData['day'])
# Out:
# {'d20191203'}

# %%
for i, cell in myData.iterrows():
    myData.at[i,'decon']="d" in myData.loc[i,'file']

# %%
myData
# Out:
#      Unnamed: 0                         file original cell name  \
# 0             0         20191203_cell-00.czi     20191125-01-17
# 1             1         20191203_cell-01.czi     20191125-01-20
# 2             2         20191203_cell-02.czi     20191125-01-23
# 3             3         20191203_cell-03.czi     20191125-01-25
# 4             4         20191203_cell-04.czi     20191125-01-32
# 5             5         20191203_cell-05.czi     20191125-01-36
# 6             6         20191203_cell-06.czi     20191125-01-37
# 7             7         20191203_cell-07.czi     20191125-01-40
# 8             8         20191203_cell-08.czi     20191125-01-41
# 9             9         20191203_cell-09.czi     20191125-01-45
# 10           10         20191203_cell-10.czi     20191125-01-52
# 11           11         20191203_cell-11.czi     20191125-01-54
# 12           12         20191203_cell-12.czi     20191125-01-57
# 13           13         20191203_cell-13.czi     20191125-01-59
# 14           14         20191203_cell-14.czi     20191125-01-65
# 15           15         20191203_cell-15.czi     20191125-01-66
# 16           16         20191203_cell-16.czi     20191125-01-68
# 17           17         20191203_cell-17.czi     20191125-01-69
# 18           18         20191203_cell-18.czi     20191125-01-71
# 19           19         20191203_cell-19.czi     20191125-01-79
# 20           20         20191203_cell-20.czi     20191125-01-81
# 21           21         20191203_cell-21.czi     20191125-01-86
# 22           22         20191203_cell-23.czi     20191125-01-87
# 23           23         20191203_cell-24.czi     20191125-01-93
# 24           24         20191203_cell-25.czi     20191125-01-99
# 25           25         20191203_cell-26.czi    20191125-01-101
# 26           26         20191203_cell-27.czi    20191125-01-102
# 27           27         20191203_cell-28.czi    20191125-01-106
# 28           28         20191203_cell-29.czi    20191125-01-108
# 29           29        20191203_cell-30.tiff     20191125-01-10
# ..          ...                          ...                ...
# 294         294  20191203_cellde-140.czi.ims    20191125-11-144
# 295         295  20191203_cellde-141.czi.ims    20191125-11-145
# 296         296  20191203_cellde-142.czi.ims     20191125-12-17
# 297         297  20191203_cellde-143.czi.ims     20191125-12-18
# 298         298  20191203_cellde-144.czi.ims     20191125-12-33
# 299         299  20191203_cellde-145.czi.ims     20191125-12-39
# 300         300  20191203_cellde-146.czi.ims     20191125-12-46
# 301         301  20191203_cellde-147.czi.ims     20191125-12-74
# 302         302  20191203_cellde-148.czi.ims     20191125-12-84
# 303         303  20191203_cellde-149.czi.ims    20191125-12-136
# 304         304  20191203_cellde-150.czi.ims     20191125-16-64
# 305         305  20191203_cellde-151.czi.ims     20191125-16-17
# 306         306  20191203_cellde-152.czi.ims     20191125-16-18
# 307         307  20191203_cellde-153.czi.ims     20191125-16-20
# 308         308  20191203_cellde-154.czi.ims     20191125-16-28
# 309         309  20191203_cellde-155.czi.ims     20191125-16-35
# 310         310  20191203_cellde-156.czi.ims     20191125-16-41
# 311         311  20191203_cellde-157.czi.ims     20191125-16-42
# 312         312  20191203_cellde-158.czi.ims     20191125-16-48
# 313         313  20191203_cellde-159.czi.ims     20191125-16-53
# 314         314  20191203_cellde-160.czi.ims     20191125-16-56
# 315         315  20191203_cellde-161.czi.ims  20191125-16-64(H)
# 316         316  20191203_cellde-162.czi.ims  20191125-16-18(H)
# 317         317  20191203_cellde-163.czi.ims  20191125-16-28(H)
# 318         318  20191203_cellde-164.czi.ims  20191125-16-35(H)
# 319         319  20191203_cellde-165.czi.ims  20191125-16-41(H)
# 320         320  20191203_cellde-166.czi.ims  20191125-16-42(H)
# 321         321  20191203_cellde-167.czi.ims  20191125-16-48(H)
# 322         322  20191203_cellde-168.czi.ims  20191125-16-53(H)
# 323         323  20191203_cellde-169.czi.ims  20191125-16-56(H)
#
#                           movie  last frame movie position x  \
# 0    191125pcnat_dhbr_cdc6vxy01                      678.301
# 1    191125pcnat_dhbr_cdc6vxy01                     1552.152
# 2    191125pcnat_dhbr_cdc6vxy01                     1131.436
# 3    191125pcnat_dhbr_cdc6vxy01                     1650.585
# 4    191125pcnat_dhbr_cdc6vxy01                     1466.687
# 5    191125pcnat_dhbr_cdc6vxy01                     1705.099
# 6    191125pcnat_dhbr_cdc6vxy01                      234.034
# 7    191125pcnat_dhbr_cdc6vxy01                      451.617
# 8    191125pcnat_dhbr_cdc6vxy01                      332.674
# 9    191125pcnat_dhbr_cdc6vxy01                      781.494
# 10   191125pcnat_dhbr_cdc6vxy01                     1682.974
# 11   191125pcnat_dhbr_cdc6vxy01                      647.356
# 12   191125pcnat_dhbr_cdc6vxy01                     1490.416
# 13   191125pcnat_dhbr_cdc6vxy01                      606.310
# 14   191125pcnat_dhbr_cdc6vxy01                      414.203
# 15   191125pcnat_dhbr_cdc6vxy01                     1577.471
# 16   191125pcnat_dhbr_cdc6vxy01                      597.275
# 17   191125pcnat_dhbr_cdc6vxy01                     1351.663
# 18   191125pcnat_dhbr_cdc6vxy01                     1255.384
# 19   191125pcnat_dhbr_cdc6vxy01                     1324.790
# 20   191125pcnat_dhbr_cdc6vxy01                     1324.790
# 21   191125pcnat_dhbr_cdc6vxy01                     1120.703
# 22   191125pcnat_dhbr_cdc6vxy01                      662.667
# 23   191125pcnat_dhbr_cdc6vxy01                      340.312
# 24   191125pcnat_dhbr_cdc6vxy01                     1502.805
# 25   191125pcnat_dhbr_cdc6vxy01                     1830.442
# 26   191125pcnat_dhbr_cdc6vxy01                      947.606
# 27   191125pcnat_dhbr_cdc6vxy01                     1513.947
# 28   191125pcnat_dhbr_cdc6vxy01                      986.417
# 29   191125pcnat_dhbr_cdc6vxy01                      275.057
# ..                          ...                          ...
# 294  191125pcnat_dhbr_cdc6vxy11                      294.209
# 295  191125pcnat_dhbr_cdc6vxy11                      707.287
# 296  191125pcnat_dhbr_cdc6vxy12                      162.731
# 297  191125pcnat_dhbr_cdc6vxy12                      881.877
# 298  191125pcnat_dhbr_cdc6vxy12                      387.745
# 299  191125pcnat_dhbr_cdc6vxy12                     1285.072
# 300  191125pcnat_dhbr_cdc6vxy12                     1425.322
# 301  191125pcnat_dhbr_cdc6vxy12                      269.667
# 302  191125pcnat_dhbr_cdc6vxy12                      385.605
# 303  191125pcnat_dhbr_cdc6vxy12                      140.062
# 304  191125pcnat_dhbr_cdc6vxy16                      466.544
# 305  191125pcnat_dhbr_cdc6vxy16                      519.876
# 306  191125pcnat_dhbr_cdc6vxy16                      338.963
# 307  191125pcnat_dhbr_cdc6vxy16                      482.750
# 308  191125pcnat_dhbr_cdc6vxy16                     1314.948
# 309  191125pcnat_dhbr_cdc6vxy16                      430.168
# 310  191125pcnat_dhbr_cdc6vxy16                     1155.751
# 311  191125pcnat_dhbr_cdc6vxy16                     1718.927
# 312  191125pcnat_dhbr_cdc6vxy16                     1606.449
# 313  191125pcnat_dhbr_cdc6vxy16                     1916.235
# 314  191125pcnat_dhbr_cdc6vxy16                     1650.477
# 315  191125pcnat_dhbr_cdc6vxy16                      466.544
# 316  191125pcnat_dhbr_cdc6vxy16                      338.963
# 317  191125pcnat_dhbr_cdc6vxy16                     1314.948
# 318  191125pcnat_dhbr_cdc6vxy16                      430.168
# 319  191125pcnat_dhbr_cdc6vxy16                     1155.751
# 320  191125pcnat_dhbr_cdc6vxy16                     1718.927
# 321  191125pcnat_dhbr_cdc6vxy16                     1606.449
# 322  191125pcnat_dhbr_cdc6vxy16                     1916.235
# 323  191125pcnat_dhbr_cdc6vxy16                     1650.477
#
#      last frame movie position y ab1 (MCM)  ab1 ch ab2 (heterochromatin)  \
# 0                        200.931      MCM3       1               HP1beta
# 1                        240.479      MCM3       1               HP1beta
# 2                        318.530      MCM3       1               HP1beta
# 3                        324.968      MCM3       1               HP1beta
# 4                        426.815      MCM3       1               HP1beta
# 5                        468.246      MCM3       1               HP1beta
# 6                        482.620      MCM3       1               HP1beta
# 7                        514.260      MCM3       1               HP1beta
# 8                        553.990      MCM3       1               HP1beta
# 9                        661.685      MCM3       1               HP1beta
# 10                       795.979      MCM3       1               HP1beta
# 11                       843.150      MCM3       1               HP1beta
# 12                       910.452      MCM3       1               HP1beta
# 13                       926.311      MCM3       1               HP1beta
# 14                      1018.464      MCM3       1               HP1beta
# 15                      1023.321      MCM3       1               HP1beta
# 16                      1041.546      MCM3       1               HP1beta
# 17                      1133.380      MCM3       1               HP1beta
# 18                      1113.755      MCM3       1               HP1beta
# 19                      1228.346      MCM3       1               HP1beta
# 20                      1228.346      MCM3       1               HP1beta
# 21                      1322.446      MCM3       1               HP1beta
# 22                      1331.578      MCM3       1               HP1beta
# 23                      1397.882      MCM3       1               HP1beta
# 24                      1480.651      MCM3       1               HP1beta
# 25                      1525.595      MCM3       1               HP1beta
# 26                      1549.244      MCM3       1               HP1beta
# 27                      1584.018      MCM3       1               HP1beta
# 28                      1616.034      MCM3       1               HP1beta
# 29                       144.649      MCM3       1               HP1beta
# ..                           ...       ...     ...                   ...
# 294                     1697.134      MCM3       1               HP1beta
# 295                     1697.434      MCM3       1               HP1beta
# 296                      183.301      MCM3       1               HP1beta
# 297                      212.429      MCM3       1               HP1beta
# 298                      396.038      MCM3       1               HP1beta
# 299                      463.128      MCM3       1               HP1beta
# 300                      530.318      MCM3       1               HP1beta
# 301                      841.209      MCM3       1               HP1beta
# 302                      946.541      MCM3       1               HP1beta
# 303                     1665.859      MCM3       1               HP1beta
# 304                     1581.823      MCM3       1               HP1beta
# 305                      303.427      MCM3       1               HP1beta
# 306                      366.795      MCM3       1               HP1beta
# 307                      426.779      MCM3       1               HP1beta
# 308                      596.674      MCM3       1               HP1beta
# 309                      814.870      MCM3       1               HP1beta
# 310                      914.461      MCM3       1               HP1beta
# 311                      920.523      MCM3       1               HP1beta
# 312                     1077.220      MCM3       1               HP1beta
# 313                     1195.856      MCM3       1               HP1beta
# 314                     1349.451      MCM3       1               HP1beta
# 315                     1581.823      MCM3       1               HP1beta
# 316                      366.795      MCM3       1               HP1beta
# 317                      596.674      MCM3       1               HP1beta
# 318                      814.870      MCM3       1               HP1beta
# 319                      914.461      MCM3       1               HP1beta
# 320                      920.523      MCM3       1               HP1beta
# 321                     1077.220      MCM3       1               HP1beta
# 322                     1195.856      MCM3       1               HP1beta
# 323                     1349.451      MCM3       1               HP1beta
#
#      ab2 ch  ...  nucleus_Otsu_erosion_inner_13x8_volume  \
# 0         2  ...                                 26649.0
# 1         2  ...                                 43312.0
# 2         2  ...                                 47734.0
# 3         2  ...                                 27674.0
# 4         2  ...                                 30259.0
# 5         2  ...                                 32120.0
# 6         2  ...                                 27272.0
# 7         2  ...                                 28229.0
# 8         2  ...                                 26898.0
# 9         2  ...                                 26591.0
# 10        2  ...                                 32420.0
# 11        2  ...                                 24115.0
# 12        2  ...                                 21902.0
# 13        2  ...                                 23554.0
# 14        2  ...                                 28016.0
# 15        2  ...                                 26287.0
# 16        2  ...                                 24219.0
# 17        2  ...                                 25780.0
# 18        2  ...                                 24840.0
# 19        2  ...                                 25445.0
# 20        2  ...                                 28062.0
# 21        2  ...                                 35070.0
# 22        2  ...                                 26403.0
# 23        2  ...                                 24385.0
# 24        2  ...                                 37190.0
# 25        2  ...                                 27419.0
# 26        2  ...                                 27669.0
# 27        2  ...                                 44913.0
# 28        2  ...                                 26096.0
# 29        2  ...                                  3776.0
# ..      ...  ...                                     ...
# 294       2  ...                                  5008.0
# 295       2  ...                                  6177.0
# 296       2  ...                                  1675.0
# 297       2  ...                                  4912.0
# 298       2  ...                                  5207.0
# 299       2  ...                                   338.0
# 300       2  ...                                  8090.0
# 301       2  ...                                  2202.0
# 302       2  ...                                  4266.0
# 303       2  ...                                  7128.0
# 304       2  ...                                  1373.0
# 305       2  ...                                  2129.0
# 306       2  ...                                  2522.0
# 307       2  ...                                  3019.0
# 308       2  ...                                  3138.0
# 309       2  ...                                  1099.0
# 310       2  ...                                  3398.0
# 311       2  ...                                  1731.0
# 312       2  ...                                  1845.0
# 313       2  ...                                  3471.0
# 314       2  ...                                  1237.0
# 315       2  ...                                   870.0
# 316       2  ...                                   354.0
# 317       2  ...                                  1751.0
# 318       2  ...                                  1296.0
# 319       2  ...                                  3783.0
# 320       2  ...                                  2563.0
# 321       2  ...                                  1653.0
# 322       2  ...                                  3763.0
# 323       2  ...                                   530.0
#
#      nucleus_Otsu_erosion_inner_13x8_ch1 nucleus_Otsu_erosion_inner_13x8_ch2  \
# 0                            287465992.0                         446357009.0
# 1                            590747409.0                         213222953.0
# 2                            538655494.0                         234835439.0
# 3                            259834011.0                         267383771.0
# 4                            348189377.0                         396907398.0
# 5                            418577472.0                         376211249.0
# 6                            328406375.0                         598255645.0
# 7                            374942333.0                         633070361.0
# 8                            303065593.0                         684357665.0
# 9                            277652824.0                         116667200.0
# 10                           383415124.0                         361094182.0
# 11                           250934210.0                         381259294.0
# 12                           263444704.0                         384140876.0
# 13                           289200671.0                         284040594.0
# 14                           217112762.0                         260700452.0
# 15                           254688688.0                         288735056.0
# 16                           205950270.0                         278888118.0
# 17                           318303041.0                         135160460.0
# 18                           236766018.0                         210175654.0
# 19                           307012922.0                         137623947.0
# 20                           366007914.0                         432817303.0
# 21                           330108237.0                         260497051.0
# 22                           339983344.0                         245479226.0
# 23                           268912850.0                         263428872.0
# 24                           356921756.0                         165002987.0
# 25                           316391296.0                         431158028.0
# 26                           240571003.0                         240659649.0
# 27                           444150450.0                         210170863.0
# 28                           260093534.0                         296373864.0
# 29                            21922895.0                          18634484.0
# ..                                   ...                                 ...
# 294                           49646808.0                          94784688.0
# 295                           61615356.0                         116288536.0
# 296                           17910572.0                          34120880.0
# 297                           51774160.0                          94085672.0
# 298                           55491984.0                          96970192.0
# 299                            3148036.0                           6733077.0
# 300                           94389248.0                         200790272.0
# 301                           23393736.0                          58121520.0
# 302                           39457168.0                         110211312.0
# 303                           63156232.0                         199941984.0
# 304                            7095677.0                           7673592.5
# 305                            9913678.0                          10149271.0
# 306                           18462574.0                          15280343.0
# 307                           18928512.0                          15291319.0
# 308                           17472658.0                          24450604.0
# 309                            7271888.0                           8232796.5
# 310                           20389548.0                          18971912.0
# 311                            8368052.0                           9053154.0
# 312                           10876621.0                          13176302.0
# 313                           20297908.0                          29263024.0
# 314                            8624491.0                          12960952.0
# 315                            8733262.0                           4742577.0
# 316                            4550304.0                           2149939.5
# 317                           20609828.0                          14248102.0
# 318                           17382854.0                           9200604.0
# 319                           47605608.0                          20194152.0
# 320                           24855320.0                          13635379.0
# 321                           19428676.0                          11445414.0
# 322                           43339808.0                          30819284.0
# 323                            8111216.0                           5313654.0
#
#      nucleus_Otsu_erosion_inner_13x8_ch3  \
# 0                           6.059570e+08
# 1                           1.244767e+09
# 2                           1.343080e+09
# 3                           8.486865e+08
# 4                           6.780964e+08
# 5                           8.338728e+08
# 6                           6.725853e+08
# 7                           6.187909e+08
# 8                           7.185127e+08
# 9                           8.307770e+08
# 10                          9.074693e+08
# 11                          5.498193e+08
# 12                          4.782867e+08
# 13                          5.214578e+08
# 14                          6.540427e+08
# 15                          6.330537e+08
# 16                          6.141921e+08
# 17                          8.112242e+08
# 18                          6.724522e+08
# 19                          7.956074e+08
# 20                          7.223204e+08
# 21                          8.600027e+08
# 22                          6.023103e+08
# 23                          5.639522e+08
# 24                          1.043281e+09
# 25                          6.842559e+08
# 26                          6.903235e+08
# 27                          1.329249e+09
# 28                          6.551472e+08
# 29                          1.192337e+08
# ..                                   ...
# 294                         1.470542e+08
# 295                         1.781924e+08
# 296                         4.912894e+07
# 297                         1.441762e+08
# 298                         1.736263e+08
# 299                         1.028290e+07
# 300                         2.161431e+08
# 301                         6.195466e+07
# 302                         1.303784e+08
# 303                         2.153778e+08
# 304                         2.632205e+07
# 305                         4.985840e+07
# 306                         5.090322e+07
# 307                         6.745018e+07
# 308                         6.160549e+07
# 309                         2.162898e+07
# 310                         6.553854e+07
# 311                         3.578122e+07
# 312                         3.559351e+07
# 313                         6.393525e+07
# 314                         2.498546e+07
# 315                         1.624266e+07
# 316                         6.890100e+06
# 317                         3.300561e+07
# 318                         2.488135e+07
# 319                         7.228060e+07
# 320                         4.968291e+07
# 321                         3.139220e+07
# 322                         6.848850e+07
# 323                         1.063151e+07
#
#      nucleus_Otsu__erosion_outer_13x8_volume  \
# 0                                    25993.0
# 1                                    23896.0
# 2                                    18390.0
# 3                                    17115.0
# 4                                    33201.0
# 5                                    24250.0
# 6                                    17859.0
# 7                                    27641.0
# 8                                    12782.0
# 9                                     8216.0
# 10                                   13084.0
# 11                                   18807.0
# 12                                   31219.0
# 13                                   31531.0
# 14                                   29773.0
# 15                                   25894.0
# 16                                   22788.0
# 17                                    6420.0
# 18                                   16842.0
# 19                                    9971.0
# 20                                   14356.0
# 21                                   18427.0
# 22                                   18002.0
# 23                                   23419.0
# 24                                   28548.0
# 25                                   17960.0
# 26                                   24230.0
# 27                                   18114.0
# 28                                   19892.0
# 29                                   32991.0
# ..                                       ...
# 294                                  25541.0
# 295                                  29640.0
# 296                                  33832.0
# 297                                  28737.0
# 298                                  29540.0
# 299                                  33881.0
# 300                                  25654.0
# 301                                  37268.0
# 302                                  26400.0
# 303                                  26262.0
# 304                                  26945.0
# 305                                  21263.0
# 306                                  28265.0
# 307                                  21098.0
# 308                                  25085.0
# 309                                  27869.0
# 310                                  23648.0
# 311                                  21919.0
# 312                                  24095.0
# 313                                  26753.0
# 314                                  28409.0
# 315                                  26398.0
# 316                                  28108.0
# 317                                  25026.0
# 318                                  27639.0
# 319                                  23449.0
# 320                                  22099.0
# 321                                  24636.0
# 322                                  26602.0
# 323                                  29148.0
#
#     nucleus_Otsu__erosion_outer_13x8_ch1  \
# 0                            263052050.0
# 1                            305520069.0
# 2                            193831872.0
# 3                            144109610.0
# 4                            348961386.0
# 5                            280889097.0
# 6                            195306833.0
# 7                            326518043.0
# 8                            151365166.0
# 9                             72564137.0
# 10                           135572391.0
# 11                           186456649.0
# 12                           350339161.0
# 13                           366491290.0
# 14                           224794952.0
# 15                           237842941.0
# 16                           192019721.0
# 17                            76455003.0
# 18                           149549069.0
# 19                           127267299.0
# 20                           187997042.0
# 21                           156267188.0
# 22                           269470646.0
# 23                           237082153.0
# 24                           247519328.0
# 25                           218124956.0
# 26                           191161795.0
# 27                           181409212.0
# 28                           186007889.0
# 29                           124910268.0
# ..                                   ...
# 294                          278921664.0
# 295                          307019584.0
# 296                          368898848.0
# 297                          312426368.0
# 298                          328076480.0
# 299                          370983808.0
# 300                          292896448.0
# 301                          429477920.0
# 302                          271556992.0
# 303                          265879472.0
# 304                          153669728.0
# 305                           94351056.0
# 306                          220857504.0
# 307                          138510080.0
# 308                          144774896.0
# 309                          192839616.0
# 310                          149235856.0
# 311                          112593952.0
# 312                          145486528.0
# 313                          163122144.0
# 314                          219316608.0
# 315                          295158944.0
# 316                          407212480.0
# 317                          302925184.0
# 318                          396547360.0
# 319                          312756992.0
# 320                          226098064.0
# 321                          304206208.0
# 322                          320408352.0
# 323                          465874752.0
#
#      nucleus_Otsu__erosion_outer_13x8_ch2  \
# 0                             343851501.0
# 1                             109216346.0
# 2                              82981277.0
# 3                             142672978.0
# 4                             363283873.0
# 5                             237466347.0
# 6                             312296662.0
# 7                             465896396.0
# 8                             232411196.0
# 9                              36247939.0
# 10                            128772436.0
# 11                            256838578.0
# 12                            452862346.0
# 13                            328573890.0
# 14                            238167930.0
# 15                            234057545.0
# 16                            224736146.0
# 17                             32074892.0
# 18                            130184490.0
# 19                             49806404.0
# 20                            177435181.0
# 21                            117351812.0
# 22                            145778274.0
# 23                            213032465.0
# 24                            122941537.0
# 25                            226443517.0
# 26                            190859022.0
# 27                             81787225.0
# 28                            190675790.0
# 29                            166728819.0
# ..                                    ...
# 294                           392760832.0
# 295                           480818880.0
# 296                           588897408.0
# 297                           509969088.0
# 298                           488771584.0
# 299                           573484544.0
# 300                           530955776.0
# 301                           825976256.0
# 302                           554092224.0
# 303                           579393408.0
# 304                           142674544.0
# 305                            96645952.0
# 306                           145587152.0
# 307                            99971264.0
# 308                           130929776.0
# 309                           171456160.0
# 310                           116690272.0
# 311                           104394448.0
# 312                           144484608.0
# 313                           204661920.0
# 314                           284910976.0
# 315                           138239328.0
# 316                           148001888.0
# 317                           131135712.0
# 318                           166011488.0
# 319                           114297440.0
# 320                           104648696.0
# 321                           146115024.0
# 322                           198094176.0
# 323                           284185152.0
#
#     nucleus_Otsu__erosion_outer_13x8_ch3        day  decon
# 0                            455215468.0  d20191203  False
# 1                            567307181.0  d20191203  False
# 2                            431364743.0  d20191203  False
# 3                            380441679.0  d20191203  False
# 4                            583863832.0  d20191203  False
# 5                            502399567.0  d20191203  False
# 6                            344920205.0  d20191203  False
# 7                            468867695.0  d20191203  False
# 8                            245818746.0  d20191203  False
# 9                            195978224.0  d20191203  False
# 10                           263424189.0  d20191203  False
# 11                           365513049.0  d20191203  False
# 12                           565982506.0  d20191203  False
# 13                           585001307.0  d20191203  False
# 14                           529808686.0  d20191203  False
# 15                           484377598.0  d20191203  False
# 16                           453677775.0  d20191203  False
# 17                           146479296.0  d20191203  False
# 18                           360070891.0  d20191203  False
# 19                           230854119.0  d20191203  False
# 20                           304503960.0  d20191203  False
# 21                           316136273.0  d20191203  False
# 22                           325230585.0  d20191203  False
# 23                           434106875.0  d20191203  False
# 24                           640781177.0  d20191203  False
# 25                           354937368.0  d20191203  False
# 26                           455925609.0  d20191203  False
# 27                           475482510.0  d20191203  False
# 28                           387623464.0  d20191203  False
# 29                           568252410.0  d20191203  False
# ..                                   ...        ...    ...
# 294                          661124992.0  d20191203   True
# 295                          754795456.0  d20191203   True
# 296                          830072576.0  d20191203   True
# 297                          762625728.0  d20191203   True
# 298                          798592000.0  d20191203   True
# 299                          832513792.0  d20191203   True
# 300                          619642048.0  d20191203   True
# 301                          897487168.0  d20191203   True
# 302                          723831424.0  d20191203   True
# 303                          654717952.0  d20191203   True
# 304                          450619712.0  d20191203   True
# 305                          424517696.0  d20191203   True
# 306                          479845568.0  d20191203   True
# 307                          407575392.0  d20191203   True
# 308                          394826048.0  d20191203   True
# 309                          481092416.0  d20191203   True
# 310                          397616096.0  d20191203   True
# 311                          403178624.0  d20191203   True
# 312                          398351776.0  d20191203   True
# 313                          415519360.0  d20191203   True
# 314                          440259904.0  d20191203   True
# 315                          430450880.0  d20191203   True
# 316                          485879584.0  d20191203   True
# 317                          400079552.0  d20191203   True
# 318                          454223232.0  d20191203   True
# 319                          384985152.0  d20191203   True
# 320                          392332800.0  d20191203   True
# 321                          405924032.0  d20191203   True
# 322                          411834976.0  d20191203   True
# 323                          454635328.0  d20191203   True
#
# [324 rows x 62 columns]

# %%
myDataSel=myData.loc[((myData.decon==True) & (myData['ab2 (heterochromatin)']=='HP1beta')),:].copy()

# %%
myDataSel["euchro_20perc_ch2"]=myDataSel.nucleus_Otsu_ch2 - myDataSel.hetChrom_20perc_ch2

# %%
myDataSel["euchro_20perc_ch3"]=myDataSel.nucleus_Otsu_ch3 - myDataSel.hetChrom_20perc_ch3

# %%
myDataSelnd=myData.loc[((myData.decon==False) & (myData['ab2 (heterochromatin)']=='HP1beta')),:].copy()

# %%
myDataSelnd["euchro_20perc_ch2"]=myDataSelnd.nucleus_Otsu_ch2 - myDataSelnd.hetChrom_20perc_ch2

# %%
myDataSelnd["euchro_20perc_ch3"]=myDataSelnd.nucleus_Otsu_ch3 - myDataSelnd.hetChrom_20perc_ch3

# %% [markdown]
# # for new dataset: channels are
# ## ch1: MCM
# ## ch2: hetChrom(HP1Beta)
# ## ch3: DAPI

# %%
# %matplotlib notebook

myDataSel['temp']=(myDataSel.hetChrom_20perc_ch2/myDataSel.nucleus_Otsu_ch2)/(myDataSel.hetChrom_20perc_ch3/myDataSel.nucleus_Otsu_ch3)
sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[('G1' in x for x in myDataSel.category),:], hue='category')
plt.ylabel("MCM/DAPI (euchrom/nucleus)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %% [markdown]
# # erosion analysis

# %% [markdown]
# ## inner (9x9 with 5 iterations)

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu_ch2/myDataSel.nucleus_Otsu_ch3)
center=(myDataSel.nucleus_Otsu_erosion_inner_9x5_ch2/myDataSel.nucleus_Otsu_erosion_inner_9x5_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (nucleus center/nucleus)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in nucleus pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in nucleus pixels')

# %%
# %matplotlib notebook

total= (myDataSel.hetChrom_20perc_ch2/myDataSel.hetChrom_20perc_ch3)
center=(myDataSel.HetChrom_erosion_inner_9x5_20_ch2/myDataSel.HetChrom_erosion_inner_9x5_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het center/het total)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu_erosion_inner_9x5_ch2/myDataSel.nucleus_Otsu_erosion_inner_9x5_ch3)
center=(myDataSel.HetChrom_erosion_inner_9x5_20_ch2/myDataSel.HetChrom_erosion_inner_9x5_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het center/nucleus center)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu_ch2/myDataSel.nucleus_Otsu_ch3)
center=(myDataSel.HetChrom_erosion_inner_9x5_20_ch2/myDataSel.HetChrom_erosion_inner_9x5_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het center/nucleus total)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %% [markdown]
# # outer (9x9 with 5 iterations)

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu_ch2/myDataSel.nucleus_Otsu_ch3)
center=(myDataSel.nucleus_Otsu__erosion_outer_9x5_ch2/myDataSel.nucleus_Otsu__erosion_outer_9x5_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (nucleus outer/nucleus)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in nucleus pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in nucleus pixels')

# %%
# %matplotlib notebook

total= (myDataSel.hetChrom_20perc_ch2/myDataSel.hetChrom_20perc_ch3)
center=(myDataSel.HetChrom_erosion_outer_9x5_20_ch2/myDataSel.HetChrom_erosion_outer_9x5_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het outer/het)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu__erosion_outer_9x5_ch2/myDataSel.nucleus_Otsu__erosion_outer_9x5_ch3)
center=(myDataSel.HetChrom_erosion_outer_9x5_20_ch2/myDataSel.HetChrom_erosion_outer_9x5_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het outer/nucleus outer)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu_ch2/myDataSel.nucleus_Otsu_ch3)
center=(myDataSel.HetChrom_erosion_outer_9x5_20_ch2/myDataSel.HetChrom_erosion_outer_9x5_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het outer/nucleus total)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %% [markdown]
# # inner (13 x 13 with 8 iterations)

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu_ch2/myDataSel.nucleus_Otsu_ch3)
center=(myDataSel.nucleus_Otsu_erosion_inner_13x8_ch2/myDataSel.nucleus_Otsu_erosion_inner_13x8_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (nucleus center/nucleus)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= (myDataSel.hetChrom_20perc_ch2/myDataSel.hetChrom_20perc_ch3)
center=(myDataSel.HetChrom_erosion_inner_13x8_20_ch2/myDataSel.HetChrom_erosion_inner_13x8_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het center/het total)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu_erosion_inner_13x8_ch2/myDataSel.nucleus_Otsu_erosion_inner_13x8_ch3)
center=(myDataSel.HetChrom_erosion_inner_13x8_20_ch2/myDataSel.HetChrom_erosion_inner_13x8_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het center/nucleus center)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu_ch2/myDataSel.nucleus_Otsu_ch3)
center=(myDataSel.HetChrom_erosion_inner_13x8_20_ch2/myDataSel.HetChrom_erosion_inner_13x8_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het center/nucleus)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %% [markdown]
# # outer (13x13 with 8 iterations)

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu_ch2/myDataSel.nucleus_Otsu_ch3)
center=(myDataSel.nucleus_Otsu__erosion_outer_13x8_ch2/myDataSel.nucleus_Otsu__erosion_outer_13x8_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (nucleus outer/nucleus)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= (myDataSel.hetChrom_20perc_ch2/myDataSel.hetChrom_20perc_ch3)
center=(myDataSel.HetChrom_erosion_outer_13x8_20_ch2/myDataSel.HetChrom_erosion_outer_13x8_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het outer/het total)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu__erosion_outer_13x8_ch2/myDataSel.nucleus_Otsu__erosion_outer_13x8_ch3)
center=(myDataSel.HetChrom_erosion_outer_13x8_20_ch2/myDataSel.HetChrom_erosion_outer_13x8_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het outer/nucleus outer)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= (myDataSel.nucleus_Otsu_ch2/myDataSel.nucleus_Otsu_ch3)
center=(myDataSel.HetChrom_erosion_outer_13x8_20_ch2/myDataSel.HetChrom_erosion_outer_13x8_20_ch3)

myDataSel['temp']= center/total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het outer/nucleus)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

total= myDataSel.hetChrom_20perc_ch2
center= myDataSel.HetChrom_erosion_outer_13x8_20_ch2

myDataSel['temp']= total

sn.scatterplot(x='molecular age ', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het outer/het total)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM density in heterochromatin pixels')

# %%
# %matplotlib notebook

myDataSel['temp']=myDataSel.nucleus_Otsu_ch2/myDataSel.nucleus_Otsu_ch3
sn.swarmplot(x='category', y = 'temp', data=myDataSel,
             order=[ "early G1", "middle G1", "late G1","S","G2"],hue='day')

plt.ylabel("MCM/DAPI total")
plt.xlabel("phase")
plt.title("MCM loading control")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM loading control')

# %%
# %matplotlib notebook

myDataSel['temp']=myDataSel.nucleus_Otsu_ch2
sn.swarmplot(x='category', y = 'temp', data=myDataSel,
             order=[ "early G1", "middle G1", "late G1","S","G2"],hue='day')

plt.ylabel("MCM/DAPI total")
plt.xlabel("phase")
plt.title("MCM loading control")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MCM loading control')

# %%
mod=0.3

myDataSel['mol_age_mod']=myDataSel['molecular age ']
myDataSel.loc[((myDataSel.age_track<1.5) & (myDataSel.category=='earlyG1')),'mol_age_mod']=mod
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-bf447e214167> in <module>
#       2
#       3 myDataSel['mol_age_mod']=myDataSel['molecular age ']
# ----> 4 myDataSel.loc[((myDataSel.age_track<1.5) & (myDataSel.category=='earlyG1')),'mol_age_mod']=mod
#
# C:\ProgramData\Anaconda3_reinstalled\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'age_track'

# %%
# %matplotlib notebook

total= myDataSel.hetChrom_20perc_ch2

myDataSel['temp']= total

sn.scatterplot(x='mol_age_mod', y = 'temp', data=myDataSel.loc[['G1' in x for x in myDataSel.category],:],hue='category')
plt.ylabel("MCM/DAPI (het outer/het total)")
plt.xlabel("molecular age [DHB]")
plt.title("MCM density in heterochromatin pixels")
