# %% [markdown]
# ## setups

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats
from itertools import islice

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading'

# %%
newfile=f'{bigDir}\\new dataset\signals_new_v3.csv'
orgfile=f'{bigDir}\signals_org_v3.csv'

# %%
newdata=pd.read_csv(newfile)
orgdata=pd.read_csv(orgfile)

# %%
newdata['day']=[f"d{x.split('_')[0]}" for x in newdata.file]
newdata = newdata.astype({"day": 'object'})
set(newdata['day'])
# Out:
# {'d20191203'}

# %%
for i, cell in newdata.iterrows():
    newdata.at[i,'decon']="d" in newdata.loc[i,'file']

# %%
newdata['p_age']=newdata['physical age [min]'] / 60 +1

# %%
newdata=newdata.drop(columns=['Unnamed: 0'])

# %%
newdata.head()
# Out:
#                    file original cell name                       movie  \
# 0  20191203_cell-00.czi     20191125-01-17  191125pcnat_dhbr_cdc6vxy01
# 1  20191203_cell-01.czi     20191125-01-20  191125pcnat_dhbr_cdc6vxy01
# 2  20191203_cell-02.czi     20191125-01-23  191125pcnat_dhbr_cdc6vxy01
# 3  20191203_cell-03.czi     20191125-01-25  191125pcnat_dhbr_cdc6vxy01
# 4  20191203_cell-04.czi     20191125-01-32  191125pcnat_dhbr_cdc6vxy01
#
#    last frame movie position x  last frame movie position y ab1 (MCM)  ab1 ch  \
# 0                      678.301                      200.931      MCM3       1
# 1                     1552.152                      240.479      MCM3       1
# 2                     1131.436                      318.530      MCM3       1
# 3                     1650.585                      324.968      MCM3       1
# 4                     1466.687                      426.815      MCM3       1
#
#   ab2 (heterochromatin)  ab2 ch  DAPI ch  ...  outer_DAPI_total  nuc_DAPI_het  \
# 0               HP1beta       2        3  ...      2.124247e+09  1.061172e+09
# 1               HP1beta       2        3  ...      4.333228e+09  1.812075e+09
# 2               HP1beta       2        3  ...      4.230824e+09  1.774444e+09
# 3               HP1beta       2        3  ...      2.766073e+09  1.229128e+09
# 4               HP1beta       2        3  ...      2.450390e+09  1.261960e+09
#
#    inner_DAPI_het  outer_DAPI_het   nuc_DAPI_eu  inner_DAPI_eu outer_DAPI_eu  \
# 0    6.286906e+08     432481890.0  2.027203e+09   3.354374e+08  1.691765e+09
# 1    1.086345e+09     725729186.0  4.615195e+09   1.007696e+09  3.607499e+09
# 2    1.047682e+09     726762664.0  4.452523e+09   9.484609e+08  3.504062e+09
# 3    5.907975e+08     638330656.0  2.382242e+09   2.544991e+08  2.127743e+09
# 4    7.882228e+08     473737399.0  2.363135e+09   3.864823e+08  1.976653e+09
#
#          day  decon      p_age
# 0  d20191203  False   6.666667
# 1  d20191203  False        NaN
# 2  d20191203  False  16.166667
# 3  d20191203  False   1.500000
# 4  d20191203  False   5.166667
#
# [5 rows x 49 columns]

# %% [markdown]
# # molecular age modifications - newdata

# %%
def mol_age_mod (threshold,add_min=False):
    
    newdata['mol_age_mod']=newdata['molecular age ']
    mol_age_change=newdata.loc[((newdata.p_age<threshold) & (newdata.category=='earlyG1')),'mol_age_mod']
    if add_min:
        add=np.min(mol_age_change)
    else:
        add=0
    newdata.loc[((newdata.p_age<threshold) & (newdata.category=='earlyG1')),'mol_age_mod']=-1*newdata['mol_age_mod']+np.max(mol_age_change)+add
    return mol_age_change

# %%
# %matplotlib notebook 
sn.scatterplot(x='p_age',y='molecular age ',data=newdata.loc[['G1' in x for x in newdata.category],:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### initial modification

# %%
mol_age_change=mol_age_mod(2)

# %%
# %matplotlib notebook 
sn.scatterplot(x='p_age',y='mol_age_mod',data=newdata.loc[['G1' in x for x in newdata.category],:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### second modification

# %%
mol_age_change=mol_age_mod(2,True)

# %%
# %matplotlib notebook 
sn.scatterplot(x='p_age',y='mol_age_mod',data=newdata.loc[['G1' in x for x in newdata.category],:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### third modification

# %%
newdata['mol_age_mod']=newdata['molecular age ']
newdata.loc[((newdata.p_age<2) & (newdata.category=='earlyG1')),'mol_age_mod']=np.min(mol_age_change)

# %%
# %matplotlib notebook 
sn.scatterplot(x='p_age',y='mol_age_mod',data=newdata.loc[['G1' in x for x in newdata.category],:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### fifth modification

# %%
newdata['mol_age_mod']=newdata['molecular age ']
newdata.loc[((newdata.p_age<2) & (newdata.category=='earlyG1')),'mol_age_mod']=np.min(newdata['molecular age '])

# %%
# %matplotlib notebook 
sn.scatterplot(x='p_age',y='mol_age_mod',data=newdata.loc[['G1' in x for x in newdata.category],:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
newdata.index[((newdata.p_age<2) & (newdata.category=='earlyG1'))]
# Out:
# Int64Index([  3,  13,  15,  23,  24,  25,  26,  40,  67,  72,  89,  93, 100,
#             141, 151, 153, 161, 162, 163, 164, 178, 205, 210, 227, 231, 238],
#            dtype='int64')

# %%
newdata.head()
# Out:
#                    file original cell name                       movie  \
# 0  20191203_cell-00.czi     20191125-01-17  191125pcnat_dhbr_cdc6vxy01
# 1  20191203_cell-01.czi     20191125-01-20  191125pcnat_dhbr_cdc6vxy01
# 2  20191203_cell-02.czi     20191125-01-23  191125pcnat_dhbr_cdc6vxy01
# 3  20191203_cell-03.czi     20191125-01-25  191125pcnat_dhbr_cdc6vxy01
# 4  20191203_cell-04.czi     20191125-01-32  191125pcnat_dhbr_cdc6vxy01
#
#    last frame movie position x  last frame movie position y ab1 (MCM)  ab1 ch  \
# 0                      678.301                      200.931      MCM3       1
# 1                     1552.152                      240.479      MCM3       1
# 2                     1131.436                      318.530      MCM3       1
# 3                     1650.585                      324.968      MCM3       1
# 4                     1466.687                      426.815      MCM3       1
#
#   ab2 (heterochromatin)  ab2 ch  DAPI ch  ...  nuc_DAPI_het inner_DAPI_het  \
# 0               HP1beta       2        3  ...  1.061172e+09   6.286906e+08
# 1               HP1beta       2        3  ...  1.812075e+09   1.086345e+09
# 2               HP1beta       2        3  ...  1.774444e+09   1.047682e+09
# 3               HP1beta       2        3  ...  1.229128e+09   5.907975e+08
# 4               HP1beta       2        3  ...  1.261960e+09   7.882228e+08
#
#    outer_DAPI_het   nuc_DAPI_eu inner_DAPI_eu  outer_DAPI_eu        day  \
# 0     432481890.0  2.027203e+09  3.354374e+08   1.691765e+09  d20191203
# 1     725729186.0  4.615195e+09  1.007696e+09   3.607499e+09  d20191203
# 2     726762664.0  4.452523e+09  9.484609e+08   3.504062e+09  d20191203
# 3     638330656.0  2.382242e+09  2.544991e+08   2.127743e+09  d20191203
# 4     473737399.0  2.363135e+09  3.864823e+08   1.976653e+09  d20191203
#
#    decon      p_age  mol_age_mod
# 0  False   6.666667        0.444
# 1  False        NaN        1.373
# 2  False  16.166667        1.371
# 3  False   1.500000        0.208
# 4  False   5.166667        0.345
#
# [5 rows x 50 columns]

# %%
newdata.to_csv(newfile.replace('v3','v4'))

# %% [markdown]
# # molecular age modification - org data

# %% [markdown]
# ## setup for orgdata

# %%
orgdata['day']=[f"d{x.split('_')[0]}" for x in orgdata.file]
orgdata = orgdata.astype({"day": 'object'})
set(orgdata['day'])
# Out:
# {'d20190506',
#  'd20190607',
#  'd20190609',
#  'd20190625',
#  'd20190701',
#  'd201907012',
#  'd201907016'}

# %%
orgdata['p_age'] = (orgdata.DHB_len - 1) *10 / 60

# %%
for i, cell in orgdata.iterrows():
    orgdata.at[i,'decon']="d" in orgdata.loc[i,'file']

# %%
orgdata.head()
# Out:
#    Unnamed: 0                  file original cell name  Amy_mod  \
# 0           0  20190625_cell-01.czi           7L-E1(T)        0
# 1           1  20190625_cell-02.czi           7L-E2(B)        0
# 2           2  20190625_cell-03.czi           7L-E2(T)        0
# 3           3  20190625_cell-05.czi              7L-G2        0
# 4           4  20190625_cell-06.czi              7L-G3        0
#
#                          movie    x    y ab1 (heterochromatin)  ab1 ch  \
# 0  190619-cdc6-dhb-pcna002xy09  158  906                  HP1B       1
# 1  190619-cdc6-dhb-pcna002xy09  832  252                  HP1B       1
# 2  190619-cdc6-dhb-pcna002xy09  888  160                  HP1B       1
# 3  190619-cdc6-dhb-pcna002xy09  172  324                  HP1B       1
# 4  190619-cdc6-dhb-pcna002xy09  492  506                  HP1B       1
#
#   ab2 (MCM)  ...  inner_DAPI_total  outer_DAPI_total  nuc_DAPI_het  \
# 0      MCM3  ...      3.409277e+09      7.162939e+09  2.603415e+09
# 1      MCM3  ...      3.719191e+09      7.431494e+09  2.648662e+09
# 2      MCM3  ...      3.427136e+09      7.047608e+09  2.521722e+09
# 3      MCM3  ...      8.811838e+09      1.280485e+10  5.093679e+09
# 4      MCM3  ...      9.410591e+09      1.360591e+10  5.393420e+09
#
#   inner_DAPI_het outer_DAPI_het   nuc_DAPI_eu inner_DAPI_eu  outer_DAPI_eu  \
# 0   1.697959e+09   9.054561e+08  7.968800e+09  1.711318e+09   6.257482e+09
# 1   1.905904e+09   7.427579e+08  8.502024e+09  1.813288e+09   6.688736e+09
# 2   1.686519e+09   8.352024e+08  7.953022e+09  1.740616e+09   6.212406e+09
# 3   3.586438e+09   1.507240e+09  1.652301e+10  5.225400e+09   1.129761e+10
# 4   3.580233e+09   1.813187e+09  1.762309e+10  5.830358e+09   1.179273e+10
#
#          day      p_age
# 0  d20190625   0.666667
# 1  d20190625   2.000000
# 2  d20190625   2.000000
# 3  d20190625  19.500000
# 4  d20190625  18.833333
#
# [5 rows x 68 columns]

# %%
# %matplotlib notebook 
sn.scatterplot(x='p_age',y='molecular age',data=orgdata.loc[((orgdata.day!='d20190625') & (orgdata.day!='d201907012') &
                                                           ['early' in x for x in orgdata.category]),:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def mol_age_mod_org (threshold,add_min=False):
    
    orgdata['mol_age_mod']=orgdata['molecular age']
    mol_age_change=orgdata.loc[((orgdata.p_age<threshold) & (orgdata.category=='earlyG1')),'mol_age_mod']
    if add_min:
        add=np.min(mol_age_change)
    else:
        add=0
    orgdata.loc[((orgdata.p_age<threshold) & (orgdata.category=='earlyG1')),'mol_age_mod']=-1*orgdata['mol_age_mod']+np.max(mol_age_change)+add
    return mol_age_change

# %% [markdown]
# ### initial modification

# %%
mol_age_change=mol_age_mod_org(2)

# %%
# %matplotlib notebook 
sn.scatterplot(x='p_age',y='mol_age_mod',data=orgdata.loc[((orgdata.day!='d20190625') & (orgdata.day!='d201907012') &
                                                           ['early' in x for x in orgdata.category]),:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### second modification

# %%
mol_age_change=mol_age_mod_org(2,True)

# %%
# %matplotlib notebook 
sn.scatterplot(x='p_age',y='mol_age_mod',data=orgdata.loc[((orgdata.day!='d20190625') & (orgdata.day!='d201907012') &
                                                           ['early' in x for x in orgdata.category]),:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### third modification

# %%
orgdata['mol_age_mod']=orgdata['molecular age']
orgdata.loc[((orgdata.p_age<1.5) & (orgdata.category=='earlyG1')),'mol_age_mod']=np.min(mol_age_change)

# %%
# %matplotlib notebook 
sn.scatterplot(x='p_age',y='mol_age_mod',data=orgdata.loc[((orgdata.day!='d20190625') & (orgdata.day!='d201907012') &
                                                           ['G1' in x for x in orgdata.category]),:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### fourth modification

# %%
orgdata['mol_age_mod']=orgdata['molecular age']
orgdata.loc[((orgdata.p_age<2) & (orgdata.category=='earlyG1')),'mol_age_mod']=np.min(orgdata['molecular age'])

# %%
# %matplotlib notebook 
sn.scatterplot(x='p_age',y='mol_age_mod',data=orgdata.loc[((orgdata.day!='d20190625') & (orgdata.day!='d201907012') &
                                                           ['early' in x for x in orgdata.category]),:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
orgdata.index[((orgdata.p_age<1.5) & (orgdata.category=='earlyG1'))]
# Out:
# Int64Index([  0,  19,  38,  39,  48,  49,  50,  59,  60,  61,  62,  63,  80,
#              81,  82,  83, 100, 101, 113, 114, 115, 116, 128, 129, 130, 131,
#             132, 133, 134, 151, 152, 153, 154, 155, 173, 174, 192, 193, 208,
#             209, 227, 228],
#            dtype='int64')

# %%
orgdata.head()
# Out:
#    Unnamed: 0                  file original cell name  Amy_mod  \
# 0           0  20190625_cell-01.czi           7L-E1(T)        0
# 1           1  20190625_cell-02.czi           7L-E2(B)        0
# 2           2  20190625_cell-03.czi           7L-E2(T)        0
# 3           3  20190625_cell-05.czi              7L-G2        0
# 4           4  20190625_cell-06.czi              7L-G3        0
#
#                          movie    x    y ab1 (heterochromatin)  ab1 ch  \
# 0  190619-cdc6-dhb-pcna002xy09  158  906                  HP1B       1
# 1  190619-cdc6-dhb-pcna002xy09  832  252                  HP1B       1
# 2  190619-cdc6-dhb-pcna002xy09  888  160                  HP1B       1
# 3  190619-cdc6-dhb-pcna002xy09  172  324                  HP1B       1
# 4  190619-cdc6-dhb-pcna002xy09  492  506                  HP1B       1
#
#   ab2 (MCM)  ...  outer_DAPI_total  nuc_DAPI_het  inner_DAPI_het  \
# 0      MCM3  ...      7.162939e+09  2.603415e+09    1.697959e+09
# 1      MCM3  ...      7.431494e+09  2.648662e+09    1.905904e+09
# 2      MCM3  ...      7.047608e+09  2.521722e+09    1.686519e+09
# 3      MCM3  ...      1.280485e+10  5.093679e+09    3.586438e+09
# 4      MCM3  ...      1.360591e+10  5.393420e+09    3.580233e+09
#
#   outer_DAPI_het   nuc_DAPI_eu  inner_DAPI_eu outer_DAPI_eu        day  \
# 0   9.054561e+08  7.968800e+09   1.711318e+09  6.257482e+09  d20190625
# 1   7.427579e+08  8.502024e+09   1.813288e+09  6.688736e+09  d20190625
# 2   8.352024e+08  7.953022e+09   1.740616e+09  6.212406e+09  d20190625
# 3   1.507240e+09  1.652301e+10   5.225400e+09  1.129761e+10  d20190625
# 4   1.813187e+09  1.762309e+10   5.830358e+09  1.179273e+10  d20190625
#
#        p_age  mol_age_mod
# 0   0.666667     0.287517
# 1   2.000000     0.431866
# 2   2.000000     0.499777
# 3  19.500000     1.479820
# 4  18.833333     1.517313
#
# [5 rows x 69 columns]

# %%
orgdata=orgdata.drop(columns=['Unnamed: 0'])

# %%
orgdata.to_csv(orgfile.replace("v3","v4"))

# %% [markdown]
# # merging modified dataframes into one file

# %%
newdata=newdata.rename(columns={'ab2 (heterochromatin)': 'ab1 (heterochromatin)'})

# %%
merged=pd.concat([orgdata,newdata],join='inner', ignore_index=True)

# %%
orgdata.columns
# Out:
# Index(['file', 'original cell name', 'Amy_mod', 'movie', 'x', 'y',
#        'ab1 (heterochromatin)', 'ab1 ch', 'ab2 (MCM)', 'ab2 ch', 'DAPI ch',
#        'DIC ch', 'category', 'physical age [min]', 'molecular age',
#        'imaging core', 'cell id for tracking', 'comment', 'dhb_tracking',
#        'exp', 'decon', 'track_cell_id', 'dist', 'x_track', 'y_track',
#        'track_length', 'path', 'paired', 'DHB_nucleus', 'DHB_cyto',
#        'DHB_ratio', 'DHB_len', 'physical_age_cleaned', 'physicalAgeMatch',
#        'time_mismatch', 'track_vs_measure', 'molecularAgeMatch',
#        'molecularAge_mismatch', 'nuc_vol_total', 'inner_vol_total',
#        'outer_vol_total', 'nuc_mcm_total', 'inner_mcm_total',
#        'outer_mcm_total', 'nuc_vol_het', 'inner_vol_het', 'outer_vol_het',
#        'nuc_mcm_het', 'inner_mcm_het', 'outer_mcm_het', 'nuc_vol_eu',
#        'inner_vol_eu', 'outer_vol_eu', 'nuc_mcm_eu', 'inner_mcm_eu',
#        'outer_mcm_eu', 'nuc_DAPI_total', 'inner_DAPI_total',
#        'outer_DAPI_total', 'nuc_DAPI_het', 'inner_DAPI_het', 'outer_DAPI_het',
#        'nuc_DAPI_eu', 'inner_DAPI_eu', 'outer_DAPI_eu', 'day', 'p_age',
#        'mol_age_mod'],
#       dtype='object')

# %%
newdata.columns
# Out:
# Index(['file', 'original cell name', 'movie', 'last frame movie position x',
#        'last frame movie position y', 'ab1 (MCM)', 'ab1 ch',
#        'ab1 (heterochromatin)', 'ab2 ch', 'DAPI ch', 'DIC ch', 'category',
#        'molecular age ', 'physical age [min]', 'imaging core',
#        'cell id for tracking', 'comment', 'molecular age 10', 'path',
#        'nuc_vol_total', 'inner_vol_total', 'outer_vol_total', 'nuc_mcm_total',
#        'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het', 'inner_vol_het',
#        'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het', 'outer_mcm_het',
#        'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu', 'nuc_mcm_eu',
#        'inner_mcm_eu', 'outer_mcm_eu', 'nuc_DAPI_total', 'inner_DAPI_total',
#        'outer_DAPI_total', 'nuc_DAPI_het', 'inner_DAPI_het', 'outer_DAPI_het',
#        'nuc_DAPI_eu', 'inner_DAPI_eu', 'outer_DAPI_eu', 'day', 'decon',
#        'p_age', 'mol_age_mod'],
#       dtype='object')

# %%
merged.columns
# Out:
# Index(['file', 'original cell name', 'movie', 'ab1 (heterochromatin)',
#        'ab1 ch', 'ab2 ch', 'DAPI ch', 'DIC ch', 'category',
#        'physical age [min]', 'imaging core', 'cell id for tracking', 'comment',
#        'decon', 'path', 'nuc_vol_total', 'inner_vol_total', 'outer_vol_total',
#        'nuc_mcm_total', 'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het',
#        'inner_vol_het', 'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het',
#        'outer_mcm_het', 'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu',
#        'nuc_mcm_eu', 'inner_mcm_eu', 'outer_mcm_eu', 'nuc_DAPI_total',
#        'inner_DAPI_total', 'outer_DAPI_total', 'nuc_DAPI_het',
#        'inner_DAPI_het', 'outer_DAPI_het', 'nuc_DAPI_eu', 'inner_DAPI_eu',
#        'outer_DAPI_eu', 'day', 'p_age', 'mol_age_mod'],
#       dtype='object')

# %%
orgdata.columns & newdata.columns
# Out:
# Index(['file', 'original cell name', 'movie', 'ab1 (heterochromatin)',
#        'ab1 ch', 'ab2 ch', 'DAPI ch', 'DIC ch', 'category',
#        'physical age [min]', 'imaging core', 'cell id for tracking', 'comment',
#        'decon', 'path', 'nuc_vol_total', 'inner_vol_total', 'outer_vol_total',
#        'nuc_mcm_total', 'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het',
#        'inner_vol_het', 'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het',
#        'outer_mcm_het', 'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu',
#        'nuc_mcm_eu', 'inner_mcm_eu', 'outer_mcm_eu', 'nuc_DAPI_total',
#        'inner_DAPI_total', 'outer_DAPI_total', 'nuc_DAPI_het',
#        'inner_DAPI_het', 'outer_DAPI_het', 'nuc_DAPI_eu', 'inner_DAPI_eu',
#        'outer_DAPI_eu', 'day', 'p_age', 'mol_age_mod'],
#       dtype='object')

# %%
merged.head()
# Out:
#                    file original cell name                        movie  \
# 0  20190625_cell-01.czi           7L-E1(T)  190619-cdc6-dhb-pcna002xy09
# 1  20190625_cell-02.czi           7L-E2(B)  190619-cdc6-dhb-pcna002xy09
# 2  20190625_cell-03.czi           7L-E2(T)  190619-cdc6-dhb-pcna002xy09
# 3  20190625_cell-05.czi              7L-G2  190619-cdc6-dhb-pcna002xy09
# 4  20190625_cell-06.czi              7L-G3  190619-cdc6-dhb-pcna002xy09
#
#   ab1 (heterochromatin)  ab1 ch  ab2 ch  DAPI ch  DIC ch category  \
# 0                  HP1B       1       2        3     4.0  earlyG1
# 1                  HP1B       1       2        3     4.0  earlyG1
# 2                  HP1B       1       2        3     4.0  earlyG1
# 3                  HP1B       1       2        3     4.0       G2
# 4                  HP1B       1       2        3     4.0       G2
#
#   physical age [min]  ... outer_DAPI_total  nuc_DAPI_het inner_DAPI_het  \
# 0                 30  ...     7.162939e+09  2.603415e+09   1.697959e+09
# 1                110  ...     7.431494e+09  2.648662e+09   1.905904e+09
# 2                110  ...     7.047608e+09  2.521722e+09   1.686519e+09
# 3               1160  ...     1.280485e+10  5.093679e+09   3.586438e+09
# 4               1120  ...     1.360591e+10  5.393420e+09   3.580233e+09
#
#   outer_DAPI_het   nuc_DAPI_eu  inner_DAPI_eu  outer_DAPI_eu        day  \
# 0   9.054561e+08  7.968800e+09   1.711318e+09   6.257482e+09  d20190625
# 1   7.427579e+08  8.502024e+09   1.813288e+09   6.688736e+09  d20190625
# 2   8.352024e+08  7.953022e+09   1.740616e+09   6.212406e+09  d20190625
# 3   1.507240e+09  1.652301e+10   5.225400e+09   1.129761e+10  d20190625
# 4   1.813187e+09  1.762309e+10   5.830358e+09   1.179273e+10  d20190625
#
#        p_age  mol_age_mod
# 0   0.666667     0.287517
# 1   2.000000     0.431866
# 2   2.000000     0.499777
# 3  19.500000     1.479820
# 4  18.833333     1.517313
#
# [5 rows x 45 columns]

# %%
merged.loc[0,]
# Out:
# file                                                  20190625_cell-01.czi
# original cell name                                                7L-E1(T)
# movie                                          190619-cdc6-dhb-pcna002xy09
# ab1 (heterochromatin)                                                 HP1B
# ab1 ch                                                                   1
# ab2 ch                                                                   2
# DAPI ch                                                                  3
# DIC ch                                                                   4
# category                                                           earlyG1
# physical age [min]                                                      30
# imaging core                                                           HIC
# cell id for tracking                                                     1
# comment                                                                NaN
# decon                                                                False
# path                     Z:\CookLab\Liu\20190816_organizedData_MCM_load...
# nuc_vol_total                                                       436537
# inner_vol_total                                                     113058
# outer_vol_total                                                     323479
# nuc_mcm_total                                                  1.27049e+09
# inner_mcm_total                                                4.36832e+08
# outer_mcm_total                                                8.33658e+08
# nuc_vol_het                                                          87319
# inner_vol_het                                                        53828
# outer_vol_het                                                        33491
# nuc_mcm_het                                                    3.19245e+08
# inner_mcm_het                                                   2.1002e+08
# outer_mcm_het                                                  1.09225e+08
# nuc_vol_eu                                                          349218
# inner_vol_eu                                                         59230
# outer_vol_eu                                                        289988
# nuc_mcm_eu                                                     9.51244e+08
# inner_mcm_eu                                                   2.26811e+08
# outer_mcm_eu                                                   7.24433e+08
# nuc_DAPI_total                                                 1.05722e+10
# inner_DAPI_total                                               3.40928e+09
# outer_DAPI_total                                               7.16294e+09
# nuc_DAPI_het                                                   2.60341e+09
# inner_DAPI_het                                                 1.69796e+09
# outer_DAPI_het                                                 9.05456e+08
# nuc_DAPI_eu                                                     7.9688e+09
# inner_DAPI_eu                                                  1.71132e+09
# outer_DAPI_eu                                                  6.25748e+09
# day                                                              d20190625
# p_age                                                             0.666667
# mol_age_mod                                                       0.287517
# Name: 0, dtype: object

# %%
merged.dtypes
# Out:
# file                      object
# original cell name        object
# movie                     object
# ab1 (heterochromatin)     object
# ab1 ch                     int64
# ab2 ch                     int64
# DAPI ch                    int64
# DIC ch                   float64
# category                  object
# physical age [min]        object
# imaging core              object
# cell id for tracking     float64
# comment                   object
# decon                     object
# path                      object
# nuc_vol_total            float64
# inner_vol_total          float64
# outer_vol_total          float64
# nuc_mcm_total            float64
# inner_mcm_total          float64
# outer_mcm_total          float64
# nuc_vol_het              float64
# inner_vol_het            float64
# outer_vol_het            float64
# nuc_mcm_het              float64
# inner_mcm_het            float64
# outer_mcm_het            float64
# nuc_vol_eu               float64
# inner_vol_eu             float64
# outer_vol_eu             float64
# nuc_mcm_eu               float64
# inner_mcm_eu             float64
# outer_mcm_eu             float64
# nuc_DAPI_total           float64
# inner_DAPI_total         float64
# outer_DAPI_total         float64
# nuc_DAPI_het             float64
# inner_DAPI_het           float64
# outer_DAPI_het           float64
# nuc_DAPI_eu              float64
# inner_DAPI_eu            float64
# outer_DAPI_eu            float64
# day                       object
# p_age                    float64
# mol_age_mod              float64
# dtype: object

# %%
merged.to_csv(f'{bigDir}\signals_combined_v2.csv')

# %% [markdown]
# # molecular age modification for 2020 dataset

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200207_new data'

file=f'{bigDir}\cellinfo_200203_v5.csv'

data=pd.read_csv(file)

# %%
data['day']=[f"d{x.split('_')[0]}" for x in data.file]
data = data.astype({"day": 'object'})
set(data['day'])
# Out:
# {'d20200203'}

# %%
data['physical age [min]'].dtypes
# Out:
# dtype('O')

# %%
test="80min"

# %%
test1=test[:-3]

# %%
test1
# Out:
# '80'

# %%
test1=int(test1)

# %%
test1
# Out:
# 80

# %%
i=0
for i,myCell in islice(data.iterrows(), i,None):
    try:
        data.loc[i, 'physical_age']=(int(data.loc[i,'physical age [min]'][:-3]) / 60) + 1
    except:
        data.loc[i, 'physical_age']=None

# %%
data['physical_age']
# Out:
# 0       2.333333
# 1       1.333333
# 2       1.333333
# 3       6.833333
# 4       4.166667
# 5       4.166667
# 6       6.166667
# 7       4.166667
# 8       5.833333
# 9       5.833333
# 10           NaN
# 11           NaN
# 12      4.166667
# 13      5.833333
# 14      7.000000
# 15           NaN
# 16      3.500000
# 17      1.500000
# 18      5.500000
# 19      5.166667
# 20           NaN
# 21      1.500000
# 22           NaN
# 23      2.000000
# 24      2.000000
# 25      2.166667
# 26      3.500000
# 27      1.666667
# 28      1.666667
# 29      7.500000
#          ...
# 116          NaN
# 117     2.500000
# 118     4.666667
# 119     4.000000
# 120     4.166667
# 121    11.833333
# 122          NaN
# 123     5.833333
# 124     2.166667
# 125     6.333333
# 126     5.833333
# 127     6.333333
# 128     1.166667
# 129     5.000000
# 130     1.166667
# 131     5.333333
# 132     5.333333
# 133     2.500000
# 134     6.166667
# 135     5.000000
# 136     2.500000
# 137     2.666667
# 138     5.333333
# 139     2.333333
# 140     2.333333
# 141     4.000000
# 142     6.166667
# 143     5.000000
# 144     4.166667
# 145     5.833333
# Name: physical_age, Length: 146, dtype: float64

# %% [markdown]
# ### category modification for 2020 dataset

# %%
i=0
for i,myCell in islice(data.iterrows(), i,None):
    if (data.loc[i,'category']=='late G1'):
        data.loc[i,'category']='lateG1'
    elif (data.loc[i, 'category']=='early G1'):
        data.loc[i,'category']='earlyG1'
    elif(data.loc[i,'category']=='middle G1'):
        data.loc[i,'category']='middleG1'

# %%
# %matplotlib notebook 
sn.scatterplot(x='physical_age',y='molecular age ',data=data.loc[['earlyG1' in x for x in data.category],:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## from the plot physical age vs molecular age, molecular age seems to be higher when physical age is lower than 2 hours

# %%
data['mol_age_mod']=data['molecular age ']
data.loc[((data.physical_age<2) & (data.category=='earlyG1')),'mol_age_mod']=np.min(data['molecular age '])

# %%
# %matplotlib notebook 
sn.scatterplot(x='physical_age',y='mol_age_mod',data=data.loc[['earlyG1' in x for x in data.category],:],hue='category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data.to_csv(file.replace('v5', 'v6'))
