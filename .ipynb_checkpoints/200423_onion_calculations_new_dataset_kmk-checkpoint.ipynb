# %%
import os
from os import listdir
from os.path import isfile, join

import pandas as pd
from itertools import islice
import numpy as np

from skimage.external import tifffile
from skimage.external.tifffile import imread

import matplotlib.pyplot as plt

import ipywidgets as widgets

import random


from scipy.ndimage.morphology import binary_erosion as br
from skimage import morphology as skmor

from scipy import ndimage
from PIL import Image, ImageDraw

import numpy.ma as ma

from skimage.measure import label, regionprops

# %% [markdown]
# ## to calculate
#
# 1_20layer_volume/HP1B/MCM/DAPI_total/hetChrom/euChrom
#
# 20 * 4 * 3 = 240 signals

# %% [markdown]
# # gathering files
# deleting the columns with the signals to recalculate and collect data

# %%
numLayers = 20

# %%
bigDir=r'S:\CookLab\Liu\20190816_organizedData_MCM_loading'

# %%
newfile=f'{bigDir}\\new dataset\signals_new_v4.csv'

# %%
newdata=pd.read_csv(newfile)

# %%
newdata=newdata.drop(columns=['Unnamed: 0'])

# %%
newdata.head()
# Out:
#                    file original cell name                       movie  \
# 0  20191203_cell-01.czi     20191125-01-20  191125pcnat_dhbr_cdc6vxy01
# 1  20191203_cell-03.czi     20191125-01-25  191125pcnat_dhbr_cdc6vxy01
# 2  20191203_cell-05.czi     20191125-01-36  191125pcnat_dhbr_cdc6vxy01
# 3  20191203_cell-08.czi     20191125-01-41  191125pcnat_dhbr_cdc6vxy01
# 4  20191203_cell-11.czi     20191125-01-54  191125pcnat_dhbr_cdc6vxy01
#
#    last frame movie position x  last frame movie position y ab1 (MCM)  ab1 ch  \
# 0                     1552.152                      240.479      MCM3       1
# 1                     1650.585                      324.968      MCM3       1
# 2                     1705.099                      468.246      MCM3       1
# 3                      332.674                      553.990      MCM3       1
# 4                      647.356                      843.150      MCM3       1
#
#   ab2 (heterochromatin)  ab2 ch  DAPI ch  ...  nuc_DAPI_het inner_DAPI_het  \
# 0               HP1beta       2        3  ...  1.812075e+09   1.086345e+09
# 1               HP1beta       2        3  ...  1.229128e+09   5.907975e+08
# 2               HP1beta       2        3  ...  1.336272e+09   8.335653e+08
# 3               HP1beta       2        3  ...  9.643314e+08   5.258328e+08
# 4               HP1beta       2        3  ...  9.153324e+08   3.707237e+08
#
#    outer_DAPI_het   nuc_DAPI_eu inner_DAPI_eu  outer_DAPI_eu        day  \
# 0     725729186.0  4.615195e+09  1.007696e+09   3.607499e+09  d20191203
# 1     638330656.0  2.382242e+09  2.544991e+08   2.127743e+09  d20191203
# 2     502707049.0  2.233975e+09  2.555882e+08   1.978387e+09  d20191203
# 3     438498603.0  2.153495e+09  3.529459e+08   1.800549e+09  d20191203
# 4     544608651.0  2.008052e+09  3.305668e+08   1.677485e+09  d20191203
#
#    decon     p_age  mol_age_mod
# 0  False       NaN        1.373
# 1  False  1.500000        0.226
# 2  False  2.166667        0.632
# 3  False  5.833333        0.759
# 4  False  6.666667        0.325
#
# [5 rows x 50 columns]

# %%
len(newdata)
# Out:
# 150

# %% [markdown]
# ## Calculations

# %%
# %%time

i=0
progBar=widgets.IntProgress(
    value=i,
    min=0,
    max=len(newdata),
    step=1,
    description='Progress:',
    orientation='horizontal'
)
display(progBar)

for i,myCell in newdata.iterrows():
    
    # open cell image
    myCell.path = myCell.path.replace('Z:','S:')
    try:
        myImage=imread(myCell.path) 
    except:
        myCell.path=myCell.path.replace('.tif','.tiff')
        myImage=imread(myCell.path)
    
    # open corresponding onion image
    onionFolder = os.path.dirname(myCell.path).replace('data_tiff',f'onion{numLayers}_nuc_mask')
    maskFile = os.path.basename(myCell.path).replace('.tif',f'_onion{numLayers}.tif')
    maskFile = maskFile.replace('.tiff','.tif')
    myOnion = imread(os.path.join(onionFolder,maskFile))
    
    # open corresponding hetChrom mask
    hetFolder = os.path.dirname(myCell.path).replace('data_tiff','segmentation_20')
    maskFile = os.path.basename(myCell.path).replace('.tif','_hetChrom.tif')
    het = imread(os.path.join(hetFolder,maskFile))
    
    # open corresponding euChrom mask
    euFolder = os.path.dirname(myCell.path).replace('data_tiff','segmentation_20_eu')
    maskFile = os.path.basename(myCell.path).replace('.tif','_euChrom.tif')
    eu = imread(os.path.join(euFolder,maskFile))
    
    # create total mask
    total = myOnion>0
    
    # define chromatin regions
    pixels=['total','het','eu']
    
    # calculate for each layer
    for j in np.arange(1,numLayers+1):
    
        for chrom in pixels:
        
            # volume
            myName = f'{str(j).zfill(2)}_vol_{chrom}'
            signal = np.sum((myOnion==j) * eval(chrom))
            newdata.loc[i,myName] = signal
            
            # volume for nuclear signals
            myName = f'nuc_vol_{chrom}'
            signal = np.sum(eval(chrom))
            newdata.loc[i,myName] = signal
    
            # DAPI
            myName = f'{str(j).zfill(2)}_DAPI_{chrom}'
            signal = np.sum((myOnion==j).astype(int) * eval(chrom).astype(int) * myImage[:,2,:,:])
            newdata.loc[i,myName] = signal
            
            # DAPI for nuclear signals
            myName = f'nuc_DAPI_{chrom}'
            signal = np.sum(eval(chrom).astype(int) * myImage[:,2,:,:])
            newdata.loc[i,myName] = signal

            # HP1B
            myName = f'{str(j).zfill(2)}_HP1B_{chrom}'
            signal = np.sum((myOnion==j).astype(int) * eval(chrom).astype(int) * myImage[:,1,:,:])
            newdata.loc[i,myName] = signal
            
            # HP1B for nuclear signals
            myName = f'nuc_HP1B_{chrom}'
            signal = np.sum(eval(chrom).astype(int) * myImage[:,1,:,:])
            newdata.loc[i,myName] = signal
            
            # MCM
            myName = f'{str(j).zfill(2)}_MCM_{chrom}'
            signal = np.sum((myOnion==j).astype(int) * eval(chrom).astype(int) * myImage[:,0,:,:])
            newdata.loc[i,myName] = signal
            
            # MCM for nuclear signals
            myName = f'nuc_MCM_{chrom}'
            signal = np.sum(eval(chrom).astype(int) * myImage[:,0,:,:])
            newdata.loc[i,myName] = signal            

    
    progBar.value=progBar.value+1
# Out:
# IntProgress(value=0, description='Progress:', max=150)
# Wall time: 49min 25s

# %%
np.sum((myOnion==j) * eval(chrom))
# Out:
# 14001

# %%
np.sum((myOnion==j).astype(int) * eval(chrom))
# Out:
# 14001

# %%
np.sum((myOnion==j).astype(int) * eval(chrom)).astype(int)
# Out:
# 14001

# %%
np.sum((myOnion==j).astype(int) * eval(chrom) * myImage[:,0,:,:])
# Out:
# 87294385.83666992

# %%
np.sum((myOnion==j).astype(int) * eval(chrom).astype(int) * myImage[:,0,:,:])
# Out:
# 87294385.83666992

# %%
np.sum((myOnion==j).astype(int) * eval(chrom).astype(int) * myImage[:,0,:,:].astype(int))
# Out:
# 87287426

# %%
myImage[10,0,180,180].astype(int)
# Out:
# 8894

# %%
eu[10,180,180]
# Out:
# 1

# %%
total.dtype
# Out:
# dtype('bool')

# %%
len(list(newdata.columns))
# Out:
# 296

# %%
list(newdata.columns)
# Out:
# ['file',
#  'original cell name',
#  'movie',
#  'last frame movie position x',
#  'last frame movie position y',
#  'ab1 (MCM)',
#  'ab1 ch',
#  'ab2 (heterochromatin)',
#  'ab2 ch',
#  'DAPI ch',
#  'DIC ch',
#  'category',
#  'molecular age ',
#  'physical age [min]',
#  'imaging core',
#  'cell id for tracking',
#  'comment',
#  'molecular age 10',
#  'path',
#  'nuc_vol_total',
#  'inner_vol_total',
#  'outer_vol_total',
#  'nuc_mcm_total',
#  'inner_mcm_total',
#  'outer_mcm_total',
#  'nuc_vol_het',
#  'inner_vol_het',
#  'outer_vol_het',
#  'nuc_mcm_het',
#  'inner_mcm_het',
#  'outer_mcm_het',
#  'nuc_vol_eu',
#  'inner_vol_eu',
#  'outer_vol_eu',
#  'nuc_mcm_eu',
#  'inner_mcm_eu',
#  'outer_mcm_eu',
#  'nuc_DAPI_total',
#  'inner_DAPI_total',
#  'outer_DAPI_total',
#  'nuc_DAPI_het',
#  'inner_DAPI_het',
#  'outer_DAPI_het',
#  'nuc_DAPI_eu',
#  'inner_DAPI_eu',
#  'outer_DAPI_eu',
#  'day',
#  'decon',
#  'p_age',
#  'mol_age_mod',
#  '01_vol_total',
#  '01_DAPI_total',
#  '01_HP1B_total',
#  'nuc_HP1B_total',
#  '01_MCM_total',
#  'nuc_MCM_total',
#  '01_vol_het',
#  '01_DAPI_het',
#  '01_HP1B_het',
#  'nuc_HP1B_het',
#  '01_MCM_het',
#  'nuc_MCM_het',
#  '01_vol_eu',
#  '01_DAPI_eu',
#  '01_HP1B_eu',
#  'nuc_HP1B_eu',
#  '01_MCM_eu',
#  'nuc_MCM_eu',
#  '02_vol_total',
#  '02_DAPI_total',
#  '02_HP1B_total',
#  '02_MCM_total',
#  '02_vol_het',
#  '02_DAPI_het',
#  '02_HP1B_het',
#  '02_MCM_het',
#  '02_vol_eu',
#  '02_DAPI_eu',
#  '02_HP1B_eu',
#  '02_MCM_eu',
#  '03_vol_total',
#  '03_DAPI_total',
#  '03_HP1B_total',
#  '03_MCM_total',
#  '03_vol_het',
#  '03_DAPI_het',
#  '03_HP1B_het',
#  '03_MCM_het',
#  '03_vol_eu',
#  '03_DAPI_eu',
#  '03_HP1B_eu',
#  '03_MCM_eu',
#  '04_vol_total',
#  '04_DAPI_total',
#  '04_HP1B_total',
#  '04_MCM_total',
#  '04_vol_het',
#  '04_DAPI_het',
#  '04_HP1B_het',
#  '04_MCM_het',
#  '04_vol_eu',
#  '04_DAPI_eu',
#  '04_HP1B_eu',
#  '04_MCM_eu',
#  '05_vol_total',
#  '05_DAPI_total',
#  '05_HP1B_total',
#  '05_MCM_total',
#  '05_vol_het',
#  '05_DAPI_het',
#  '05_HP1B_het',
#  '05_MCM_het',
#  '05_vol_eu',
#  '05_DAPI_eu',
#  '05_HP1B_eu',
#  '05_MCM_eu',
#  '06_vol_total',
#  '06_DAPI_total',
#  '06_HP1B_total',
#  '06_MCM_total',
#  '06_vol_het',
#  '06_DAPI_het',
#  '06_HP1B_het',
#  '06_MCM_het',
#  '06_vol_eu',
#  '06_DAPI_eu',
#  '06_HP1B_eu',
#  '06_MCM_eu',
#  '07_vol_total',
#  '07_DAPI_total',
#  '07_HP1B_total',
#  '07_MCM_total',
#  '07_vol_het',
#  '07_DAPI_het',
#  '07_HP1B_het',
#  '07_MCM_het',
#  '07_vol_eu',
#  '07_DAPI_eu',
#  '07_HP1B_eu',
#  '07_MCM_eu',
#  '08_vol_total',
#  '08_DAPI_total',
#  '08_HP1B_total',
#  '08_MCM_total',
#  '08_vol_het',
#  '08_DAPI_het',
#  '08_HP1B_het',
#  '08_MCM_het',
#  '08_vol_eu',
#  '08_DAPI_eu',
#  '08_HP1B_eu',
#  '08_MCM_eu',
#  '09_vol_total',
#  '09_DAPI_total',
#  '09_HP1B_total',
#  '09_MCM_total',
#  '09_vol_het',
#  '09_DAPI_het',
#  '09_HP1B_het',
#  '09_MCM_het',
#  '09_vol_eu',
#  '09_DAPI_eu',
#  '09_HP1B_eu',
#  '09_MCM_eu',
#  '10_vol_total',
#  '10_DAPI_total',
#  '10_HP1B_total',
#  '10_MCM_total',
#  '10_vol_het',
#  '10_DAPI_het',
#  '10_HP1B_het',
#  '10_MCM_het',
#  '10_vol_eu',
#  '10_DAPI_eu',
#  '10_HP1B_eu',
#  '10_MCM_eu',
#  '11_vol_total',
#  '11_DAPI_total',
#  '11_HP1B_total',
#  '11_MCM_total',
#  '11_vol_het',
#  '11_DAPI_het',
#  '11_HP1B_het',
#  '11_MCM_het',
#  '11_vol_eu',
#  '11_DAPI_eu',
#  '11_HP1B_eu',
#  '11_MCM_eu',
#  '12_vol_total',
#  '12_DAPI_total',
#  '12_HP1B_total',
#  '12_MCM_total',
#  '12_vol_het',
#  '12_DAPI_het',
#  '12_HP1B_het',
#  '12_MCM_het',
#  '12_vol_eu',
#  '12_DAPI_eu',
#  '12_HP1B_eu',
#  '12_MCM_eu',
#  '13_vol_total',
#  '13_DAPI_total',
#  '13_HP1B_total',
#  '13_MCM_total',
#  '13_vol_het',
#  '13_DAPI_het',
#  '13_HP1B_het',
#  '13_MCM_het',
#  '13_vol_eu',
#  '13_DAPI_eu',
#  '13_HP1B_eu',
#  '13_MCM_eu',
#  '14_vol_total',
#  '14_DAPI_total',
#  '14_HP1B_total',
#  '14_MCM_total',
#  '14_vol_het',
#  '14_DAPI_het',
#  '14_HP1B_het',
#  '14_MCM_het',
#  '14_vol_eu',
#  '14_DAPI_eu',
#  '14_HP1B_eu',
#  '14_MCM_eu',
#  '15_vol_total',
#  '15_DAPI_total',
#  '15_HP1B_total',
#  '15_MCM_total',
#  '15_vol_het',
#  '15_DAPI_het',
#  '15_HP1B_het',
#  '15_MCM_het',
#  '15_vol_eu',
#  '15_DAPI_eu',
#  '15_HP1B_eu',
#  '15_MCM_eu',
#  '16_vol_total',
#  '16_DAPI_total',
#  '16_HP1B_total',
#  '16_MCM_total',
#  '16_vol_het',
#  '16_DAPI_het',
#  '16_HP1B_het',
#  '16_MCM_het',
#  '16_vol_eu',
#  '16_DAPI_eu',
#  '16_HP1B_eu',
#  '16_MCM_eu',
#  '17_vol_total',
#  '17_DAPI_total',
#  '17_HP1B_total',
#  '17_MCM_total',
#  '17_vol_het',
#  '17_DAPI_het',
#  '17_HP1B_het',
#  '17_MCM_het',
#  '17_vol_eu',
#  '17_DAPI_eu',
#  '17_HP1B_eu',
#  '17_MCM_eu',
#  '18_vol_total',
#  '18_DAPI_total',
#  '18_HP1B_total',
#  '18_MCM_total',
#  '18_vol_het',
#  '18_DAPI_het',
#  '18_HP1B_het',
#  '18_MCM_het',
#  '18_vol_eu',
#  '18_DAPI_eu',
#  '18_HP1B_eu',
#  '18_MCM_eu',
#  '19_vol_total',
#  '19_DAPI_total',
#  '19_HP1B_total',
#  '19_MCM_total',
#  '19_vol_het',
#  '19_DAPI_het',
#  '19_HP1B_het',
#  '19_MCM_het',
#  '19_vol_eu',
#  '19_DAPI_eu',
#  '19_HP1B_eu',
#  '19_MCM_eu',
#  '20_vol_total',
#  '20_DAPI_total',
#  '20_HP1B_total',
#  '20_MCM_total',
#  '20_vol_het',
#  '20_DAPI_het',
#  '20_HP1B_het',
#  '20_MCM_het',
#  '20_vol_eu',
#  '20_DAPI_eu',
#  '20_HP1B_eu',
#  '20_MCM_eu']

# %%
# test functions
# for newly calculated signals
pixels=['total','het','eu']

signals = ['vol','HP1B','DAPI','MCM']

for chrom in pixels:
       
    for signal in signals:
        
        temp = np.zeros(len(newdata))
        
        for j in np.arange(1,numLayers+1):
    
            myName = f'{str(j).zfill(2)}_{signal}_{chrom}'
    
            myColumn = newdata[myName]
        
            temp = temp + myColumn
            
        test = ((np.sum(temp - newdata[f'nuc_{signal}_{chrom}'])))
            
        print(f'{signal}_{chrom}: {test}')
# Out:
# vol_total: 0.0
# HP1B_total: 8589934592.0
# DAPI_total: 304942678016.0
# MCM_total: 133143986176.0
# vol_het: 0.0
# HP1B_het: 0.0
# DAPI_het: 0.0
# MCM_het: 0.0
# vol_eu: 0.0
# HP1B_eu: 0.0
# DAPI_eu: 171798691840.0
# MCM_eu: 21474836480.0

# %%
# %matplotlib notebook
plt.plot(newdata['nuc_vol_het']+newdata['nuc_vol_eu']-newdata['nuc_vol_total'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.plot(temp - newdata[f'nuc_{signal}_{chrom}'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# divide into n layers by volume

n = 2

myVolume = 0

ind = 0

for i,myCell in newdata.iterrows():

    for j in np.arange(1,numLayers+1):

        myVolume = myVolume + myCell[f'{str(j).zfill(2)}_vol_total']
        myVolumeRatio = myVolume/myCell['nuc_vol_total']
        
        if myVolumeRatio > 0.5:
            
            print(j)
            
            break

# %%
for i,myCell in newdata.iterrows():

# %%
## calculating signals for new dataset
calculate_DAPI_signals(newdata)

# %%
## checking if signal calculations resulted in the way we have expected
(np.sum(newdata['inner_DAPI_total'])+np.sum(newdata['outer_DAPI_total']))/np.sum(newdata['nuc_DAPI_total'])

# %%
## checking if signal calculations resulted in the way we have expected
print((np.sum(newdata['inner_DAPI_het'])+np.sum(newdata['outer_DAPI_het']))/np.sum(newdata['nuc_DAPI_het']),
(np.sum(newdata['inner_DAPI_eu'])+np.sum(newdata['outer_DAPI_eu']))/np.sum(newdata['nuc_DAPI_eu']))

# %%
## saving the dataset to csv file
newdata.to_csv(newfile.replace('v1','v2'))

# %% [markdown]
# the data/signal calculations that were done in this file will be retreived in the other file - '200221_DAPI_calculations'
