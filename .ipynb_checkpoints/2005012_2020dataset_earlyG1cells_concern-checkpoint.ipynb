# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200207_new data'

# %%
file=f'{bigDir}\cellinfo_200203_v6.csv'

# %%
data=pd.read_csv(file)

# %% [markdown]
# # data visualizations

# %%
data=data.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])

# %%
data.head()
# Out:
#                    file        original cell name               movie  \
# 0  20200203_cell_00.ciz  20200203-06-13-63X 16bit  20200203 simcmxy06
# 1  20200203_cell_01.ciz  20200203-06-25-63X 16bit  20200203 simcmxy06
# 2  20200203_cell_02.ciz  20200203-06-27-63X 16bit  20200203 simcmxy06
# 3  20200203_cell_03.ciz  20200203-06-29-63X 16bit  20200203 simcmxy06
# 4  20200203_cell_04.ciz  20200203-06-51-63X 16bit  20200203 simcmxy06
#
#    last frame movie position x  last frame movie position y ab1 (MCM)  ab1 ch  \
# 0                      647.518                      153.039      MCM3     1.0
# 1                     1490.165                      332.591      MCM3     1.0
# 2                     1560.535                      380.034      MCM3     1.0
# 3                      930.763                      391.252      MCM3     1.0
# 4                     1653.035                      635.701      MCM3     1.0
#
#   ab2 (heterochromatin)  ab2 ch  DAPI ch  ... outer_DAPI_total  nuc_DAPI_het  \
# 0               HP1beta     2.0      3.0  ...       1781811545     942249454
# 1               HP1beta     2.0      3.0  ...       1768827952     733928606
# 2               HP1beta     2.0      3.0  ...       1844852860     744758812
# 3               HP1beta     2.0      3.0  ...       2026255216    1034361320
# 4               HP1beta     2.0      3.0  ...       2058830570    1055250742
#
#   inner_DAPI_het outer_DAPI_het  nuc_DAPI_eu inner_DAPI_eu outer_DAPI_eu  \
# 0      553948216      388301238   1841375979     447865672    1393510307
# 1      333304109      400624497   1888008341     519804886    1368203455
# 2      334218140      410540672   1937366665     503054477    1434312188
# 3      571961971      462399349   1946238103     382382236    1563855867
# 4      627925856      427324886   2059952844     428447160    1631505684
#
#          day  physical_age  mol_age_mod
# 0  d20200203      2.333333        0.225
# 1  d20200203      1.333333        0.166
# 2  d20200203      1.333333        0.166
# 3  d20200203      6.833333        0.684
# 4  d20200203      4.166667        0.376
#
# [5 rows x 47 columns]

# %%
Luc=data.loc[(data.group=='siLuc'),:].copy()

# %%
MCM3=data.loc[(data.group=='MCM3'),:].copy()

# %%
# %matplotlib notebook
sn.violinplot(x='group',y='nuc_mcm_total',data=data)
# Out:
# <img src="data:image/png;base64,..." width="640">
