# %%
import os
from os import listdir
from os.path import isfile, join

import pandas as pd
from itertools import islice
import numpy as np

from skimage.external import tifffile
from skimage.external.tifffile import imread

import matplotlib.pyplot as plt

import ipywidgets as widgets

import random


from scipy.ndimage.morphology import binary_erosion as br
from skimage import morphology as skmor

from scipy import ndimage
from PIL import Image, ImageDraw

import numpy.ma as ma

from skimage.measure import label, regionprops

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading'

# %%
orgfile=f'{bigDir}\\csv_signals_cell_data\signal_data_total_v3.csv'
newfile=f'{bigDir}\\new dataset\signals_new_v4.csv'

# %%
orgdata=pd.read_csv(orgfile)
newdata=pd.read_csv(newfile)

# %%
#orgdata=orgdata.drop(columns=['Unnamed: 0'])
orgdata=orgdata.drop(orgdata.iloc[:,39:94],axis=1)

# %%
orgdata.head()
# Out:
#    Unnamed: 0                  file original cell name  Amy_mod  \
# 0           0  20190625_cell-00.czi            7LE1(B)  1130/10
# 1           1  20190625_cell-01.czi           7L-E1(T)        0
# 2           2  20190625_cell-02.czi           7L-E2(B)        0
# 3           3  20190625_cell-03.czi           7L-E2(T)        0
# 4           4  20190625_cell-05.czi              7L-G2        0
#
#                          movie    x    y ab1 (heterochromatin)  ab1 ch  \
# 0  190619-cdc6-dhb-pcna002xy09  172  956                  HP1B       1
# 1  190619-cdc6-dhb-pcna002xy09  158  906                  HP1B       1
# 2  190619-cdc6-dhb-pcna002xy09  832  252                  HP1B       1
# 3  190619-cdc6-dhb-pcna002xy09  888  160                  HP1B       1
# 4  190619-cdc6-dhb-pcna002xy09  172  324                  HP1B       1
#
#   ab2 (MCM)  ...  nucleus_Otsu_erosion_outer_9x5_ch2  \
# 0      MCM3  ...                         847235311.0
# 1      MCM3  ...                         833657732.0
# 2      MCM3  ...                         935399926.0
# 3      MCM3  ...                         892877230.0
# 4      MCM3  ...                         961789578.0
#
#    nucleus_Otsu_erosion_outer_9x5_ch3  nucleus_Otsu_erosion_inner_13x8_volume  \
# 0                        6.867781e+09                                108435.0
# 1                        7.162939e+09                                120724.0
# 2                        7.431494e+09                                129190.0
# 3                        7.047608e+09                                128365.0
# 4                        1.280485e+10                                296285.0
#
#   nucleus_Otsu_erosion_inner_13x8_ch1 nucleus_Otsu_erosion_inner_13x8_ch2  \
# 0                        9.745788e+08                         425379714.0
# 1                        1.040932e+09                         468251524.0
# 2                        1.430971e+09                         633238899.0
# 3                        1.246361e+09                         588378714.0
# 4                        3.478092e+09                         900348539.0
#
#    nucleus_Otsu_erosion_inner_13x8_ch3 nucleus_Otsu_erosion_outer_13x8_volume  \
# 0                         3.213620e+09                               351463.0
# 1                         3.694105e+09                               315813.0
# 2                         4.411502e+09                               267850.0
# 3                         3.992517e+09                               293263.0
# 4                         9.504919e+09                               517987.0
#
#    nucleus_Otsu_erosion_outer_13x8_ch1 nucleus_Otsu_erosion_outer_13x8_ch2  \
# 0                         1.816693e+09                         882420324.0
# 1                         1.598153e+09                         802237729.0
# 2                         1.751315e+09                         844649484.0
# 3                         1.638840e+09                         816943925.0
# 4                         3.527791e+09                         937550088.0
#
#    nucleus_Otsu_erosion_outer_13x8_ch3
# 0                         7.137711e+09
# 1                         6.878110e+09
# 2                         6.739183e+09
# 3                         6.482227e+09
# 4                         1.211177e+10
#
# [5 rows x 79 columns]

# %%
newdata.head()
# Out:
#    Unnamed: 0                  file original cell name  \
# 0           0  20191203_cell-00.czi     20191125-01-17
# 1           1  20191203_cell-01.czi     20191125-01-20
# 2           2  20191203_cell-02.czi     20191125-01-23
# 3           3  20191203_cell-03.czi     20191125-01-25
# 4           4  20191203_cell-04.czi     20191125-01-32
#
#                         movie  last frame movie position x  \
# 0  191125pcnat_dhbr_cdc6vxy01                      678.301
# 1  191125pcnat_dhbr_cdc6vxy01                     1552.152
# 2  191125pcnat_dhbr_cdc6vxy01                     1131.436
# 3  191125pcnat_dhbr_cdc6vxy01                     1650.585
# 4  191125pcnat_dhbr_cdc6vxy01                     1466.687
#
#    last frame movie position y ab1 (MCM)  ab1 ch ab2 (heterochromatin)  \
# 0                      200.931      MCM3       1               HP1beta
# 1                      240.479      MCM3       1               HP1beta
# 2                      318.530      MCM3       1               HP1beta
# 3                      324.968      MCM3       1               HP1beta
# 4                      426.815      MCM3       1               HP1beta
#
#    ab2 ch  ...  nuc_DAPI_het  inner_DAPI_het outer_DAPI_het   nuc_DAPI_eu  \
# 0       2  ...  1.061172e+09    6.286906e+08    432481890.0  2.027203e+09
# 1       2  ...  1.812075e+09    1.086345e+09    725729186.0  4.615195e+09
# 2       2  ...  1.774444e+09    1.047682e+09    726762664.0  4.452523e+09
# 3       2  ...  1.229128e+09    5.907975e+08    638330656.0  2.382242e+09
# 4       2  ...  1.261960e+09    7.882228e+08    473737399.0  2.363135e+09
#
#    inner_DAPI_eu outer_DAPI_eu        day  decon      p_age mol_age_mod
# 0   3.354374e+08  1.691765e+09  d20191203  False   6.666667       0.444
# 1   1.007696e+09  3.607499e+09  d20191203  False        NaN       1.373
# 2   9.484609e+08  3.504062e+09  d20191203  False  16.166667       1.371
# 3   2.544991e+08  2.127743e+09  d20191203  False   1.500000       0.208
# 4   3.864823e+08  1.976653e+09  d20191203  False   5.166667       0.345
#
# [5 rows x 51 columns]

# %% [markdown]
# # 2020 dataset calculations

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200207_new data'

# %%
file=f'{bigDir}\\cellinfo_200203_v8.csv'
data=pd.read_csv(file)

# %% [markdown]
# # hp1b calculations

# %%
def calculate_hp1b_signals (name, data):
    
    ## if the given dataset is new, the hp1 channel is 1
    ## else, hp1 channel is 0 (for original dataset)
    if name=="new":
        channel=1
    else:
        channel=0
    i=0
    progBar=widgets.IntProgress(
        value=i,
        min=0,
        max=len(data),
        step=1,
        description='Progress:',
        orientation='horizontal'
    )
    display(progBar)
    for i,myCell in islice(data.iterrows(), i,None):
        
        ## opening cell image
        try:
            myImage=imread(myCell.path) 
        except:
            myCell.path=myCell.path.replace('.tif','.tiff')
            myImage=imread(myCell.path)
        
        ## setting arrays with names 
        
        ### for the column names
        pixels=['total','het','eu']
        components=['nuc','inner','outer']
        
        ### for image names
        dirs=['segmentation_nucleus_Otsu','erosion_nuc_mask','erosion_nuc_mask',
              'segmentation_20','segmentation_20_erosion','segmentation_20_erosion',
             'segmentation_20_eu','segmentation_20_eu_erosion','segmentation_20_eu_erosion',]

        files=['_nucleus.tif','_eroded_9^5_inner_mask_20.tif','_eroded_9^5_outer_mask_20.tif',
                   '_hetChrom.tif', '_hetChrom_inner.tif', '_hetChrom_outer.tif',
                   '_euChrom.tif', '_euChrom_inner.tif','_euChrom_outer.tif']

        ## making a dummy dataframe to store the signal calculations
        df=pd.DataFrame(columns=['nuc_hp1b_total','inner_hp1b_total','outer_hp1b_total',
                                 'nuc_hp1b_het','inner_hp1b_het','outer_hp1b_het',
                                'nuc_hp1b_eu','inner_hp1b_eu', 'outer_hp1b_eu'])

        ## signals calculated
        for k in range(len(pixels)):
            for j in range(len(components)):
                ## copying image every time new signal is calculated
                myIm=myImage.copy()
                myChannel=myIm[:,channel,:,:] 
                
                ## column name set up based on the component and the pixels
                currColName=f'{components[j]}_hp1b_{pixels[k]}'
                
                ## opening mask images
                ### the indexing is in such way so that the image opened matches up with the name being used for calculation
                direc=myCell.path.replace('data_tiff',dirs[(j)+(k*3)])
                try:
                    direc=direc.replace('.tif',files[(k*3)+(j)])
                    mask=imread(direc)  
                except:
                    direc=direc.replace('_nucleus.tiff',files[(k*3)+(j)])
                    mask=imread(direc)

                ## changing mask type to binary
                mask=mask.astype(bool)
                
                ## masking the image
                myChannel[~mask]=0
                
                ## calculating the signal
                df[f'{currColName}']=myChannel.sum(-1).sum(-1)

                ## calculating the volume of the pixels
                currColName=f'{components[j]}_vol_{pixels[k]}'
                df.loc[0,f'{currColName}']=np.sum(mask)
        
        ## saving the calculated signals to original/big dataframe
        for myMeasurement in df.columns:
            myString=f"data.loc[i,'{myMeasurement}']=np.sum(df.{myMeasurement})"
            exec(myString)
        

        progBar.value=progBar.value+1

# %%
## running the function for new dataset
calculate_hp1b_signals ("2020", data)
# Out:
# IntProgress(value=0, description='Progress:', max=146)

# %%
data.head()
# Out:
#    Unnamed: 0                  file        original cell name  \
# 0           0  20200203_cell_00.ciz  20200203-06-13-63X 16bit
# 1           1  20200203_cell_01.ciz  20200203-06-25-63X 16bit
# 2           2  20200203_cell_02.ciz  20200203-06-27-63X 16bit
# 3           3  20200203_cell_03.ciz  20200203-06-29-63X 16bit
# 4           4  20200203_cell_04.ciz  20200203-06-51-63X 16bit
#
#                 movie  last frame movie position x  \
# 0  20200203 simcmxy06                      647.518
# 1  20200203 simcmxy06                     1490.165
# 2  20200203 simcmxy06                     1560.535
# 3  20200203 simcmxy06                      930.763
# 4  20200203 simcmxy06                     1653.035
#
#    last frame movie position y ab1 (MCM)  ab1 ch ab2 (heterochromatin)  \
# 0                      153.039      MCM3     1.0               HP1beta
# 1                      332.591      MCM3     1.0               HP1beta
# 2                      380.034      MCM3     1.0               HP1beta
# 3                      391.252      MCM3     1.0               HP1beta
# 4                      635.701      MCM3     1.0               HP1beta
#
#    ab2 ch  ...  outer_DAPI_eu nuc_hp1b_total  inner_hp1b_total  \
# 0     2.0  ...     1504498329   9.427838e+08       349642876.0
# 1     2.0  ...     1350995701   6.651304e+08       192031110.0
# 2     2.0  ...     1474035399   6.169736e+08       178148056.0
# 3     2.0  ...     1640580552   1.153006e+09       394670302.0
# 4     2.0  ...     1682229016   9.681591e+08       337894665.0
#
#   outer_hp1b_total nuc_hp1b_het  inner_hp1b_het outer_hp1b_het  nuc_hp1b_eu  \
# 0      593140967.0  411417481.0     280431564.0    130985917.0  531366362.0
# 1      473099293.0  284459269.0     137123780.0    147335489.0  380671134.0
# 2      438825571.0  257712769.0     142562608.0    115150161.0  359260858.0
# 3      758335461.0  488267621.0     294355848.0    193911773.0  664738142.0
# 4      630264462.0  434549898.0     243834433.0    190715465.0  533609229.0
#
#    inner_hp1b_eu  outer_hp1b_eu
# 0     69211312.0    462155050.0
# 1     54907330.0    325763804.0
# 2     35585448.0    323675410.0
# 3    100314454.0    564423688.0
# 4     94060232.0    439548997.0
#
# [5 rows x 54 columns]

# %%
data.iloc[0]
# Out:
# Unnamed: 0                                                                     0
# file                                                        20200203_cell_00.ciz
# original cell name                                      20200203-06-13-63X 16bit
# movie                                                         20200203 simcmxy06
# last frame movie position x                                              647.518
# last frame movie position y                                              153.039
# ab1 (MCM)                                                                   MCM3
# ab1 ch                                                                         1
# ab2 (heterochromatin)                                                    HP1beta
# ab2 ch                                                                         2
# DAPI ch                                                                        3
# category                                                                 earlyG1
# molecular age                                                              0.225
# physical age [min]                                                         80min
# imaging core                                                                 HIC
# cell id for tracking                                                         NaN
# group                                                                      siLuc
# path                           Z:\CookLab\Liu\20190816_organizedData_MCM_load...
# nuc_vol_total                                                             229977
# inner_vol_total                                                            44163
# outer_vol_total                                                           185814
# nuc_mcm_total                                                         1424995771
# inner_mcm_total                                                        465859722
# outer_mcm_total                                                        959136049
# nuc_vol_het                                                                46005
# inner_vol_het                                                              29782
# outer_vol_het                                                              16223
# nuc_mcm_het                                                            438858192
# inner_mcm_het                                                          306436934
# outer_mcm_het                                                          132421258
# nuc_vol_eu                                                                183972
# inner_vol_eu                                                               14381
# outer_vol_eu                                                              169591
# nuc_mcm_eu                                                             986137579
# inner_mcm_eu                                                           159422788
# outer_mcm_eu                                                           826714791
# nuc_DAPI_total                                                        2783625433
# inner_DAPI_total                                                      1001813888
# outer_DAPI_total                                                      1781811545
# nuc_DAPI_het                                                           966421592
# inner_DAPI_het                                                         689108376
# outer_DAPI_het                                                         277313216
# nuc_DAPI_eu                                                           1817203841
# inner_DAPI_eu                                                          312705512
# outer_DAPI_eu                                                         1504498329
# nuc_hp1b_total                                                       9.42784e+08
# inner_hp1b_total                                                     3.49643e+08
# outer_hp1b_total                                                     5.93141e+08
# nuc_hp1b_het                                                         4.11417e+08
# inner_hp1b_het                                                       2.80432e+08
# outer_hp1b_het                                                       1.30986e+08
# nuc_hp1b_eu                                                          5.31366e+08
# inner_hp1b_eu                                                        6.92113e+07
# outer_hp1b_eu                                                        4.62155e+08
# Name: 0, dtype: object

# %%
## testing to see if the calculated signals have results as expected
print(
(np.sum(data['nuc_hp1b_het']+data['nuc_hp1b_eu']))/np.sum(data['nuc_hp1b_total']),
(np.mean(data['inner_hp1b_het'])+np.mean(data['inner_hp1b_eu']))/np.mean(data['inner_hp1b_total']),
(np.sum(data['outer_hp1b_het']+data['outer_hp1b_eu']))/np.sum(data['outer_hp1b_total']))
# Out:
# 1.0 1.0 1.0

# %%
print(
(np.sum(data['inner_hp1b_het']+data['outer_hp1b_het']))/np.sum(data['nuc_hp1b_het']),
(np.mean(data['outer_hp1b_eu'])+np.mean(data['inner_hp1b_eu']))/np.mean(data['nuc_hp1b_eu']),
(np.sum(data['nuc_hp1b_het'])+np.sum(data['nuc_hp1b_eu']))/np.sum(data['nuc_hp1b_total']),
(np.sum(data['inner_hp1b_total']+data['outer_hp1b_total'])/np.sum(data['nuc_hp1b_total'])))
# Out:
# 1.0 0.9999999999999999 1.0 1.0

# %%
## saving the dataset with calculated signals
data.to_csv(f'{bigDir}\\cellinfo_200203_v9.csv')

# %%
calculate_hp1b_signals ("new", newdata)
# Out:
# IntProgress(value=0, description='Progress:', max=276)

# %%
## testing to see if the calculated signals have results as expected
print(
(np.sum(newdata['nuc_hp1b_het']+newdata['nuc_hp1b_eu']))/np.sum(newdata['nuc_hp1b_total']),
(np.mean(newdata['inner_hp1b_het'])+np.mean(newdata['inner_hp1b_eu']))/np.mean(newdata['inner_hp1b_total']),
(np.sum(newdata['outer_hp1b_het']+newdata['outer_hp1b_eu']))/np.sum(newdata['outer_hp1b_total']))
# Out:
# 1.0000000020465323 0.9999999979825239 1.000000005647029

# %%
print(
(np.sum(newdata['inner_hp1b_het']+newdata['outer_hp1b_het']))/np.sum(newdata['nuc_hp1b_het']),
(np.mean(newdata['outer_hp1b_eu'])+np.mean(newdata['inner_hp1b_eu']))/np.mean(newdata['nuc_hp1b_eu']),
(np.sum(newdata['nuc_hp1b_het'])+np.sum(newdata['nuc_hp1b_eu']))/np.sum(newdata['nuc_hp1b_total']),
(np.sum(newdata['inner_hp1b_total']+newdata['outer_hp1b_total'])/np.sum(newdata['nuc_hp1b_total'])))
# Out:
# 1.0000000012705967 1.000000002098169 1.0000000020465323 0.9999999999025461

# %%
## saving the dataset with calculated signals
newdata.to_csv(newfile.replace('v4','v5'))
