# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200217_geminin'

# %%
file=f'{bigDir}\\200217_cellinfo_v8.csv'

# %%
data=pd.read_csv(file)

# %% [markdown]
# # data visualizations

# %%
data=data.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])

# %%
data.head()
# Out:
#    Unnamed: 0.1.1                  file     original cell name  \
# 0               0  20200217_cell_00.ciz  2020024-19-21-63X.czi
# 1               1  20200217_cell_01.ciz  2020024-19-27-63X.czi
# 2               2  20200217_cell_02.ciz  2020024-19-39-63X.czi
# 3               3  20200217_cell_03.ciz  2020024-19-49-63X.czi
# 4               4  20200217_cell_04.ciz  2020024-19-51-63X.czi
#
#                           movie         x        y ab1 (MCM)  ab1 ch  \
# 0  20200217pinducer gemininxy19  1312.741  235.893      MCM3       1
# 1  20200217pinducer gemininxy19  1323.444  397.761      MCM3       1
# 2  20200217pinducer gemininxy19  1772.297  584.995      MCM3       1
# 3  20200217pinducer gemininxy19   163.044  727.256      MCM3       1
# 4  20200217pinducer gemininxy19  1791.955  755.367      MCM3       1
#
#   ab2 (heterochromatin)  ab2 ch  ...  mol_age_mod  nuc_hp1b_total  \
# 0                   HP1       2  ...        0.948    2.693842e+09
# ...

# %%
data.group.unique()
# Out:
# array(['CTL', 'DOX_7h', 'TSA_7h'], dtype=object)

# %%
CTL=data.loc[(data.group=='CTL'),:].copy()

# %%
DOX=data.loc[(data.group=='DOX_7h'),:].copy()

# %%
TSA=data.loc[(data.group=='TSA_7h'),:].copy()

# %%
# %matplotlib notebook
sn.scatterplot(x='mol_age_mod',y='nuc_hp1b_total',data=CTL.loc[(['G1' in x for x in CTL.category]),:],color='blue',label='Control')
sn.scatterplot(x='mol_age_mod',y='nuc_hp1b_total',data=TSA.loc[(['G1' in x for x in TSA.category]),:],color='red',label='TSA')
plt.legend()
plt.xlabel('Molecular age [DHB]')
plt.ylabel('hp1 signal in nucleus')
plt.title('hp1 signal in nucleus VS molecular age for Control group',fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'hp1 signal in nucleus VS molecular age for Control group')
