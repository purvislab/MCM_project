# %%
import pandas as pd
import numpy as np

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200604_h3k9me3'

# %%
file=f'{bigDir}\\cellinfo_200604v6_10percent.csv'

# %%
data=pd.read_csv(file)

# %%
data.head()
# Out:
#    Unnamed: 0                  file         original_name       movie  \
# 0           0  20200604_cell_00.ciz  200604_09_15_63X.czi  200604xy09
# 1           1  20200604_cell_01.ciz  200604_09_46_63X.czi  200604xy09
# 2           2  20200604_cell_02.ciz  200604_09_51_63X.czi  200604xy09
# 3           3  20200604_cell_03.ciz  200604_09_53_63X.czi  200604xy09
# 4           4  20200604_cell_04.ciz  200604_09_58_63X.czi  200604xy09
#
#    last frame movie position x  last frame movie position y  \
# 0                      325.986                      135.825
# 1                     1103.256                      483.760
# 2                     1865.490                      559.814
# 3                      601.353                      583.042
# 4                     1577.064                      627.569
#
#   ab1 (Heterochromatin)  ab1 ch ab2 (MCM)  ab2 ch  ...      temp  \
# 0               H3K9Me3       1      MCM2       2  ...  0.100020
# 1               H3K9Me3       1      MCM2       2  ...  0.100014
# 2               H3K9Me3       1      MCM2       2  ...  0.100013
# 3               H3K9Me3       1      MCM2       2  ...  0.100003
# 4               H3K9Me3       1      MCM2       2  ...  0.100028
#
#   nuc_DAPI_total  inner_DAPI_total outer_DAPI_total nuc_DAPI_het  \
# 0   2.697250e+09       822467048.0     1.874783e+09  628945846.0
# 1   2.321032e+09       899578615.0     1.421453e+09  490617687.0
# 2   2.570708e+09       959263344.0     1.611445e+09  556729653.0
# 3   2.176022e+09       779353206.0     1.396669e+09  459623544.0
# 4   2.687250e+09       828964429.0     1.858286e+09  554604150.0
#
#    inner_DAPI_het  outer_DAPI_het   nuc_DAPI_eu  inner_DAPI_eu  outer_DAPI_eu
# 0     454611114.0     174334732.0  2.068304e+09    367855934.0   1.700448e+09
# 1     340295962.0     150321725.0  1.830414e+09    559282653.0   1.271131e+09
# 2     365812625.0     190917028.0  2.013979e+09    593450719.0   1.420528e+09
# 3     333437537.0     126186007.0  1.716398e+09    445915669.0   1.270483e+09
# 4     367070421.0     187533729.0  2.132646e+09    461894008.0   1.670752e+09
#
# [5 rows x 50 columns]

# %%
data.category.unique()
# Out:
# array(['earlyG1', 'lateG1', 'middleG1', 'G2'], dtype=object)

# %%
data=data.drop(columns=['Unnamed: 0'])

# %%
from itertools import islice

# %% [markdown]
# ## molecular age modification

# %%
data['mol_age_mod']=data['molecular age ']

# %%
i=0
for i,myCell in islice(data.iterrows(), i,None):
    try:
        data.loc[i,'physical_age']=((int(data.loc[i,'physical age [min]'][:-3]) / 60) + 1)
    except:
        data.loc[i,'physical_age']=None

# %%
data.loc[((data.physical_age<2) & (data.category=='earlyG1')),'mol_age_mod']=np.min(data['molecular age '])

# %%
data.loc[((data.physical_age<2) & (data.category=='earlyG1')),'mol_age_mod'].describe()
# Out:
# count    1.100000e+01
# mean     1.670000e-01
# std      2.911029e-17
# min      1.670000e-01
# 25%      1.670000e-01
# 50%      1.670000e-01
# 75%      1.670000e-01
# max      1.670000e-01
# Name: mol_age_mod, dtype: float64

# %%
data.to_csv(file)

# %% [markdown]
# ## molecular age modification for 50% 200604

# %%
file=f'{bigDir}\\cellinfo_200604v6_50percent.csv'

# %%
data=pd.read_csv(file)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                  file  \
# 0           0             0               0  20200604_cell_00.ciz
# 1           1             1               1  20200604_cell_01.ciz
# 2           2             2               2  20200604_cell_02.ciz
# 3           3             3               3  20200604_cell_03.ciz
# 4           4             4               4  20200604_cell_04.ciz
#
#           original_name       movie  last frame movie position x  \
# 0  200604_09_15_63X.czi  200604xy09                      325.986
# 1  200604_09_46_63X.czi  200604xy09                     1103.256
# 2  200604_09_51_63X.czi  200604xy09                     1865.490
# 3  200604_09_53_63X.czi  200604xy09                      601.353
# 4  200604_09_58_63X.czi  200604xy09                     1577.064
#
#    last frame movie position y ab1 (Heterochromatin)  ab1 ch  ...      temp  \
# 0                      135.825               H3K9Me3       1  ...  0.500012
# 1                      483.760               H3K9Me3       1  ...  0.500009
# 2                      559.814               H3K9Me3       1  ...  0.500041
# 3                      583.042               H3K9Me3       1  ...  0.500030
# 4                      627.569               H3K9Me3       1  ...  0.500053
#
#    nuc_DAPI_total  inner_DAPI_total outer_DAPI_total  nuc_DAPI_het  \
# 0    2.697250e+09       822467048.0     1.874783e+09  2.004453e+09
# 1    2.321032e+09       899578615.0     1.421453e+09  1.796049e+09
# 2    2.570708e+09       959263344.0     1.611445e+09  1.963019e+09
# 3    2.176022e+09       779353206.0     1.396669e+09  1.617514e+09
# 4    2.687250e+09       828964429.0     1.858286e+09  1.979640e+09
#
#   inner_DAPI_het outer_DAPI_het  nuc_DAPI_eu  inner_DAPI_eu outer_DAPI_eu
# 0    821272403.0   1.183180e+09  692797145.0      1194645.0   691602500.0
# 1    887957601.0   9.080914e+08  524982545.0     11621014.0   513361531.0
# 2    949256767.0   1.013762e+09  607689731.0     10006577.0   597683154.0
# 3    769429745.0   8.480846e+08  558507576.0      9923461.0   548584115.0
# 4    817325173.0   1.162315e+09  707610736.0     11639256.0   695971480.0
#
# [5 rows x 52 columns]

# %%
data['mol_age_mod']=data['molecular age ']

# %%
i=0
for i,myCell in islice(data.iterrows(), i,None):
    try:
        data.loc[i,'physical_age']=((int(data.loc[i,'physical age [min]'][:-3]) / 60) + 1)
    except:
        data.loc[i,'physical_age']=None

# %%
data.loc[((data.physical_age<2) & (data.category=='earlyG1')),'mol_age_mod']=np.min(data['molecular age '])

# %%
data.loc[((data.physical_age<2) & (data.category=='earlyG1')),'mol_age_mod'].describe()
# Out:
# count    1.100000e+01
# mean     1.670000e-01
# std      2.911029e-17
# min      1.670000e-01
# 25%      1.670000e-01
# 50%      1.670000e-01
# 75%      1.670000e-01
# max      1.670000e-01
# Name: mol_age_mod, dtype: float64

# %%
data.to_csv(file)

# %% [markdown]
# # molecular age modification 10% 200615

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200615_h3k9me3'

# %%
file=f'{bigDir}\\cellinfo_200615v6_10percent.csv'

# %%
data=pd.read_csv(file)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1.1                  file           original_name  \
# 0           0               0  20200615_cell_00.ciz  20200615_29_11_63x.czi
# 1           1               1  20200615_cell_01.ciz  20200615_29_18_63x.czi
# 2           2               2  20200615_cell_02.ciz  20200615_29_23_63x.czi
# 3           3               3  20200615_cell_03.ciz  20200615_29_24_63x.czi
# 4           4               4  20200615_cell_04.ciz  20200615_29_31_63x.czi
#
#         movie  last frame movie position x  last frame movie position y  \
# 0  200614xy29                     1781.995                      159.930
# 1  200614xy29                     1534.667                      302.703
# 2  200614xy29                      558.209                      366.997
# 3  200614xy29                     1147.608                      371.829
# 4  200614xy29                     1649.449                      469.520
#
#   ab1 (MCM)  ab1 ch ab2 (heterochromatin)  ...  Unnamed: 0.1.1.1  \
# 0   H3K9Me3       1                  MCM2  ...                 0
# 1   H3K9Me3       1                  MCM2  ...                 1
# 2   H3K9Me3       1                  MCM2  ...                 2
# 3   H3K9Me3       1                  MCM2  ...                 3
# 4   H3K9Me3       1                  MCM2  ...                 4
#
#    nuc_DAPI_total inner_DAPI_total  outer_DAPI_total nuc_DAPI_het  \
# 0    2.906368e+09     8.883452e+08      2.018023e+09  541422545.0
# 1    2.902209e+09     8.534346e+08      2.048775e+09  542010973.0
# 2    2.678936e+09     8.294657e+08      1.849470e+09  469187384.0
# 3    3.867871e+09     1.053710e+09      2.814161e+09  630177628.0
# 4    3.541353e+09     1.288501e+09      2.252852e+09  668026585.0
#
#   inner_DAPI_het  outer_DAPI_het   nuc_DAPI_eu  inner_DAPI_eu  outer_DAPI_eu
# 0    187973581.0     353448964.0  2.364945e+09    700371613.0   1.664574e+09
# 1    282857622.0     259153351.0  2.360198e+09    570576978.0   1.789622e+09
# 2    171664012.0     297523372.0  2.209749e+09    657801691.0   1.551947e+09
# 3    210546841.0     419630787.0  3.237694e+09    843162929.0   2.394531e+09
# 4    452944462.0     215082123.0  2.873326e+09    835556815.0   2.037770e+09
#
# [5 rows x 49 columns]

# %%
data['mol_age_mod']=data['molecular age ']

# %%
i=0
for i,myCell in islice(data.iterrows(), i,None):
    try:
        data.loc[i,'physical_age']=((int(data.loc[i,'physical age [min]'][:-3]) / 60) + 1)
    except:
        data.loc[i,'physical_age']=None

# %%
data.loc[((data.physical_age<2) & (data.category=='earlyG1')),'mol_age_mod']=np.min(data['molecular age '])

# %%
data.loc[((data.physical_age<2) & (data.category=='earlyG1')),'mol_age_mod'].describe()
# Out:
# count    1.300000e+01
# mean     1.100000e-01
# std      2.888892e-17
# min      1.100000e-01
# 25%      1.100000e-01
# 50%      1.100000e-01
# 75%      1.100000e-01
# max      1.100000e-01
# Name: mol_age_mod, dtype: float64

# %%
data.to_csv(file)

# %% [markdown]
# ## molecular age modification 50% 200615

# %%
file=f'{bigDir}\\cellinfo_200615v6_50percent.csv'

# %%
data=pd.read_csv(file)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                  file  \
# 0           0             0               0  20200615_cell_00.ciz
# 1           1             1               1  20200615_cell_01.ciz
# 2           2             2               2  20200615_cell_02.ciz
# 3           3             3               3  20200615_cell_03.ciz
# 4           4             4               4  20200615_cell_04.ciz
#
#             original_name       movie  last frame movie position x  \
# 0  20200615_29_11_63x.czi  200614xy29                     1781.995
# 1  20200615_29_18_63x.czi  200614xy29                     1534.667
# 2  20200615_29_23_63x.czi  200614xy29                      558.209
# 3  20200615_29_24_63x.czi  200614xy29                     1147.608
# 4  20200615_29_31_63x.czi  200614xy29                     1649.449
#
#    last frame movie position y ab1 (MCM)  ab1 ch  ... Unnamed: 0.1.1.1  \
# 0                      159.930   H3K9Me3       1  ...                0
# 1                      302.703   H3K9Me3       1  ...                1
# 2                      366.997   H3K9Me3       1  ...                2
# 3                      371.829   H3K9Me3       1  ...                3
# 4                      469.520   H3K9Me3       1  ...                4
#
#    nuc_DAPI_total  inner_DAPI_total outer_DAPI_total  nuc_DAPI_het  \
# 0    2.906368e+09      8.883452e+08     2.018023e+09  2.195022e+09
# 1    2.902209e+09      8.534346e+08     2.048775e+09  2.158831e+09
# 2    2.678936e+09      8.294657e+08     1.849470e+09  1.975732e+09
# 3    3.867871e+09      1.053710e+09     2.814161e+09  2.869494e+09
# 4    3.541353e+09      1.288501e+09     2.252852e+09  2.582704e+09
#
#   inner_DAPI_het outer_DAPI_het  nuc_DAPI_eu inner_DAPI_eu  outer_DAPI_eu
# 0   8.570760e+08   1.337946e+09  711346064.0    31269198.0    680076866.0
# 1   8.308982e+08   1.327933e+09  743378611.0    22536363.0    720842248.0
# 2   8.043897e+08   1.171342e+09  703204338.0    25076034.0    678128304.0
# 3   1.028024e+09   1.841470e+09  998376893.0    25685695.0    972691198.0
# 4   1.268266e+09   1.314439e+09  958648758.0    20235773.0    938412985.0
#
# [5 rows x 50 columns]

# %%
data['mol_age_mod']=data['molecular age ']

# %%
i=0
for i,myCell in islice(data.iterrows(), i,None):
    try:
        data.loc[i,'physical_age']=((int(data.loc[i,'physical age [min]'][:-3]) / 60) + 1)
    except:
        data.loc[i,'physical_age']=None

# %%
data.loc[((data.physical_age<2) & (data.category=='earlyG1')),'mol_age_mod']=np.min(data['molecular age '])

# %%
data.loc[((data.physical_age<2) & (data.category=='earlyG1')),'mol_age_mod'].describe()
# Out:
# count    1.300000e+01
# mean     1.100000e-01
# std      2.888892e-17
# min      1.100000e-01
# 25%      1.100000e-01
# 50%      1.100000e-01
# 75%      1.100000e-01
# max      1.100000e-01
# Name: mol_age_mod, dtype: float64

# %%
data=data.drop(columns=['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'])

# %%
data.to_csv(file)
