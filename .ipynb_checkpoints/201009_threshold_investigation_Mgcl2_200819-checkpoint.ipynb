# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as stats

# %%
import os
from os import listdir
from os.path import isfile, join
from itertools import islice
from skimage.external import tifffile
from skimage.external.tifffile import imread
import ipywidgets as widgets

# %%
bigDir = r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200829_h3k9me3'

# %%
file = f"{bigDir}\\200819_cellinfo_v6_20.csv"
data = pd.read_csv(file)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                   file   original cell name  \
# 0           0             0  20200819_cell2_01.ciz   20200818xy19_6.czi
# 1           1             1  20200819_cell2_02.ciz   20200818xy19_8.czi
# 2           2             2  20200819_cell2_03.ciz  20200818xy19_22.czi
# 3           3             3  20200819_cell2_04.ciz  20200818xy19_25.czi
# 4           4             4  20200819_cell2_05.ciz  20200818xy19_27.czi
#
#         movie         x        y ab1 (MCM)  ab1 ch ab2 (heterochromatin)  ...  \
# 0  200819xy19  1526.899   85.295   H3k9me3       1                  MCM2  ...
# 1  200819xy19  1112.568   94.321   H3k9me3       1                  MCM2  ...
# 2  200819xy19  1412.269  290.826   H3k9me3       1                  MCM2  ...
# 3  200819xy19  1764.520  336.100   H3k9me3       1                  MCM2  ...
# 4  200819xy19   188.411  367.506   H3k9me3       1                  MCM2  ...
#
#    outer_DAPI_eu  nuc_h3k9me3_total  inner_h3k9me3_total outer_h3k9me3_total  \
# 0   8.056507e+08       1.556340e+09          507823395.0        1.048516e+09
# 1   8.659832e+08       1.519626e+09          374000205.0        1.145626e+09
# 2   9.180782e+08       1.031510e+09          329936617.0        7.015734e+08
# 3   1.037998e+09       1.255900e+09          244456731.0        1.011443e+09
# 4   1.771447e+09       1.834223e+09          612423518.0        1.221800e+09
#
#    nuc_h3k9me3_het  inner_h3k9me3_het  outer_h3k9me3_het nuc_h3k9me3_eu  \
# 0      658184045.0        359266210.0        298917835.0   8.981557e+08
# 1      603664320.0        217624195.0        386040125.0   9.159621e+08
# 2      457591039.0        256291447.0        201299592.0   5.739190e+08
# 3      579531132.0        203671825.0        375859307.0   6.763688e+08
# 4      716771839.0        397258618.0        319513221.0   1.117451e+09
#
#   inner_h3k9me3_eu  outer_h3k9me3_eu
# 0      148557185.0       749598468.0
# 1      156376010.0       759586103.0
# 2       73645170.0       500273850.0
# 3       40784906.0       635583861.0
# 4      215164900.0       902286564.0
#
# [5 rows x 61 columns]

# %%
file2 = f"{bigDir}\\200819_cellinfo_v6_30.csv"
data2 = pd.read_csv(file2)

# %%
file3 = f"{bigDir}\\200819_cellinfo_v6_40.csv"
data3 = pd.read_csv(file3)

# %% [markdown]
# # Questions to answer
# 1. Do the cells change the volume of nuclei in MgCL2? - answered by Liu
# 2. What is the distribution of heterochromatin intensity threshold in ctrl population of cells?
# 3. Compare total heterochromatin marker signal in cells in ctl and MgCl2 groups. which group has more signal?
# 4. Find thresdhold for heterochromatin volume in MgCl2 treated cells that will match the intensity threshold from ctl cells.

# %%
myHetSignalFinal=[]
myChannelFinal=[]
myHetSignal_1Final=[]

# %%
data_test=data

# %%
hp1=0

## calculating 20% brightest pixles
het_percentile=20

# Progress Bar
i=0

progBar=widgets.IntProgress(
    value=i,
    min=0,
    max=len(data_test),
    step=1,
    description='Progress:',
    orientation='horizontal'
)
display(progBar)
for i,myCell in islice(data_test.iterrows(), i,None):
    if myCell.group=='CTL':
        #%matplotlib notebook
        ## create folder to store this percentile data if it doesn't exist yet
        newSegFolder = os.path.dirname(myCell.path).replace('data_tiff',f'segmentation_{het_percentile}')
        newResultsFolder = os.path.dirname(myCell.path).replace('data_tiff', 'results')

        try:
            os.mkdir(newSegFolder)
        except:
            pass

        try:
            os.mkdir(newResultsFolder)
        except:
            pass


        ## open tiff image of a cell
        try:
            myImage=imread(myCell.path)    
        except:
            myCell.path=myCell.path.replace('.tif','.tiff')
            myImage=imread(myCell.path)    
        #print(myImage.shape)
        ## opening the channel according to the dataset
        myChannel = myImage[:, hp1, :, :] 

        ## open nucleus mask
        ### if the file is not found in the directory, trying to change the file extension 
        #### this is because there are some file files that are saved as tiff image 
        nucleusMaskPath=myCell.path
        nucleusMaskPath=nucleusMaskPath.replace('data_tiff','segmentation_nucleus_Otsu')
        nucleusMaskPath=nucleusMaskPath.replace('.tif','_nucleus.tif')
        try:
            nucleusMask=imread(nucleusMaskPath)
        except:
            nucleusMaskPath=nucleusMaskPath.replace('.tiff','.tif')
            nucleusMask=imread(nucleusMaskPath)


        ## make nucleus mask binary
        nucleusMask = nucleusMask.astype(bool)

        ## clean image
        myNucleus = myChannel[nucleusMask]
        #sns.distplot(myNucleus)
            #myChannelFinal.extend(myNucleus)
        #print(myNucleus.shape)
        #sns.distplot(myNucleus)

        ## find threshold
        myPercentile = np.nanpercentile(myNucleus, (100-het_percentile)) 
        #plt.axvline(myPercentile, 0,1)


        ## threshold
        myHetMask=np.zeros(myChannel.shape).astype('bool')
        myHetMask[myChannel >= myPercentile] = 1

        ## clean from elements outside the nucleus
        cleanNucleusMask=~nucleusMask
        myHetMask[cleanNucleusMask]=0
        cleanHetMask = ~myHetMask

        ## save segmentation mask
        maskFile = os.path.basename(myCell.path).replace('.tif',f'_hetChrom.tif')
        tifffile.imsave(os.path.join(newSegFolder,maskFile), myHetMask.astype('uint8'))
        
        myChannel[~myHetMask]=0
        myHetSignal_1=myChannel.ravel()
        myHetSignal_1=[i for i in myHetSignal_1 if i !=0]
        #sns.distplot(myHetSignal_1)
        #myHetSignal_1Final.extend(myHetSignal_1)
        
        data_test.loc[i,'hetThreshold'] = min(myHetSignal_1)
        data_test.loc[i,'volThreshold'] = myPercentile
        
        #sns.distplot(myHetSignal)
        progBar.value=progBar.value+1
# Out:
# IntProgress(value=0, description='Progress:', max=113)

# %%
# %matplotlib notebook
hp1=0

## calculating 20% brightest pixles
het_percentile=20

# Progress Bar
i=60

progBar=widgets.IntProgress(
    value=i,
    min=0,
    max=len(data),
    step=1,
    description='Progress:',
    orientation='horizontal'
)
display(progBar)
for i,myCell in islice(data.iterrows(), i,None):
    if myCell.group=='Mgcl2':
        ## create folder to store this percentile data if it doesn't exist yet
        newSegFolder = os.path.dirname(myCell.path).replace('data_tiff',f'segmentation_{het_percentile}')
        newResultsFolder = os.path.dirname(myCell.path).replace('data_tiff', 'results')

        try:
            os.mkdir(newSegFolder)
        except:
            pass

        try:
            os.mkdir(newResultsFolder)
        except:
            pass


        ## open tiff image of a cell
        try:
            myImage=imread(myCell.path)    
        except:
            myCell.path=myCell.path.replace('.tif','.tiff')
            myImage=imread(myCell.path)    
        #print(myImage.shape)
        ## opening the channel according to the dataset
        myChannel = myImage[:, hp1, :, :] 

        ## open nucleus mask
        ### if the file is not found in the directory, trying to change the file extension 
        #### this is because there are some file files that are saved as tiff image 
        nucleusMaskPath=myCell.path
        nucleusMaskPath=nucleusMaskPath.replace('data_tiff','segmentation_nucleus_Otsu')
        nucleusMaskPath=nucleusMaskPath.replace('.tif','_nucleus.tif')
        try:
            nucleusMask=imread(nucleusMaskPath)
        except:
            nucleusMaskPath=nucleusMaskPath.replace('.tiff','.tif')
            nucleusMask=imread(nucleusMaskPath)


        ## make nucleus mask binary
        nucleusMask = nucleusMask.astype(bool)

        ## clean image
        myNucleus = myChannel[nucleusMask]
        #myChannelFinal_mgcl.extend(myNucleus)
        #print(myNucleus.shape)
        #sns.distplot(myNucleus)

        ## find threshold
        myPercentile = np.nanpercentile(myNucleus, (100-het_percentile)) 
        #plt.axvline(myPercentile, 0,1)


        ## threshold
        myHetMask=np.zeros(myChannel.shape).astype('bool')
        myHetMask[myChannel >= myPercentile] = 1

        ## clean from elements outside the nucleus
        cleanNucleusMask=~nucleusMask
        myHetMask[cleanNucleusMask]=0
        cleanHetMask = ~myHetMask

        ## save segmentation mask
        maskFile = os.path.basename(myCell.path).replace('.tif',f'_hetChrom.tif')
        tifffile.imsave(os.path.join(newSegFolder,maskFile), myHetMask.astype('uint8'))
        
        myChannel[~myHetMask]=0
        myHetSignal_1=myChannel.ravel()
        myHetSignal_1=[i for i in myHetSignal_1 if i !=0]
        
        data_test.loc[i,'hetThreshold'] = min(myHetSignal_1)
        data_test.loc[i,'volThreshold'] = myPercentile
        
        #sns.distplot(myHetSignal)
        progBar.value=progBar.value+1
# Out:
# IntProgress(value=60, description='Progress:', max=113)

# %%
data_test.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                   file   original cell name  \
# 0           0             0  20200819_cell2_01.ciz   20200818xy19_6.czi
# 1           1             1  20200819_cell2_02.ciz   20200818xy19_8.czi
# 2           2             2  20200819_cell2_03.ciz  20200818xy19_22.czi
# 3           3             3  20200819_cell2_04.ciz  20200818xy19_25.czi
# 4           4             4  20200819_cell2_05.ciz  20200818xy19_27.czi
#
#         movie         x        y ab1 (MCM)  ab1 ch ab2 (heterochromatin)  ...  \
# 0  200819xy19  1526.899   85.295   H3k9me3       1                  MCM2  ...
# 1  200819xy19  1112.568   94.321   H3k9me3       1                  MCM2  ...
# 2  200819xy19  1412.269  290.826   H3k9me3       1                  MCM2  ...
# 3  200819xy19  1764.520  336.100   H3k9me3       1                  MCM2  ...
# 4  200819xy19   188.411  367.506   H3k9me3       1                  MCM2  ...
#
#    inner_h3k9me3_total  outer_h3k9me3_total  nuc_h3k9me3_het  \
# 0          507823395.0         1.048516e+09      658184045.0
# 1          374000205.0         1.145626e+09      603664320.0
# 2          329936617.0         7.015734e+08      457591039.0
# 3          244456731.0         1.011443e+09      579531132.0
# 4          612423518.0         1.221800e+09      716771839.0
#
#   inner_h3k9me3_het  outer_h3k9me3_het  nuc_h3k9me3_eu  inner_h3k9me3_eu  \
# 0       359266210.0        298917835.0    8.981557e+08       148557185.0
# 1       217624195.0        386040125.0    9.159621e+08       156376010.0
# 2       256291447.0        201299592.0    5.739190e+08        73645170.0
# 3       203671825.0        375859307.0    6.763688e+08        40784906.0
# 4       397258618.0        319513221.0    1.117451e+09       215164900.0
#
#   outer_h3k9me3_eu hetThreshold  volThreshold
# 0      749598468.0       9772.0        9771.2
# 1      759586103.0      13648.0       13648.0
# 2      500273850.0       6497.0        6497.0
# 3      635583861.0      10715.0       10715.0
# 4      902286564.0       8398.0        8398.0
#
# [5 rows x 63 columns]

# %%
hetThresholdCTL=data_test.loc[(['CTL' in x for x in data_test.group]), 'hetThreshold']

# %%
volThresholdCTL=data_test.loc[(['CTL' in x for x in data_test.group]), 'volThreshold']

# %%
hetThresholdMGCL_20=data_test.loc[(['Mgcl2' in x for x in data_test.group]), 'hetThreshold']
volThresholdMGCL_20=data_test.loc[(['Mgcl2' in x for x in data_test.group]), 'volThreshold']

# %%
np.mean(hetThresholdCTL)
# Out:
# 10234.533333333333

# %%
np.mean(volThresholdCTL)
# Out:
# 10234.476666666667

# %%
np.mean(hetThresholdMGCL_20)
# Out:
# 12755.018867924528

# %%
np.mean(volThresholdMGCL_20)
# Out:
# 12754.958490566041

# %%
(np.mean(hetThresholdMGCL_20)-np.mean(hetThresholdCTL))/np.mean(hetThresholdCTL)
# Out:
# 0.24627263916197398

# %%
# %matplotlib notebook
hp1=0

## calculating 20% brightest pixles
het_percentile=30

# Progress Bar
i=60

progBar=widgets.IntProgress(
    value=i,
    min=0,
    max=len(data),
    step=1,
    description='Progress:',
    orientation='horizontal'
)
display(progBar)
for i,myCell in islice(data2.iterrows(), i,None):
    if myCell.group=='Mgcl2':
        ## create folder to store this percentile data if it doesn't exist yet
        newSegFolder = os.path.dirname(myCell.path).replace('data_tiff',f'segmentation_{het_percentile}')
        newResultsFolder = os.path.dirname(myCell.path).replace('data_tiff', 'results')

        try:
            os.mkdir(newSegFolder)
        except:
            pass

        try:
            os.mkdir(newResultsFolder)
        except:
            pass


        ## open tiff image of a cell
        try:
            myImage=imread(myCell.path)    
        except:
            myCell.path=myCell.path.replace('.tif','.tiff')
            myImage=imread(myCell.path)    
        #print(myImage.shape)
        ## opening the channel according to the dataset
        myChannel = myImage[:, hp1, :, :] 

        ## open nucleus mask
        ### if the file is not found in the directory, trying to change the file extension 
        #### this is because there are some file files that are saved as tiff image 
        nucleusMaskPath=myCell.path
        nucleusMaskPath=nucleusMaskPath.replace('data_tiff','segmentation_nucleus_Otsu')
        nucleusMaskPath=nucleusMaskPath.replace('.tif','_nucleus.tif')
        try:
            nucleusMask=imread(nucleusMaskPath)
        except:
            nucleusMaskPath=nucleusMaskPath.replace('.tiff','.tif')
            nucleusMask=imread(nucleusMaskPath)


        ## make nucleus mask binary
        nucleusMask = nucleusMask.astype(bool)

        ## clean image
        myNucleus = myChannel[nucleusMask]
        #myChannelFinal_mgcl.extend(myNucleus)
        #print(myNucleus.shape)
        #sns.distplot(myNucleus)

        ## find threshold
        myPercentile = np.nanpercentile(myNucleus, (100-het_percentile)) 
        #plt.axvline(myPercentile, 0,1)


        ## threshold
        myHetMask=np.zeros(myChannel.shape).astype('bool')
        myHetMask[myChannel >= myPercentile] = 1

        ## clean from elements outside the nucleus
        cleanNucleusMask=~nucleusMask
        myHetMask[cleanNucleusMask]=0
        cleanHetMask = ~myHetMask

        ## save segmentation mask
        maskFile = os.path.basename(myCell.path).replace('.tif',f'_hetChrom.tif')
        tifffile.imsave(os.path.join(newSegFolder,maskFile), myHetMask.astype('uint8'))
        
        myChannel[~myHetMask]=0
        myHetSignal_1=myChannel.ravel()
        myHetSignal_1=[i for i in myHetSignal_1 if i !=0]
        
        data_test.loc[i,'hetThreshold'] = min(myHetSignal_1)
        data_test.loc[i,'volThreshold'] = myPercentile
        
        #sns.distplot(myHetSignal)
        progBar.value=progBar.value+1
# Out:
# IntProgress(value=60, description='Progress:', max=113)

# %%
hetThresholdMGCL_30=data_test.loc[(['Mgcl2' in x for x in data_test.group]), 'hetThreshold']
volThresholdMGCL_30=data_test.loc[(['Mgcl2' in x for x in data_test.group]), 'volThreshold']

# %%
np.mean(hetThresholdMGCL_30)
# Out:
# 9888.943396226416

# %%
np.mean(volThresholdMGCL_30)
# Out:
# 9888.90754716981

# %%
(np.mean(hetThresholdMGCL_30)-np.mean(hetThresholdCTL))/np.mean(hetThresholdCTL)
# Out:
# -0.033767043972718236

# %%
data.loc[(['CTL' in x for x in data.group]), 'hetThreshold']=hetThresholdCTL

# %%
data.loc[(['Mgcl2' in x for x in data.group]), 'hetThreshold']=hetThresholdMGCL_20

# %%
data2.loc[(['CTL' in x for x in data2.group]), 'hetThreshold']=hetThresholdCTL

# %%
data2.loc[(['Mgcl2' in x for x in data2.group]), 'hetThreshold']=hetThresholdMGCL_30

# %%
np.mean(data.loc[(['CTL' in x for x in data.group]), 'hetThreshold'])
# Out:
# 10234.533333333333

# %%
np.mean(data.loc[(['Mgcl2' in x for x in data.group]), 'hetThreshold'])
# Out:
# 12755.018867924528

# %%
np.mean(data2.loc[(['CTL' in x for x in data2.group]), 'hetThreshold'])
# Out:
# 10234.533333333333

# %%
np.mean(data2.loc[(['Mgcl2' in x for x in data2.group]), 'hetThreshold'])
# Out:
# 9888.943396226416

# %%
data.to_csv(file.replace('v6','v7'))

# %%
data2.to_csv(file2.replace('v6','v7'))

# %%
file_new = f"{bigDir}\\200819_cellinfo_v7_20.csv"
data_new = pd.read_csv(file_new)

# %% [markdown]
# # #2: What is the distribution of heterochromatin intensity threshold in CTL population of cells?

# %%
# %matplotlib notebook
plt.title("Distribution of heterochromatin intensity threshold in CTL group (20% volume)",fontsize=10)
sns.distplot(data_new.loc[(['G1' in x for x in data_new.category] and ['CTL' in x for x in data_new.group]), 'hetThreshold'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
sns.boxplot(x='group', y = 'hetThreshold', data=data_new.loc[(['G1' in x for x in data_new.category]),:])
plt.title("Heterochromatin intensity threshold in CTL and MgCl2 (20% volume)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Heterochromatin intensity threshold in CTL and MgCl2 (20% volume)')

# %%
file_new2 = f"{bigDir}\\200819_cellinfo_v7_30.csv"
data_new2 = pd.read_csv(file_new2)

# %%
# %matplotlib notebook
sns.boxplot(x='group', y = 'hetThreshold', data=data_new2.loc[(['G1' in x for x in data_new2.category]),:])
plt.title("Heterochromatin intensity threshold in CTL and MgCl2 (30% volume)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Heterochromatin intensity threshold in CTL and MgCl2 (30% volume)')

# %% [markdown]
# # #3. Compare the total heterochromatin marker signal in CTL and MgCl2 groups. which group has more signal?

# %%
# %matplotlib notebook
sns.boxplot(x='group', y='nuc_h3k9me3_het', data=data_new.loc[(['G1' in x for x in data_new.category]),:])
plt.title("Heterochromatin marker Signal in CTL and MgCl2 (20% volume)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Heterochromatin marker Signal in CTL and MgCl2 (20% volume)')

# %%
# %matplotlib notebook
sns.boxplot(x='group', y='nuc_h3k9me3_het', data=data_new2.loc[(['G1' in x for x in data_new2.category]),:])
plt.title("Heterochromatin marker Signal in CTL and MgCl2 (30% volume)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Heterochromatin marker Signal in CTL and MgCl2 (30% volume)')

# %% [markdown]
# # #4: Find threshold for heterochromatin volume in MgCl2 treated cells that will match the intensity threshold from CTL cells.
