# %%
import numpy as np
import pandas as pd
import scipy
from scipy import stats
import matplotlib.pyplot as plt
from skimage.external import tifffile
import seaborn as sns
from skimage.external.tifffile import imread
import os
from os import listdir
from os.path import isfile, join

# %%
bigDir=r'Z:\CookLab\Liu\DNAdamageAnalysis\20210110'

# %%
imageFolder=f'{bigDir}\\data_tiff'

# %%
dataFile=f'{bigDir}\\cellinfo_20210110_v7.csv'
data=pd.read_csv(dataFile)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                  file   original cell name  \
# 0           0             0  20210110_cell_00.ciz  20210110xy01_S1.czi
# 1           1             1  20210110_cell_02.ciz  20210110xy01_S3.czi
# 2           2             2  20210110_cell_03.ciz  20210110xy01_S4.czi
# 3           3             3  20210110_cell_04.ciz  20210110xy01_S5.czi
# 4           4             4  20210110_cell_05.ciz  20210110xy01_S6.czi
#
#           movie  ID   x   y  molecular_age category  ... nuc_DAPI_total  \
# 0  20210110xy01 NaN NaN NaN            NaN    LateS  ...     6817731168
# 1  20210110xy01 NaN NaN NaN            NaN    LateS  ...     6516142543
# 2  20210110xy01 NaN NaN NaN            NaN    LateS  ...     6386977448
# 3  20210110xy01 NaN NaN NaN            NaN    LateS  ...     6825566649
# 4  20210110xy01 NaN NaN NaN            NaN    LateS  ...     6486096125
#
#   inner_DAPI_total  outer_DAPI_total nuc_DAPI_het  inner_DAPI_het  \
# 0       2354269459        4463461709   2330318547      1321232918
# 1       2162395235        4353747308   2248349916      1239642048
# 2       2441791517        3945185931   2222657732      1285322397
# 3       2248947872        4576618777   2257515934      1292296373
# 4       2365441587        4120654538   2302812319      1516125809
#
#    outer_DAPI_het nuc_DAPI_eu inner_DAPI_eu outer_DAPI_eu        day
# 0      1009085629  4487412621    1033036541    3454376080  d20210110
# 1      1008707868  4267792627     922753187    3345039440  d20210110
# 2       937335335  4164319716    1156469120    3007850596  d20210110
# 3       965219561  4568050715     956651499    3611399216  d20210110
# 4       786686510  4183283806     849315778    3333968028  d20210110
#
# [5 rows x 47 columns]

# %% [markdown]
# for i, row in data.iterrows():
#     newSegFolder = os.path.dirname(row.path).replace('data_tiff',f'masked_image')
#
#     try:
#         os.mkdir(newSegFolder)
#     except:
#         pass
#
#     img=imread(row.path)
#     ch=img[:,1,:,:]
#
#     maskpath=row.path.replace('data_tiff','segmentation_nucleus_Otsu')
#     maskpath=maskpath.replace('.tif','_nucleus.tif')
#     nucMask=imread(maskpath)
#     nucMask=nucMask.astype(bool)
#     ch[~nucMask]=0
#
#     maskFile = os.path.basename(row.path).replace('.tif',f'_masked.tif')
#     tifffile.imsave(os.path.join(newSegFolder,maskFile), ch)

# %%
data.group.unique()
# Out:
# array(['CTL', 'APH', 'APH+DOX', 'DOX'], dtype=object)

# %%
#for i, row in data.iterrows():
#    data.loc[i,'path']=data.loc[i,'path'].replace('D:\\POST_DOC\\python_practice\\cyclinE_53bp1','Z:\\CookLab\\Liu\\DNAdamageAnalysis')

# %%
#data.to_csv(dataFile)

# %%
CTL=data.loc[data.group=='CTL',:]

# %%
APH=data.loc[data.group=='APH',:]

# %%
APHDOX=data.loc[data.group=='APH+DOX',:]

# %%
DOX=data.loc[data.group=='DOX',:]

# %%
data.category.unique()
# Out:
# array(['LateS'], dtype=object)

# %%
img=imread(CTL.path[0])

# %%
ch=img[:,1,:,:]

# %%
ch.shape
# Out:
# (35, 380, 380)

# %%
resultsDir=f'{bigDir}\\foci-results'

# %%
path1=CTL.path[0].replace('data_tiff','foci-results')
path1=path1.replace('20210110_cell_','Results-')
path1=path1.replace('.tif','.csv')
path1
# Out:
# 'Z:\\CookLab\\Liu\\DNAdamageAnalysis\\20210110\\foci-results\\Results-00.csv'

# %%
testDF=pd.read_csv(path1)

# %%
testDF.head()
# Out:
#                     ImageTitle  FocusNO    CoreX    CoreY   CoreZ  Volume  \
# 0  20210110_cell_00_masked.tif        1  158.396  143.960  13.551      61
# 1  20210110_cell_00_masked.tif        2  162.845  142.960  13.507      39
# 2  20210110_cell_00_masked.tif        3  129.217  180.560  14.931      48
# 3  20210110_cell_00_masked.tif        4  127.660  168.940  11.551      35
# 4  20210110_cell_00_masked.tif        5  115.590  193.111  15.945      57
#
#    AreaXY  AreaXZ  AreaYZ  Intensity  Background     MinI   MaxI  Range
# 0      23      17      23  24441.342        4758  20065.0  35372  14936
# 1      15      12      17  19955.719        4404  16348.5  28293  11690
# 2      20      16      20  14463.521        4485  11869.5  19254   7345
# 3      17      19      12  14108.201        3418  11278.0  19138   7770
# 4      28      17      21  13572.490        3877  11425.0  18973   7542

# %%
import math

# %%
x=math.floor(testDF['CoreX'])
y=math.floor(testDF['CoreY'])
z=math.floor(testDF['CoreZ'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-2ddc58f5a959> in <module>
# ----> 1 x=math.floor(testDF['CoreX'])
#       2 y=math.floor(testDF['CoreY'])
#       3 z=math.floor(testDF['CoreZ'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#      91             return converter(self.iloc[0])
#      92         raise TypeError("cannot convert the series to "
# ---> 93                         "{0}".format(str(converter)))
#      94
#      95     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'float'>

# %%
ch[z,x,y]=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-2edbecf973bf> in <module>
# ----> 1 ch[z,x,y]=1
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
fociMask=np.zeros(ch.shape)

# %%
fociMask[math.floor(z[0]),math.floor(y[0]),math.floor(x[0])]=1

# %%
# %matplotlib notebook
plt.imshow(fociMask[(math.floor(z[0]))])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import skimage

# %%
ch1=skimage.img_as_float(ch)

# %%
ch1[z[0],y[0],x[0]] = 0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-09d38f6048bc> in <module>
# ----> 1 ch1[z[0],y[0],x[0]] = 0
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
ch1
# Out:
# array([[[0.01351949, 0.01536584, 0.0153048 , ..., 0.01773098,
#          0.01550317, 0.016907  ],
#         [0.01617456, 0.01811246, 0.01641871, ..., 0.01606775,
#          0.01582361, 0.01567102],
#         [0.01574731, 0.01579309, 0.01593042, ..., 0.01774624,
#          0.0202182 , 0.01768521],
#         ...,
#         [0.01707485, 0.01680018, 0.01608301, ..., 0.01535058,
#          0.01826505, 0.01493858],
#         [0.01559472, 0.01791409, 0.0137026 , ..., 0.01550317,
#          0.01347372, 0.01507591],
#         [0.01849393, 0.01557946, 0.01579309, ..., 0.01557946,
#          0.01402304, 0.01806668]],
#
#        [[0.01445029, 0.01329061, 0.01339742, ..., 0.01702907,
#          0.01457237, 0.01547265],
#         [0.01474022, 0.01425193, 0.01441978, ..., 0.01542687,
#          0.01660182, 0.01568627],
#         [0.01570153, 0.01353475, 0.01565576, ..., 0.01873808,
#          0.01533532, 0.01596094],
#         ...,
#         [0.01568627, 0.0170901 , 0.01652552, ..., 0.0158999 ,
#          0.01678492, 0.01489281],
#         [0.01634241, 0.01689174, 0.01542687, ..., 0.01567102,
#          0.01582361, 0.01640345],
#         [0.01585412, 0.01486229, 0.01751736, ..., 0.01586938,
#          0.01762417, 0.01658656]],
#
#        [[0.01741054, 0.0162356 , 0.01585412, ..., 0.01760891,
#          0.01567102, 0.01899748],
#         [0.01576257, 0.01779202, 0.01625086, ..., 0.01568627,
#          0.01744106, 0.01446555],
#         [0.0140383 , 0.01365682, 0.01754788, ..., 0.01542687,
#          0.01628138, 0.01766995],
#         ...,
#         [0.01765469, 0.01631189, 0.01611353, ..., 0.01672389,
#          0.01860075, 0.01577783],
#         [0.01507591, 0.01576257, 0.01608301, ..., 0.01896696,
#          0.01782254, 0.01660182],
#         [0.01600671, 0.01387045, 0.01591516, ..., 0.01588464,
#          0.01481651, 0.01640345]],
#
#        ...,
#
#        [[0.01385519, 0.01567102, 0.01434348, ..., 0.01545739,
#          0.0161593 , 0.01754788],
#         [0.01315328, 0.01635767, 0.01448081, ..., 0.01828031,
#          0.01651026, 0.0171664 ],
#         [0.01528954, 0.01380941, 0.01483177, ..., 0.01666285,
#          0.01557946, 0.01850919],
#         ...,
#         [0.01765469, 0.01518273, 0.01544213, ..., 0.01600671,
#          0.01516747, 0.01451133],
#         [0.014374  , 0.01553368, 0.01524376, ..., 0.01477073,
#          0.01611353, 0.01693751],
#         [0.01603723, 0.01538109, 0.01510643, ..., 0.01393149,
#          0.01782254, 0.01608301]],
#
#        [[0.01466392, 0.01728847, 0.01391623, ..., 0.01577783,
#          0.01812772, 0.01855497],
#         [0.01625086, 0.01612879, 0.01329061, ..., 0.01829557,
#          0.01692226, 0.01573205],
#         [0.01583886, 0.0187686 , 0.01477073, ..., 0.01541161,
#          0.01603723, 0.01599145],
#         ...,
#         [0.01800565, 0.01477073, 0.01539635, ..., 0.01512169,
#          0.01533532, 0.01608301],
#         [0.01863127, 0.01588464, 0.01603723, ..., 0.01640345,
#          0.01733425, 0.01837186],
#         [0.0177615 , 0.01570153, 0.01580835, ..., 0.01617456,
#          0.01695277, 0.01768521]],
#
#        [[0.01599145, 0.01599145, 0.01727321, ..., 0.01715114,
#          0.01568627, 0.01771572],
#         [0.01388571, 0.01863127, 0.01644923, ..., 0.01295491,
#          0.0170901 , 0.0142977 ],
#         [0.0162356 , 0.01304646, 0.01457237, ..., 0.01486229,
#          0.01574731, 0.01730373],
#         ...,
#         [0.01618982, 0.01773098, 0.01644923, ..., 0.01593042,
#          0.01788357, 0.01507591],
#         [0.01525902, 0.01498436, 0.01606775, ..., 0.01687648,
#          0.01681544, 0.01515221],
#         [0.01472496, 0.01756313, 0.01455711, ..., 0.0170901 ,
#          0.01727321, 0.01663233]]])

# %%
z[0].dtype
# Out:
# dtype('float64')
