# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
from scipy import stats
import matplotlib.pyplot as plt
from skimage.external import tifffile
import seaborn as sns
from skimage.external.tifffile import imread
import os
from os import listdir
from os.path import isfile, join

# %%
bigDir=r'Z:\CookLab\Liu\DNAdamageAnalysis\20210110'

# %%
imageFolder=f'{bigDir}\\data_tiff'

# %%
dataFile=f'{bigDir}\\cellinfo_20210110_v9.csv'
data=pd.read_csv(dataFile)

# %% [markdown]
# # setting #2
# - foci-results2
# - result-image2

# %%
#data=data.drop(columns=['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1', 'Unnamed: 0.1.1.1.1'])
#data.to_csv(dataFile)

# %%
results=f'{bigDir}\\foci-results2'
images=f'{bigDir}\\result-image2-final'

# %%
newSegFolder = os.path.dirname(f'{images}\\nuc_total_foci')

try:
    os.mkdir(newSegFolder)
except:
    pass

# %%
for i,row in data.iterrows():
    ending=data.loc[i,'resultPath'].split('Results-')[1].split('.')[0]+'.tif'
    imagePath=f'{images}\\FociMask_45.0-{ending}'
    data.loc[i,'imagePath']=imagePath

# %%
#data.to_csv(dataFile)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                  file   original cell name  \
# 0           0             0  20210110_cell_00.ciz  20210110xy01_S1.czi
# 1           1             1  20210110_cell_02.ciz  20210110xy01_S3.czi
# 2           2             2  20210110_cell_03.ciz  20210110xy01_S4.czi
# 3           3             3  20210110_cell_04.ciz  20210110xy01_S5.czi
# 4           4             4  20210110_cell_05.ciz  20210110xy01_S6.czi
#
#           movie  ID   x   y  molecular_age category  ... nuc_DAPI_het  \
# 0  20210110xy01 NaN NaN NaN            NaN    LateS  ...   2330318547
# 1  20210110xy01 NaN NaN NaN            NaN    LateS  ...   2248349916
# 2  20210110xy01 NaN NaN NaN            NaN    LateS  ...   2222657732
# 3  20210110xy01 NaN NaN NaN            NaN    LateS  ...   2257515934
# 4  20210110xy01 NaN NaN NaN            NaN    LateS  ...   2302812319
#
#   inner_DAPI_het  outer_DAPI_het nuc_DAPI_eu  inner_DAPI_eu  outer_DAPI_eu  \
# 0     1321232918      1009085629  4487412621     1033036541     3454376080
# 1     1239642048      1008707868  4267792627      922753187     3345039440
# 2     1285322397       937335335  4164319716     1156469120     3007850596
# 3     1292296373       965219561  4568050715      956651499     3611399216
# 4     1516125809       786686510  4183283806      849315778     3333968028
#
#          day fociNo                                         resultPath  \
# 0  d20210110   11.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 1  d20210110   22.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 2  d20210110   16.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 3  d20210110    7.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 4  d20210110   24.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
#
#                                            imagePath
# 0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 1  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 2  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 3  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 4  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
#
# [5 rows x 50 columns]

# %%
for i, row in data.iterrows():
    newSegFolder = os.path.dirname(row.path.replace('data_tiff','result-image2-final//nuc_total_foci'))
    try:
        os.mkdir(newSegFolder)
    except:
        pass
    reMask=imread(data.loc[i,'imagePath'])
    img=imread(data.loc[i,'path'].replace('data_tiff','masked_image').replace('.tif','_masked.tif'))
    
    reMask[reMask==255]=1
    reMask=reMask.astype(bool)
    img[~reMask]=0
    
    imgFile = os.path.basename(row.path).replace('.tif',f'_nuc_total_foci.tif')
    tifffile.imsave(os.path.join(newSegFolder,imgFile), img.astype('uint8'))

# %%
for i, row in data.iterrows():
    newSegFolder = os.path.dirname(row.path.replace('data_tiff','result-image2-final//eu_foci'))
    newSeg1Folder=os.path.dirname(row.path.replace('data_tiff','result-image2-final//het_foci'))
    
    try:
        os.mkdir(newSegFolder)
        os.mkdir(newSeg1Folder)
    except:
        pass
    
    foci=imread(data.loc[i,'imagePath'])
    img=imread(data.loc[i,'path'].replace('data_tiff','masked_image').replace('.tif','_masked.tif'))
    het=imread(data.loc[i,'path'].replace('data_tiff','segmentation_20').replace('.tif','_hetChrom.tif'))
    eu=imread(data.loc[i,'path'].replace('data_tiff','segmentation_20_eu').replace('.tif','_euChrom.tif'))
    
    het=het.astype(bool)
    eu=eu.astype(bool)
    
    imHet=img.copy()
    imEu=img.copy()
    
    foci[foci==255]=1
    foci=foci.astype(bool)
    
    imHet[~het]=0
    imHet[~foci]=0
    imgFile = os.path.basename(row.path).replace('.tif',f'_het_foci.tif')
    tifffile.imsave(os.path.join(newSeg1Folder,imgFile), imHet.astype('uint8'))  
    
    imEu[~eu]=0
    imEu[~foci]=0
    imgFile = os.path.basename(row.path).replace('.tif',f'_eu_foci.tif')
    tifffile.imsave(os.path.join(newSegFolder,imgFile), img.astype('uint8'))

# %% [markdown]
# # setting #2-2
# - foci-results2-2
# - result-image2-2-final

# %%
data.head()
# Out:
#                    file   original cell name         movie  ID   x   y  \
# 0  20210110_cell_00.ciz  20210110xy01_S1.czi  20210110xy01 NaN NaN NaN
# 1  20210110_cell_02.ciz  20210110xy01_S3.czi  20210110xy01 NaN NaN NaN
# 2  20210110_cell_03.ciz  20210110xy01_S4.czi  20210110xy01 NaN NaN NaN
# 3  20210110_cell_04.ciz  20210110xy01_S5.czi  20210110xy01 NaN NaN NaN
# 4  20210110_cell_05.ciz  20210110xy01_S6.czi  20210110xy01 NaN NaN NaN
#
#    molecular_age category group ab1 (heterochromatin)  ...  inner_DAPI_total  \
# 0            NaN    LateS   CTL                   HP1  ...        2354269459
# 1            NaN    LateS   CTL                   HP1  ...        2162395235
# 2            NaN    LateS   CTL                   HP1  ...        2441791517
# 3            NaN    LateS   CTL                   HP1  ...        2248947872
# 4            NaN    LateS   CTL                   HP1  ...        2365441587
#
#   outer_DAPI_total  nuc_DAPI_het  inner_DAPI_het outer_DAPI_het nuc_DAPI_eu  \
# 0       4463461709    2330318547      1321232918     1009085629  4487412621
# 1       4353747308    2248349916      1239642048     1008707868  4267792627
# 2       3945185931    2222657732      1285322397      937335335  4164319716
# 3       4576618777    2257515934      1292296373      965219561  4568050715
# 4       4120654538    2302812319      1516125809      786686510  4183283806
#
#   inner_DAPI_eu  outer_DAPI_eu        day  fociNo
# 0    1033036541     3454376080  d20210110    10.0
# 1     922753187     3345039440  d20210110    17.0
# 2    1156469120     3007850596  d20210110    10.0
# 3     956651499     3611399216  d20210110     4.0
# 4     849315778     3333968028  d20210110    22.0
#
# [5 rows x 46 columns]

# %%
dataFile=f'{bigDir}\\cellinfo_20210110_v9-2.csv'
data=pd.read_csv(dataFile)
data=data.drop(columns=['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1'])
data.to_csv(dataFile)

# %%
for i,row in data.iterrows():
    resultPath=data.loc[i,'path'].replace('data_tiff','foci-results2-2')
    resultPath=resultPath.replace('20210110_cell_','Results-')
    resultPath=resultPath.replace('.tif','.csv')
    data.loc[i,'resultPath']=resultPath

# %%
results=f'{bigDir}\\foci-results2-2'
images=f'{bigDir}\\result-image2-2-final'

# %%
for i,row in data.iterrows():
    ending=data.loc[i,'resultPath'].split('Results-')[1].split('.')[0]+'.tif'
    imagePath=f'{images}\\FociMask_45.0-{ending}'
    data.loc[i,'imagePath']=imagePath

# %%
#data.to_csv(dataFile)

# %%
data.head()
# Out:
#                    file   original cell name         movie  ID   x   y  \
# 0  20210110_cell_00.ciz  20210110xy01_S1.czi  20210110xy01 NaN NaN NaN
# 1  20210110_cell_02.ciz  20210110xy01_S3.czi  20210110xy01 NaN NaN NaN
# 2  20210110_cell_03.ciz  20210110xy01_S4.czi  20210110xy01 NaN NaN NaN
# 3  20210110_cell_04.ciz  20210110xy01_S5.czi  20210110xy01 NaN NaN NaN
# 4  20210110_cell_05.ciz  20210110xy01_S6.czi  20210110xy01 NaN NaN NaN
#
#    molecular_age category group ab1 (heterochromatin)  ...  nuc_DAPI_het  \
# 0            NaN    LateS   CTL                   HP1  ...    2330318547
# 1            NaN    LateS   CTL                   HP1  ...    2248349916
# 2            NaN    LateS   CTL                   HP1  ...    2222657732
# 3            NaN    LateS   CTL                   HP1  ...    2257515934
# 4            NaN    LateS   CTL                   HP1  ...    2302812319
#
#   inner_DAPI_het  outer_DAPI_het  nuc_DAPI_eu inner_DAPI_eu outer_DAPI_eu  \
# 0     1321232918      1009085629   4487412621    1033036541    3454376080
# 1     1239642048      1008707868   4267792627     922753187    3345039440
# 2     1285322397       937335335   4164319716    1156469120    3007850596
# 3     1292296373       965219561   4568050715     956651499    3611399216
# 4     1516125809       786686510   4183283806     849315778    3333968028
#
#          day  fociNo                                         resultPath  \
# 0  d20210110    10.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 1  d20210110    17.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 2  d20210110    10.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 3  d20210110     4.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 4  d20210110    22.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
#
#                                            imagePath
# 0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 1  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 2  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 3  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 4  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
#
# [5 rows x 48 columns]

# %%
for i, row in data.iterrows():
    newSegFolder = os.path.dirname(row.path.replace('data_tiff','result-image2-2-final//nuc_total_foci'))
    try:
        os.mkdir(newSegFolder)
    except:
        pass
    reMask=imread(data.loc[i,'imagePath'])
    img=imread(data.loc[i,'path'].replace('data_tiff','masked_image').replace('.tif','_masked.tif'))
    
    reMask[reMask==255]=1
    reMask=reMask.astype(bool)
    img[~reMask]=0
    
    imgFile = os.path.basename(row.path).replace('.tif',f'_nuc_total_foci.tif')
    tifffile.imsave(os.path.join(newSegFolder,imgFile), img.astype('uint8'))

# %%
for i, row in data.iterrows():
    newSegFolder = os.path.dirname(row.path.replace('data_tiff','result-image2-2-final//eu_foci'))
    newSeg1Folder=os.path.dirname(row.path.replace('data_tiff','result-image2-2-final//het_foci'))
    
    try:
        os.mkdir(newSegFolder)
        os.mkdir(newSeg1Folder)
    except:
        pass
    
    foci=imread(data.loc[i,'imagePath'])
    img=imread(data.loc[i,'path'].replace('data_tiff','masked_image').replace('.tif','_masked.tif'))
    het=imread(data.loc[i,'path'].replace('data_tiff','segmentation_20').replace('.tif','_hetChrom.tif'))
    eu=imread(data.loc[i,'path'].replace('data_tiff','segmentation_20_eu').replace('.tif','_euChrom.tif'))
    
    het=het.astype(bool)
    eu=eu.astype(bool)
    
    imHet=img.copy()
    imEu=img.copy()
    
    foci[foci==255]=1
    foci=foci.astype(bool)
    
    imHet[~het]=0
    imHet[~foci]=0
    imgFile = os.path.basename(row.path).replace('.tif',f'_het_foci.tif')
    tifffile.imsave(os.path.join(newSeg1Folder,imgFile), imHet.astype('uint8'))  
    
    imEu[~eu]=0
    imEu[~foci]=0
    imgFile = os.path.basename(row.path).replace('.tif',f'_eu_foci.tif')
    tifffile.imsave(os.path.join(newSegFolder,imgFile), img.astype('uint8'))
