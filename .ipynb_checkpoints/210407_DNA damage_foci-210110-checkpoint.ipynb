# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
from scipy import stats
import matplotlib.pyplot as plt
from skimage.external import tifffile
import seaborn as sns
from skimage.external.tifffile import imread
import os
from os import listdir
from os.path import isfile, join

# %%
bigDir=r'Z:\CookLab\Liu\DNAdamageAnalysis\20210110'

# %%
imageFolder=f'{bigDir}\\data_tiff'

# %%
dataFile=f'{bigDir}\\cellinfo_20210110_v9.csv'
data=pd.read_csv(dataFile)

# %% [markdown]
# # setting #2
# - foci-results2
# - result-image2

# %%
#data=data.drop(columns=['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1', 'Unnamed: 0.1.1.1.1'])
#data.to_csv(dataFile)

# %%
results=f'{bigDir}\\foci-results2'
images=f'{bigDir}\\result-image2-final'

# %%
for i,row in data.iterrows():
    ending=data.loc[i,'resultPath'].split('Results-')[1].split('.')[0]+'.tif'
    imagePath=f'{images}\\FociMask_45.0-{ending}'
    data.loc[i,'imagePath']=imagePath

# %%
#data.to_csv(dataFile)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                  file  \
# 0           0             0               0  20210110_cell_00.ciz
# 1           1             1               1  20210110_cell_02.ciz
# 2           2             2               2  20210110_cell_03.ciz
# 3           3             3               3  20210110_cell_04.ciz
# 4           4             4               4  20210110_cell_05.ciz
#
#     original cell name         movie  ID   x   y  molecular_age  ...  \
# 0  20210110xy01_S1.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 1  20210110xy01_S3.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 2  20210110xy01_S4.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 3  20210110xy01_S5.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 4  20210110xy01_S6.czi  20210110xy01 NaN NaN NaN            NaN  ...
#
#   inner_DAPI_het outer_DAPI_het nuc_DAPI_eu  inner_DAPI_eu outer_DAPI_eu  \
# 0     1321232918     1009085629  4487412621     1033036541    3454376080
# 1     1239642048     1008707868  4267792627      922753187    3345039440
# 2     1285322397      937335335  4164319716     1156469120    3007850596
# 3     1292296373      965219561  4568050715      956651499    3611399216
# 4     1516125809      786686510  4183283806      849315778    3333968028
#
#          day  fociNo                                         resultPath  \
# 0  d20210110    11.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 1  d20210110    22.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 2  d20210110    16.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 3  d20210110     7.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 4  d20210110    24.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
#
#                                            imagePath  \
# 0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 1  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 2  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 3  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 4  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
#
#                                            intensity
# 0  [25705.58, 21960.438, 15551.518, 14896.57, 139...
# 1  [26105.709, 21349.041, 19728.039, 17971.768, 1...
# 2  [19153.35, 18027.488, 17394.143, 16057.05, 160...
# 3  [18837.4, 15755.615, 14266.773000000001, 11617...
# 4  [21303.871, 21151.697, 17408.346, 16875.402, 1...
#
# [5 rows x 52 columns]

# %%
for i, row in data.iterrows():
    newSegFolder = os.path.dirname(row.path.replace('data_tiff','result-image2-final//nuc_total_foci'))
    try:
        os.mkdir(newSegFolder)
    except:
        pass
    reMask=imread(data.loc[i,'imagePath'])
    img=imread(data.loc[i,'path'].replace('data_tiff','masked_image').replace('.tif','_masked.tif'))
    
    reMask[reMask==255]=1
    reMask=reMask.astype(bool)
    img[~reMask]=0
    
    imgFile = os.path.basename(row.path).replace('.tif',f'_nuc_total_foci.tif')
    tifffile.imsave(os.path.join(newSegFolder,imgFile), img.astype('uint32'))

# %%
for i, row in data.iterrows():
    newSegFolder = os.path.dirname(row.path.replace('data_tiff','result-image2-final//eu_foci'))
    newSeg1Folder=os.path.dirname(row.path.replace('data_tiff','result-image2-final//het_foci'))
    
    try:
        os.mkdir(newSegFolder)
        os.mkdir(newSeg1Folder)
    except:
        pass
    
    foci=imread(data.loc[i,'imagePath'])
    img=imread(data.loc[i,'path'].replace('data_tiff','masked_image').replace('.tif','_masked.tif'))
    het=imread(data.loc[i,'path'].replace('data_tiff','segmentation_20').replace('.tif','_hetChrom.tif'))
    eu=imread(data.loc[i,'path'].replace('data_tiff','segmentation_20_eu').replace('.tif','_euChrom.tif'))
    
    het=het.astype(bool)
    eu=eu.astype(bool)
    
    imHet=img.copy()
    imEu=img.copy()
    
    foci[foci==255]=1
    foci=foci.astype(bool)
    
    imHet[~het]=0
    imHet[~foci]=0
    imgFile = os.path.basename(row.path).replace('.tif',f'_het_foci.tif')
    tifffile.imsave(os.path.join(newSeg1Folder,imgFile), imHet.astype('uint32'))  
   
    imEu[~eu]=0
    imEu[~foci]=0
    imgFile = os.path.basename(row.path).replace('.tif',f'_eu_foci.tif')
    tifffile.imsave(os.path.join(newSegFolder,imgFile), imEu.astype('uint32'))

# %%
for i, row in data.iterrows():
    data.intensity=data.intensity.astype('object')
    try:
        result=pd.read_csv(data.loc[i,'resultPath'])
        data.intensity=data.intensity.astype('object')
        intensity=result.loc[:,'Intensity'].values.tolist()
        data.at[i,'intensity']=intensity
    except:
        data.at[i,'intensity']=[]

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                  file  \
# 0           0             0               0  20210110_cell_00.ciz
# 1           1             1               1  20210110_cell_02.ciz
# 2           2             2               2  20210110_cell_03.ciz
# 3           3             3               3  20210110_cell_04.ciz
# 4           4             4               4  20210110_cell_05.ciz
#
#     original cell name         movie  ID   x   y  molecular_age  ...  \
# 0  20210110xy01_S1.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 1  20210110xy01_S3.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 2  20210110xy01_S4.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 3  20210110xy01_S5.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 4  20210110xy01_S6.czi  20210110xy01 NaN NaN NaN            NaN  ...
#
#   inner_DAPI_eu outer_DAPI_eu        day  fociNo  \
# 0    1033036541    3454376080  d20210110    11.0
# 1     922753187    3345039440  d20210110    22.0
# 2    1156469120    3007850596  d20210110    16.0
# 3     956651499    3611399216  d20210110     7.0
# 4     849315778    3333968028  d20210110    24.0
#
#                                           resultPath  \
# 0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 1  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 2  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 3  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 4  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
#
#                                            imagePath  \
# 0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 1  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 2  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 3  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 4  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
#
#                                            intensity  \
# 0  [25705.58, 21960.438, 15551.518, 14896.57, 139...
# 1  [26105.709, 21349.041, 19728.039, 17971.768, 1...
# 2  [19153.35, 18027.488, 17394.143, 16057.05, 160...
# 3  [18837.4, 15755.615, 14266.773000000001, 11617...
# 4  [21303.871, 21151.697, 17408.346, 16875.402, 1...
#
#                                         nucIntensity  \
# 0  [12923, 12785, 13093, 14395, 13516, 13817, 133...
# 1  [12398, 11980, 14071, 14305, 17039, 14186, 173...
# 2  [10036, 10603, 10432, 10487, 10579, 10387, 103...
# 3  [14235, 14287, 13781, 14312, 14002, 13600, 147...
# 4  [13635, 14355, 15514, 13436, 13056, 13141, 156...
#
#                                         hetIntensity euIntensity
# 0  [12923, 12785, 13093, 14395, 13516, 13817, 133...          []
# 1  [12398, 11980, 14071, 14305, 17039, 14186, 173...          []
# 2  [10036, 10603, 10432, 10487, 10579, 10387, 103...          []
# 3  [14235, 14287, 13781, 14312, 14002, 13600, 147...          []
# 4  [13635, 14355, 15514, 13436, 13056, 13141, 156...          []
#
# [5 rows x 55 columns]

# %%
#data.to_csv(dataFile)

# %%
CTL=data.loc[data.group=='CTL',:]

# %%
# %matplotlib notebook
sns.boxplot(data=data,x='group',y=np.sum(data.intensity))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data.loc[0,'nucIntensity']=0
data.loc[0,'hetIntensity']=0
data.loc[0,'euIntensity']=0

# %%
#data.nucIntensity=data.nucIntensity.astype('object')
#data.hetIntensity=data.hetIntensity.astype('object')
#data.euIntensity=data.euIntensity.astype('object')

for i, row in data.iterrows():
    data.nucIntensity=data.nucIntensity.astype('object')
    data.hetIntensity=data.hetIntensity.astype('object')
    data.euIntensity=data.euIntensity.astype('object')
    
    nuc_file=data.loc[i,'path'].replace('data_tiff','result-image2-final\\nuc_total_foci').replace('.tif','_nuc_total_foci.tif')
    het_file=data.loc[i,'path'].replace('data_tiff','result-image2-final\\het_foci').replace('.tif','_het_foci.tif')
    eu_file=data.loc[i,'path'].replace('data_tiff','result-image2-final\\eu_foci').replace('.tif','_eu_foci.tif')
    
    nucIm=imread(nuc_file)
    hetIm=imread(het_file)
    euIm=imread(eu_file)
    
    nuc=nucIm[np.nonzero(nucIm)].tolist()
    het=hetIm[np.nonzero(hetIm)].tolist()
    eu=euIm[np.nonzero(euIm)].tolist()
    
    data.at[i,'nucIntensity']=nuc
    data.at[i,'hetIntensity']=het
    data.at[i,'euIntensity']=eu

# %%
data.to_csv(dataFile)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                  file  \
# 0           0             0               0  20210110_cell_00.ciz
# 1           1             1               1  20210110_cell_02.ciz
# 2           2             2               2  20210110_cell_03.ciz
# 3           3             3               3  20210110_cell_04.ciz
# 4           4             4               4  20210110_cell_05.ciz
#
#     original cell name         movie  ID   x   y  molecular_age  ...  \
# 0  20210110xy01_S1.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 1  20210110xy01_S3.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 2  20210110xy01_S4.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 3  20210110xy01_S5.czi  20210110xy01 NaN NaN NaN            NaN  ...
# 4  20210110xy01_S6.czi  20210110xy01 NaN NaN NaN            NaN  ...
#
#   inner_DAPI_eu outer_DAPI_eu        day  fociNo  \
# 0    1033036541    3454376080  d20210110    11.0
# 1     922753187    3345039440  d20210110    22.0
# 2    1156469120    3007850596  d20210110    16.0
# 3     956651499    3611399216  d20210110     7.0
# 4     849315778    3333968028  d20210110    24.0
#
#                                           resultPath  \
# 0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 1  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 2  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 3  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 4  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
#
#                                            imagePath  \
# 0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 1  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 2  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 3  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 4  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
#
#                                            intensity  \
# 0  [25705.58, 21960.438, 15551.518, 14896.57, 139...
# 1  [26105.709, 21349.041, 19728.039, 17971.768, 1...
# 2  [19153.35, 18027.488, 17394.143, 16057.05, 160...
# 3  [18837.4, 15755.615, 14266.773000000001, 11617...
# 4  [21303.871, 21151.697, 17408.346, 16875.402, 1...
#
#                                         nucIntensity  \
# 0  [12923, 12785, 13093, 14395, 13516, 13817, 133...
# 1  [12398, 11980, 14071, 14305, 17039, 14186, 173...
# 2  [10036, 10603, 10432, 10487, 10579, 10387, 103...
# 3  [14235, 14287, 13781, 14312, 14002, 13600, 147...
# 4  [13635, 14355, 15514, 13436, 13056, 13141, 156...
#
#                                         hetIntensity euIntensity
# 0  [12923, 12785, 13093, 14395, 13516, 13817, 133...          []
# 1  [12398, 11980, 14071, 14305, 17039, 14186, 173...          []
# 2  [10036, 10603, 10432, 10487, 10579, 10387, 103...          []
# 3  [14235, 14287, 13781, 14312, 14002, 13600, 147...          []
# 4  [13635, 14355, 15514, 13436, 13056, 13141, 156...          []
#
# [5 rows x 55 columns]

# %%
# %matplotlib notebook
sns.boxplot(data=data,x='group',y=np.sum(data.nucIntensity))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
sns.boxplot(data=data,x='group',y=np.sum(data.hetIntensity))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # setting #2-2
# - foci-results2-2
# - result-image2-2-final

# %%
dataFile=f'{bigDir}\\cellinfo_20210110_v9-2.csv'
data=pd.read_csv(dataFile)
#data=data.drop(columns=['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1'])
#data.to_csv(dataFile)

# %%
data.head()
# Out:
#    Unnamed: 0                  file   original cell name         movie  ID  \
# 0           0  20210110_cell_00.ciz  20210110xy01_S1.czi  20210110xy01 NaN
# 1           1  20210110_cell_02.ciz  20210110xy01_S3.czi  20210110xy01 NaN
# 2           2  20210110_cell_03.ciz  20210110xy01_S4.czi  20210110xy01 NaN
# 3           3  20210110_cell_04.ciz  20210110xy01_S5.czi  20210110xy01 NaN
# 4           4  20210110_cell_05.ciz  20210110xy01_S6.czi  20210110xy01 NaN
#
#     x   y  molecular_age category group  ... nuc_DAPI_het  inner_DAPI_het  \
# 0 NaN NaN            NaN    LateS   CTL  ...   2330318547      1321232918
# 1 NaN NaN            NaN    LateS   CTL  ...   2248349916      1239642048
# 2 NaN NaN            NaN    LateS   CTL  ...   2222657732      1285322397
# 3 NaN NaN            NaN    LateS   CTL  ...   2257515934      1292296373
# 4 NaN NaN            NaN    LateS   CTL  ...   2302812319      1516125809
#
#   outer_DAPI_het  nuc_DAPI_eu  inner_DAPI_eu outer_DAPI_eu        day fociNo  \
# 0     1009085629   4487412621     1033036541    3454376080  d20210110   10.0
# 1     1008707868   4267792627      922753187    3345039440  d20210110   17.0
# 2      937335335   4164319716     1156469120    3007850596  d20210110   10.0
# 3      965219561   4568050715      956651499    3611399216  d20210110    4.0
# 4      786686510   4183283806      849315778    3333968028  d20210110   22.0
#
#                                           resultPath  \
# 0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 1  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 2  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 3  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 4  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
#
#                                            imagePath
# 0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 1  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 2  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 3  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 4  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
#
# [5 rows x 49 columns]

# %%
for i,row in data.iterrows():
    resultPath=data.loc[i,'path'].replace('data_tiff','foci-results2-2')
    resultPath=resultPath.replace('20210110_cell_','Results-')
    resultPath=resultPath.replace('.tif','.csv')
    data.loc[i,'resultPath']=resultPath

# %%
results=f'{bigDir}\\foci-results2-2'
images=f'{bigDir}\\result-image2-2-final'

# %%
for i,row in data.iterrows():
    ending=data.loc[i,'resultPath'].split('Results-')[1].split('.')[0]+'.tif'
    imagePath=f'{images}\\FociMask_45.0-{ending}'
    data.loc[i,'imagePath']=imagePath

# %%
#data.to_csv(dataFile)

# %%
data.head()
# Out:
#                    file   original cell name         movie  ID   x   y  \
# 0  20210110_cell_00.ciz  20210110xy01_S1.czi  20210110xy01 NaN NaN NaN
# 1  20210110_cell_02.ciz  20210110xy01_S3.czi  20210110xy01 NaN NaN NaN
# 2  20210110_cell_03.ciz  20210110xy01_S4.czi  20210110xy01 NaN NaN NaN
# 3  20210110_cell_04.ciz  20210110xy01_S5.czi  20210110xy01 NaN NaN NaN
# 4  20210110_cell_05.ciz  20210110xy01_S6.czi  20210110xy01 NaN NaN NaN
#
#    molecular_age category group ab1 (heterochromatin)  ...  nuc_DAPI_het  \
# 0            NaN    LateS   CTL                   HP1  ...    2330318547
# 1            NaN    LateS   CTL                   HP1  ...    2248349916
# 2            NaN    LateS   CTL                   HP1  ...    2222657732
# 3            NaN    LateS   CTL                   HP1  ...    2257515934
# 4            NaN    LateS   CTL                   HP1  ...    2302812319
#
#   inner_DAPI_het  outer_DAPI_het  nuc_DAPI_eu inner_DAPI_eu outer_DAPI_eu  \
# 0     1321232918      1009085629   4487412621    1033036541    3454376080
# 1     1239642048      1008707868   4267792627     922753187    3345039440
# 2     1285322397       937335335   4164319716    1156469120    3007850596
# 3     1292296373       965219561   4568050715     956651499    3611399216
# 4     1516125809       786686510   4183283806     849315778    3333968028
#
#          day  fociNo                                         resultPath  \
# 0  d20210110    10.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 1  d20210110    17.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 2  d20210110    10.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 3  d20210110     4.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
# 4  d20210110    22.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...
#
#                                            imagePath
# 0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 1  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 2  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 3  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
# 4  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\resu...
#
# [5 rows x 48 columns]

# %%
for i, row in data.iterrows():
    newSegFolder = os.path.dirname(row.path.replace('data_tiff','result-image2-2-final//nuc_total_foci'))
    try:
        os.mkdir(newSegFolder)
    except:
        pass
    reMask=imread(data.loc[i,'imagePath'])
    img=imread(data.loc[i,'path'].replace('data_tiff','masked_image').replace('.tif','_masked.tif'))
    
    reMask[reMask==255]=1
    reMask=reMask.astype(bool)
    img[~reMask]=0
    
    imgFile = os.path.basename(row.path).replace('.tif',f'_nuc_total_foci.tif')
    tifffile.imsave(os.path.join(newSegFolder,imgFile), img.astype('uint32'))

# %%
for i, row in data.iterrows():
    newSegFolder = os.path.dirname(row.path.replace('data_tiff','result-image2-2-final//eu_foci'))
    newSeg1Folder=os.path.dirname(row.path.replace('data_tiff','result-image2-2-final//het_foci'))
    
    try:
        os.mkdir(newSegFolder)
        os.mkdir(newSeg1Folder)
    except:
        pass
    
    foci=imread(data.loc[i,'imagePath'])
    img=imread(data.loc[i,'path'].replace('data_tiff','masked_image').replace('.tif','_masked.tif'))
    het=imread(data.loc[i,'path'].replace('data_tiff','segmentation_20').replace('.tif','_hetChrom.tif'))
    eu=imread(data.loc[i,'path'].replace('data_tiff','segmentation_20_eu').replace('.tif','_euChrom.tif'))
    
    het=het.astype(bool)
    eu=eu.astype(bool)
    
    imHet=img.copy()
    imEu=img.copy()
    
    foci[foci==255]=1
    foci=foci.astype(bool)
    
    imHet[~het]=0
    imHet[~foci]=0
    imgFile = os.path.basename(row.path).replace('.tif',f'_het_foci.tif')
    tifffile.imsave(os.path.join(newSeg1Folder,imgFile), imHet.astype('uint32'))  
    
    imEu[~eu]=0
    imEu[~foci]=0
    imgFile = os.path.basename(row.path).replace('.tif',f'_eu_foci.tif')
    tifffile.imsave(os.path.join(newSegFolder,imgFile), imEu.astype('uint32'))

# %%
data.loc[0,'intensity']=0
for i, row in data.iterrows():
    data.intensity=data.intensity.astype('object')
    try:
        result=pd.read_csv(data.loc[i,'resultPath'])
        intensity=result.loc[:,'Intensity'].values.tolist()
        data.at[i,'intensity']=intensity
    except:
        data.at[i,'intensity']=[]

# %%
#data.to_csv(dataFile)

# %%
CTL=data.loc[data.group=='CTL',:]

# %%
# %matplotlib notebook
sns.boxplot(data=data,x='group',y=np.sum(data.intensity))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data.loc[0,'nucIntensity']=0
data.loc[0,'hetIntensity']=0
data.loc[0,'euIntensity']=0

# %%
#data.nucIntensity=data.nucIntensity.astype('object')
#data.hetIntensity=data.hetIntensity.astype('object')
#data.euIntensity=data.euIntensity.astype('object')

for i, row in data.iterrows():
    data.nucIntensity=data.nucIntensity.astype('object')
    data.hetIntensity=data.hetIntensity.astype('object')
    data.euIntensity=data.euIntensity.astype('object')
    
    nuc_file=data.loc[i,'path'].replace('data_tiff','result-image2-2-final\\nuc_total_foci').replace('.tif','_nuc_total_foci.tif')
    het_file=data.loc[i,'path'].replace('data_tiff','result-image2-2-final\\het_foci').replace('.tif','_het_foci.tif')
    eu_file=data.loc[i,'path'].replace('data_tiff','result-image2-2-final\\eu_foci').replace('.tif','_eu_foci.tif')
    
    nucIm=imread(nuc_file)
    hetIm=imread(het_file)
    euIm=imread(eu_file)
    
    nuc=nucIm[np.nonzero(nucIm)].tolist()
    het=hetIm[np.nonzero(hetIm)].tolist()
    eu=euIm[np.nonzero(euIm)].tolist()
    
    data.at[i,'nucIntensity']=nuc
    data.at[i,'hetIntensity']=het
    data.at[i,'euIntensity']=eu

# %%
# %matplotlib notebook
sns.boxplot(data=data,x='group',y=np.sum(data.nucIntensity))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
sns.boxplot(data=data,x='group',y=np.sum(data.hetIntensity))
# Out:
# <img src="data:image/png;base64,..." width="640">
