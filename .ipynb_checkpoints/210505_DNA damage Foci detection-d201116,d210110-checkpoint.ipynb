# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
from scipy import stats
import matplotlib.pyplot as plt
from skimage.external import tifffile
import seaborn as sns
from skimage.external.tifffile import imread
import os
from os import listdir
from os.path import isfile, join

# %%
bigDir=r'Z:\CookLab\Liu\DNAdamageAnalysis\20201116'
dataFile=f'{bigDir}\\cellinfo_20201116_v10-2.csv'
data1=pd.read_csv(dataFile)

# %%
bigDir=r'Z:\CookLab\Liu\DNAdamageAnalysis\20210110'
dataFile=f'{bigDir}\\cellinfo_20210110_v9.csv'
data2=pd.read_csv(dataFile)

# %%
data=[data1,data2]

# %%
finalData=pd.concat(data)
# Out:
# C:\ProgramData\Anaconda3_reinstalled\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
finalData.head
# Out:
# <bound method NDFrame.head of      DAPI ch  ID  Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0          4 NaN           0           NaN             NaN               NaN
# 1          4 NaN           1           NaN             NaN               NaN
# 2          4 NaN           2           NaN             NaN               NaN
# 3          4 NaN           3           NaN             NaN               NaN
# 4          4 NaN           4           NaN             NaN               NaN
# 5          4 NaN           5           NaN             NaN               NaN
# 6          4 NaN           6           NaN             NaN               NaN
# 7          4 NaN           7           NaN             NaN               NaN
# 8          4 NaN           8           NaN             NaN               NaN
# 9          4 NaN           9           NaN             NaN               NaN
# 10         4 NaN          10           NaN             NaN               NaN
# 11         4 NaN          11           NaN             NaN               NaN
# 12         4 NaN          12           NaN             NaN               NaN
# 13         4 NaN          13           NaN             NaN               NaN
# 14         4 NaN          14           NaN             NaN               NaN
# 15         4 NaN          15           NaN             NaN               NaN
# 16         4 NaN          16           NaN             NaN               NaN
# 17         4 NaN          17           NaN             NaN               NaN
# 18         4 NaN          18           NaN             NaN               NaN
# 19         4 NaN          19           NaN             NaN               NaN
# 20         4 NaN          20           NaN             NaN               NaN
# 21         4 NaN          21           NaN             NaN               NaN
# 22         4 NaN          22           NaN             NaN               NaN
# 23         4 NaN          23           NaN             NaN               NaN
# 24         4 NaN          24           NaN             NaN               NaN
# 25         4 NaN          25           NaN             NaN               NaN
# 26         4 NaN          26           NaN             NaN               NaN
# 27         4 NaN          27           NaN             NaN               NaN
# 28         4 NaN          28           NaN             NaN               NaN
# 29         4 NaN          29           NaN             NaN               NaN
# ..       ...  ..         ...           ...             ...               ...
# 79         3 NaN          79          79.0            79.0              79.0
# 80         3 NaN          80          80.0            80.0              80.0
# 81         3 NaN          81          81.0            81.0              81.0
# 82         3 NaN          82          82.0            82.0              82.0
# 83         3 NaN          83          83.0            83.0              83.0
# 84         3 NaN          84          84.0            84.0              84.0
# 85         3 NaN          85          85.0            85.0              85.0
# 86         3 NaN          86          86.0            86.0              86.0
# 87         3 NaN          87          87.0            87.0              87.0
# 88         3 NaN          88          88.0            88.0              88.0
# 89         3 NaN          89          89.0            89.0              89.0
# 90         3 NaN          90          90.0            90.0              90.0
# 91         3 NaN          91          91.0            91.0              91.0
# 92         3 NaN          92          92.0            92.0              92.0
# 93         3 NaN          93          93.0            93.0              93.0
# 94         3 NaN          94          94.0            94.0              94.0
# 95         3 NaN          95          95.0            95.0              95.0
# 96         3 NaN          96          96.0            96.0              96.0
# 97         3 NaN          97          97.0            97.0              97.0
# 98         3 NaN          98          98.0            98.0              98.0
# 99         3 NaN          99          99.0            99.0              99.0
# 100        3 NaN         100         100.0           100.0             100.0
# 101        3 NaN         101         101.0           101.0             101.0
# 102        3 NaN         102         102.0           102.0             102.0
# 103        3 NaN         103         103.0           103.0             103.0
# 104        3 NaN         104         104.0           104.0             104.0
# 105        3 NaN         105         105.0           105.0             105.0
# 106        3 NaN         106         106.0           106.0             106.0
# 107        3 NaN         107         107.0           107.0             107.0
# 108        3 NaN         108         108.0           108.0             108.0
#
#      Unnamed: 0.1.1.1.1  Unnamed: 3 ab1 (EdU) ab1 (heterochromatin)  ...  \
# 0                   NaN         1.0       EdU                   NaN  ...
# 1                   NaN         2.0       EdU                   NaN  ...
# 2                   NaN         3.0       EdU                   NaN  ...
# 3                   NaN         4.0       EdU                   NaN  ...
# 4                   NaN         5.0       EdU                   NaN  ...
# 5                   NaN         6.0       EdU                   NaN  ...
# 6                   NaN         7.0       EdU                   NaN  ...
# 7                   NaN         8.0       EdU                   NaN  ...
# 8                   NaN         9.0       EdU                   NaN  ...
# 9                   NaN        10.0       EdU                   NaN  ...
# 10                  NaN        11.0       EdU                   NaN  ...
# 11                  NaN        12.0       EdU                   NaN  ...
# 12                  NaN        13.0       EdU                   NaN  ...
# 13                  NaN         1.0       EdU                   NaN  ...
# 14                  NaN         2.0       EdU                   NaN  ...
# 15                  NaN         3.0       EdU                   NaN  ...
# 16                  NaN         4.0       EdU                   NaN  ...
# 17                  NaN         5.0       EdU                   NaN  ...
# 18                  NaN         6.0       EdU                   NaN  ...
# 19                  NaN         7.0       EdU                   NaN  ...
# 20                  NaN         8.0       EdU                   NaN  ...
# 21                  NaN        10.0       EdU                   NaN  ...
# 22                  NaN        12.0       EdU                   NaN  ...
# 23                  NaN        13.0       EdU                   NaN  ...
# 24                  NaN         1.0       EdU                   NaN  ...
# 25                  NaN         2.0       EdU                   NaN  ...
# 26                  NaN         3.0       EdU                   NaN  ...
# 27                  NaN         4.0       EdU                   NaN  ...
# 28                  NaN         5.0       EdU                   NaN  ...
# 29                  NaN         6.0       EdU                   NaN  ...
# ..                  ...         ...       ...                   ...  ...
# 79                 79.0         NaN       NaN                   HP1  ...
# 80                 80.0         NaN       NaN                   HP1  ...
# 81                 81.0         NaN       NaN                   HP1  ...
# 82                 82.0         NaN       NaN                   HP1  ...
# 83                 83.0         NaN       NaN                   HP1  ...
# 84                 84.0         NaN       NaN                   HP1  ...
# 85                 85.0         NaN       NaN                   HP1  ...
# 86                 86.0         NaN       NaN                   HP1  ...
# 87                 87.0         NaN       NaN                   HP1  ...
# 88                 88.0         NaN       NaN                   HP1  ...
# 89                 89.0         NaN       NaN                   HP1  ...
# 90                 90.0         NaN       NaN                   HP1  ...
# 25         161503.0  Z:\CookLab\Liu\DNAdamageAnalysis\20201116\data...
# 26         167434.0  Z:\CookLab\Liu\DNAdamageAnalysis\20201116\data...
# 27         128689.0  Z:\CookLab\Liu\DNAdamageAnalysis\20201116\data...
# 28         142986.0  Z:\CookLab\Liu\DNAdamageAnalysis\20201116\data...
# 29         135995.0  Z:\CookLab\Liu\DNAdamageAnalysis\20201116\data...
# ..              ...                                                ...
# 79         400190.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 80         398406.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 81         422003.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 82         441927.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 83         451205.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 84         439151.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 85         455527.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 86         462515.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 87         491706.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 88         405761.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 89         458856.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 90         519521.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 91         458359.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 92         424954.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 93         412696.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 94         402907.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 95         400347.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 96         410531.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 97         508204.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 98         517556.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 99         386311.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 100        523302.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 101        422499.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 102        368439.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 103        490295.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 104        420179.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 105        433134.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 106        376633.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 107        459988.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
# 108        432002.0  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\data...
#
#                                             resultPath totalCount   x   y
# 0    Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      219.0 NaN NaN
# 1    Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      286.0 NaN NaN
# 2    Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      546.0 NaN NaN
# 3    Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      199.0 NaN NaN
# 4    Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      386.0 NaN NaN
# 5    Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      319.0 NaN NaN
# 6    Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      185.0 NaN NaN
# 7    Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      253.0 NaN NaN
# 8    Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...       96.0 NaN NaN
# 9    Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      228.0 NaN NaN
# 10   Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      255.0 NaN NaN
# 11   Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      166.0 NaN NaN
# 12   Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      142.0 NaN NaN
# 13   Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      520.0 NaN NaN
# 14   Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      195.0 NaN NaN
# 15   Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      642.0 NaN NaN
# 16   Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...       92.0 NaN NaN
# 17   Z:\CookLab\Liu\DNAdamageAnalysis\20201116\foci...      576.0 NaN NaN
Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...        NaN NaN NaN
# 101  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...        NaN NaN NaN
# 102  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...        NaN NaN NaN
# 103  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...        NaN NaN NaN
# 104  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...        NaN NaN NaN
# 105  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...        NaN NaN NaN
# 106  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...        NaN NaN NaN
# 107  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...        NaN NaN NaN
# 108  Z:\CookLab\Liu\DNAdamageAnalysis\20210110\foci...        NaN NaN NaN
#
# [220 rows x 92 columns]>

# %%
finalData=finalData.drop(columns=['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1', 'Unnamed: 0.1.1.1', 'Unnamed: 0.1.1.1.1'])

# %%
finalData.to_csv(r'Z:\CookLab\Liu\DNAdamageAnalysis\cellinfo_201116-210110.csv')

# %%
data=pd.read_csv(r'Z:\CookLab\Liu\DNAdamageAnalysis\cellinfo_201116-210110.csv')

# %%
for i, row in data.iterrows():
    data.loc[i,'day']='d'+data.loc[i,'file'].split("_cell")[0]

# %%
data.day.head()
# Out:
# 0    d20201116
# 1    d20201116
# 2    d20201116
# 3    d20201116
# 4    d20201116
# Name: day, dtype: object

# %%
from ast import literal_eval

# %%
for i,row in data.iterrows():
    data.nucIntensity[i]=literal_eval(data.nucIntensity[i])
# Out:
# C:\ProgramData\Anaconda3_reinstalled\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i,row in data.iterrows():
    data.hetIntensity[i]=literal_eval(data.hetIntensity[i])
    data.euIntensity[i]=literal_eval(data.euIntensity[i])
# Out:
# C:\ProgramData\Anaconda3_reinstalled\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3_reinstalled\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.nucIntensity.dtype
# Out:
# dtype('O')

# %%
for i, row in data.iterrows():
    if data.group[i] =='APH_25ng':
        data.group[i]='APH'
    if data.group[i] == 'DOX_24H':
        data.group[i] = 'DOX'
# Out:
# C:\ProgramData\Anaconda3_reinstalled\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3_reinstalled\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
# %matplotlib notebook
sns.boxplot(data=data,x='group',y=np.sum(data.nucIntensity), hue='day')
plt.xlabel('Treatment Group')
plt.ylabel('Intensity')
plt.title('Foci Intensity in Groups [total nucleus]', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Foci Intensity in Groups [total nucleus]')

# %%
# %matplotlib notebook
sns.boxplot(data=data,x='group',y=np.sum(data.hetIntensity), hue='day')
plt.xlabel('Treatment Group')
plt.ylabel('Intensity')
plt.title('Foci Intensity in Groups [total nucleus]', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Foci Intensity in Groups [total nucleus]')

# %%
# %matplotlib notebook
data=data.loc[data.day=='d20201116',:]
sns.boxplot(data=data,x='group',y=np.sum(data.euIntensity))
plt.xlabel('Treatment Group')
plt.ylabel('Intensity')
plt.title('Foci Intensity in Groups [total nucleus]', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Foci Intensity in Groups [total nucleus]')

# %%
data.to_csv(r'Z:\CookLab\Liu\DNAdamageAnalysis\cellinfo_201116-210110.csv')
