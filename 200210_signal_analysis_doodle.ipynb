# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats
import math

# %%
dataFile = r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\new dataset\cellinfo_signals_v3.csv'
orgFile=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\signal_data_total_v3.csv'

# %%
data=pd.read_csv(dataFile)

# %%
org=pd.read_csv(orgFile)

# %% [markdown]
# ## new dataset

# %%
# het ch2 (MCM)
data['het_expected_ch2']=data['HetChrom_erosion_inner_9x5_20_ch2']+data['HetChrom_erosion_outer_9x5_20_ch2']

# %%
data['het_ratio_ch2']=data['het_expected_ch2']/data['hetChrom_20perc_ch2']

# %%
min(data['het_ratio_ch2'])
# Out:
# 0.9999998857581314

# %%
max(data['het_ratio_ch2'])
# Out:
# 1.224305970920881

# %%
data.loc[data['het_ratio_ch2']>1.1,:]
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                   file  \
# 29          29            29              29  20191203_cell-30.tiff
# 31          31            31              31  20191203_cell-32.tiff
#
#    original cell name                       movie  \
# 29     20191125-01-10  191125pcnat_dhbr_cdc6vxy01
# 31    20191125-01-120  191125pcnat_dhbr_cdc6vxy01
#
#     last frame movie position x  last frame movie position y ab1 (MCM)  \
# 29                      275.057                      144.649      MCM3
# 31                     1821.011                     1855.967      MCM3
#
#     ab1 ch  ... nucleus_Otsu_erosion_inner_13x8_ch2  \
# 29       1  ...                          65964885.0
# 31       1  ...                         157803129.0
#
#     nucleus_Otsu_erosion_inner_13x8_ch3  \
# 29                            509694943
# 31                            993170419
#
#     nucleus_Otsu_erosion_outer_13x8_volume  \
# 29                                  167921
# ...

# %%
# %matplotlib notebook 
plt.hist(data['het_ratio_ch2'],10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([322.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   2.]),
#  array([0.99999989, 1.02243049, 1.0448611 , 1.06729171, 1.08972232,
#         1.11215293, 1.13458354, 1.15701415, 1.17944475, 1.20187536,
#         1.22430597]),
#  <a list of 10 Patch objects>)

# %%
# het ch3 (dapi)
data['het_expected_ch3']=data['HetChrom_erosion_inner_9x5_20_ch3']+data['HetChrom_erosion_outer_9x5_20_ch3']

# %%
data['het_ratio_ch3']=data['het_expected_ch3']/data['hetChrom_20perc_ch3']

# %%
data.loc[data['het_ratio_ch3']<.9, :]
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                   file  \
# 29          29            29              29  20191203_cell-30.tiff
# 31          31            31              31  20191203_cell-32.tiff
#
#    original cell name                       movie  \
# 29     20191125-01-10  191125pcnat_dhbr_cdc6vxy01
# 31    20191125-01-120  191125pcnat_dhbr_cdc6vxy01
#
#     last frame movie position x  last frame movie position y ab1 (MCM)  \
# 29                      275.057                      144.649      MCM3
# 31                     1821.011                     1855.967      MCM3
#
#     ab1 ch  ... nucleus_Otsu_erosion_inner_13x8_ch2  \
# 29       1  ...                          65964885.0
# 31       1  ...                         157803129.0
#
#     nucleus_Otsu_erosion_inner_13x8_ch3  \
# 29                            509694943
# 31                            993170419
#
#     nucleus_Otsu_erosion_outer_13x8_volume  \
# 29                                  167921
# ...

# %%
min(data['het_ratio_ch3'])
# Out:
# 0.7033714255536742

# %%
max(data['het_ratio_ch3'])
# Out:
# 1.0000001242731678

# %%
# %matplotlib notebook 
plt.hist(data['het_ratio_ch3'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  1.,   0.,   0.,   1.,   0.,   0.,   0.,   0.,   0., 322.]),
#  array([0.70337143, 0.7330343 , 0.76269717, 0.79236004, 0.82202291,
#         0.85168577, 0.88134864, 0.91101151, 0.94067438, 0.97033725,
#         1.00000012]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## org dataset

# %%
# het ch2 (mcm)
org['het_expected_ch2']=org['HetChrom_erosion_inner_9x5_20_ch2']+org['HetChrom_erosion_outer_9x5_20_ch2']

# %%
org['het_ratio_ch2']=org['het_expected_ch2']/org['hetChrom_20perc_ch2']

# %%
min(org['het_ratio_ch2'])
# Out:
# 0.9999998113059796

# %%
max(org['het_ratio_ch2'])
# Out:
# 1.0000001376957552

# %%
# %matplotlib notebook 
plt.hist(org['het_ratio_ch2'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  2.,   1.,   5.,  18.,  25., 194.,  21.,  22.,   6.,   6.]),
#  array([0.99999981, 0.99999984, 0.99999988, 0.99999991, 0.99999994,
#         0.99999997, 1.00000001, 1.00000004, 1.00000007, 1.00000011,
#         1.00000014]),
#  <a list of 10 Patch objects>)

# %%
# het ch3 (dapi)
org['het_expected_ch3']=org['HetChrom_erosion_inner_9x5_20_ch3']+org['HetChrom_erosion_outer_9x5_20_ch3']

# %%
org['het_ratio_ch3']=org['het_expected_ch3']/org['hetChrom_20perc_ch3']

# %%
min(org['het_ratio_ch3'])
# Out:
# 0.9999998731261687

# %%
max(org['het_ratio_ch3'])
# Out:
# 1.0000001338708635

# %%
# %matplotlib notebook 
plt.hist(org['het_ratio_ch3'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  2.,   9.,  17.,  21., 190.,  10.,  29.,  12.,   8.,   2.]),
#  array([0.99999987, 0.9999999 , 0.99999993, 0.99999995, 0.99999998,
#         1.        , 1.00000003, 1.00000006, 1.00000008, 1.00000011,
#         1.00000013]),
#  <a list of 10 Patch objects>)

# %%
from skimage.external import tifffile
from skimage.external.tifffile import imread

import matplotlib.pyplot as plt

import ipywidgets as widgets

import random


from scipy.ndimage.morphology import binary_erosion as br
from skimage import morphology as skmor

from scipy import ndimage
from PIL import Image, ImageDraw

# %%
data_unmatch=data.loc[data['het_ratio_ch2']<.9, :]

# %%
data.loc[data['het_ratio_ch3']<.9, :]
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                   file  \
# 29          29            29              29  20191203_cell-30.tiff
# 31          31            31              31  20191203_cell-32.tiff
#
#    original cell name                       movie  \
# 29     20191125-01-10  191125pcnat_dhbr_cdc6vxy01
# 31    20191125-01-120  191125pcnat_dhbr_cdc6vxy01
#
#     last frame movie position x  last frame movie position y ab1 (MCM)  \
# 29                      275.057                      144.649      MCM3
# 31                     1821.011                     1855.967      MCM3
#
#     ab1 ch  ... nucleus_Otsu_erosion_inner_13x8_ch2  \
# 29       1  ...                          65964885.0
# 31       1  ...                         157803129.0
#
#     nucleus_Otsu_erosion_inner_13x8_ch3  \
# 29                            509694943
# 31                            993170419
#
#     nucleus_Otsu_erosion_outer_13x8_volume  \
# 29                                  167921
# ...

# %%
for i, cell in data_unmatch.iterrows():
    path=cell.path
    nucpath=path.replace(".tif", "_nucleus.tif")
    nucpath=nucpath.replace("data_tiff", "segmentation_nucleus_Otsu")
    break

# %%
path
# Out:
# 'Z:\\CookLab\\Liu\\20190816_organizedData_MCM_loading\\new dataset\\20191203_cell\\data_tiff\\20191203_cell-30.cell1.tif'

# %%
myim=imread(path+'f')

# %%
mycha=myim[:,1,:,:]

# %%
# %matplotlib notebook
plt.imshow(mycha[20])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nucpath
# Out:
# 'Z:\\CookLab\\Liu\\20190816_organizedData_MCM_loading\\new dataset\\20191203_cell\\segmentation_nucleus_Otsu\\20191203_cell-30.cell1_nucleus.tif'

# %%
mynuc=imread(nucpath)

# %%
mynuc.shape
# Out:
# (56, 219, 219)

# %%
# %matplotlib notebook
plt.imshow(mynuc[20])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cell.hetChrom_20perc_ch2
# Out:
# 233585774.0

# %%
cell.HetChrom_erosion_inner_9x5_20_ch2
# Out:
# 28771888

# %%
cell.HetChrom_erosion_outer_9x5_20_ch2
# Out:
# 156591415

# %%
cell.HetChrom_erosion_inner_9x5_20_ch2+cell.HetChrom_erosion_outer_9x5_20_ch2
# Out:
# 185363303

# %%
data.loc[193,'HetChrom_erosion_inner_9x5_20_ch2']
# Out:
# 36985256

# %%
data.loc[193,'HetChrom_erosion_outer_9x5_20_ch2']
# Out:
# 85738288

# %%
data.loc[193,'hetChrom_20perc_ch1']
# Out:
# 122723536.0

# %%
36985256+85738288
# Out:
# 122723544

# %%
122723536
294925504
