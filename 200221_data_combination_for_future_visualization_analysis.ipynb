# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading'

# %% [markdown]
# ### found an error in file for second signal calculations for new dataset
# would have to merge the two - version 1 and version 2 to save in the file format we want

# %%
newfile_1=f'{bigDir}\\new dataset\signals_new_v1.csv'
newfile_2=f'{bigDir}\\new dataset\signals_new_v2.csv'

# %%
newdata1=pd.read_csv(newfile_1)

# %%
newdata1=newdata1.drop(columns=['Unnamed: 0'])

# %%
newdata1.head()
# Out:
#                    file original cell name                       movie  \
# 0  20191203_cell-00.czi     20191125-01-17  191125pcnat_dhbr_cdc6vxy01
# 1  20191203_cell-01.czi     20191125-01-20  191125pcnat_dhbr_cdc6vxy01
# 2  20191203_cell-02.czi     20191125-01-23  191125pcnat_dhbr_cdc6vxy01
# 3  20191203_cell-03.czi     20191125-01-25  191125pcnat_dhbr_cdc6vxy01
# 4  20191203_cell-04.czi     20191125-01-32  191125pcnat_dhbr_cdc6vxy01
#
#    last frame movie position x  last frame movie position y ab1 (MCM)  ab1 ch  \
# 0                      678.301                      200.931      MCM3       1
# 1                     1552.152                      240.479      MCM3       1
# 2                     1131.436                      318.530      MCM3       1
# 3                     1650.585                      324.968      MCM3       1
# 4                     1466.687                      426.815      MCM3       1
#
# ...

# %%
newdata2=pd.read_csv(newfile_2)

# %%
newdata2=newdata2.drop(columns=['Unnamed: 0', 'nuc_vol_total','inner_vol_total','outer_vol_total',
                                 'nuc_mcm_total','inner_mcm_total','outer_mcm_total',
                                'nuc_vol_het','inner_vol_het','outer_vol_het',
                                 'nuc_mcm_het','inner_mcm_het','outer_mcm_het',
                                 'nuc_vol_eu','inner_vol_eu','outer_vol_eu',
                                'nuc_mcm_eu','inner_mcm_eu', 'outer_mcm_eu'])

# %%
newdata2.head()
# Out:
#                    file original cell name                       movie  \
# 0  20191203_cell-00.czi     20191125-01-17  191125pcnat_dhbr_cdc6vxy01
# 1  20191203_cell-01.czi     20191125-01-20  191125pcnat_dhbr_cdc6vxy01
# 2  20191203_cell-02.czi     20191125-01-23  191125pcnat_dhbr_cdc6vxy01
# 3  20191203_cell-03.czi     20191125-01-25  191125pcnat_dhbr_cdc6vxy01
# 4  20191203_cell-04.czi     20191125-01-32  191125pcnat_dhbr_cdc6vxy01
#
#    last frame movie position x  last frame movie position y ab1 (MCM)  ab1 ch  \
# 0                      678.301                      200.931      MCM3       1
# 1                     1552.152                      240.479      MCM3       1
# 2                     1131.436                      318.530      MCM3       1
# 3                     1650.585                      324.968      MCM3       1
# 4                     1466.687                      426.815      MCM3       1
#
#   ab2 (heterochromatin)  ab2 ch  DAPI ch  ...  \
# ...

# %%
merge_new=pd.merge(newdata1,newdata2, on=['file','original cell name','movie','last frame movie position x',
                                      'last frame movie position y','ab1 (MCM)','ab1 ch','ab2 (heterochromatin)',
                                      'ab2 ch','DAPI ch','DIC ch','category','molecular age ','physical age [min]',
                                      'imaging core','cell id for tracking','comment','molecular age 10','path'])

# %%
merge_new.head()
# Out:
#                    file original cell name                       movie  \
# 0  20191203_cell-00.czi     20191125-01-17  191125pcnat_dhbr_cdc6vxy01
# 1  20191203_cell-01.czi     20191125-01-20  191125pcnat_dhbr_cdc6vxy01
# 2  20191203_cell-02.czi     20191125-01-23  191125pcnat_dhbr_cdc6vxy01
# 3  20191203_cell-03.czi     20191125-01-25  191125pcnat_dhbr_cdc6vxy01
# 4  20191203_cell-04.czi     20191125-01-32  191125pcnat_dhbr_cdc6vxy01
#
#    last frame movie position x  last frame movie position y ab1 (MCM)  ab1 ch  \
# 0                      678.301                      200.931      MCM3       1
# 1                     1552.152                      240.479      MCM3       1
# 2                     1131.436                      318.530      MCM3       1
# 3                     1650.585                      324.968      MCM3       1
# 4                     1466.687                      426.815      MCM3       1
#
# ...

# %%
merge_new.loc[0,]
# Out:
# file                                                        20191203_cell-00.czi
# original cell name                                                20191125-01-17
# movie                                                 191125pcnat_dhbr_cdc6vxy01
# last frame movie position x                                              678.301
# last frame movie position y                                              200.931
# ab1 (MCM)                                                                   MCM3
# ab1 ch                                                                         1
# ab2 (heterochromatin)                                                    HP1beta
# ab2 ch                                                                         2
# DAPI ch                                                                        3
# DIC ch                                                                         4
# category                                                                middleG1
# ...

# %%
len(merge_new)
# Out:
# 276

# %%
merge_new.to_csv(f'{bigDir}\\new dataset\signals_new_v3.csv')

# %% [markdown]
# ### found an error in file for second signal calculations for original dataset as well
# would have to merge the two - version 1 and version 2 to save in the file format we want

# %%
orgfile1=f'{bigDir}\\signals_org_v1.csv'
orgfile2=f'{bigDir}\\signals_org_v2.csv'

# %%
orgdata1=pd.read_csv(orgfile1)
orgdata2=pd.read_csv(orgfile2)

# %%
orgdata1=orgdata1.drop(columns=['nucleus_Otsu_inner_volume','nucleus_Otsu_inner_ch1','nucleus_Otsu_inner_ch2',
                                'nucleus_Otsu_inner_ch3','nucleus_Otsu_outer_volume','nucleus_Otsu_outer_ch1',
                                'nucleus_Otsu_outer_ch2','nucleus_Otsu_outer_ch3','HetChrom_erosion_inner_9x5_20_Volume',
                                'HetChrom_erosion_inner_9x5_20_ch1','HetChrom_erosion_inner_9x5_20_ch2',
                                'HetChrom_erosion_inner_9x5_20_ch3','HetChrom_erosion_outer_9x5_20_Volume',
                                'HetChrom_erosion_outer_9x5_20_ch1','HetChrom_erosion_outer_9x5_20_ch2',
                                'HetChrom_erosion_outer_9x5_20_ch3','HetChrom_erosion_inner_13x8_20_Volume',
                                'HetChrom_erosion_inner_13x8_20_ch1','HetChrom_erosion_inner_13x8_20_ch2',
                                'HetChrom_erosion_inner_13x8_20_ch3','HetChrom_erosion_outer_13x8_20_Volume',
                                'HetChrom_erosion_outer_13x8_20_ch1','HetChrom_erosion_outer_13x8_20_ch2',
                                'HetChrom_erosion_outer_13x8_20_ch3','nucleus_Otsu_erosion_inner_9x5_volume',
                                'nucleus_Otsu_erosion_inner_9x5_ch1','nucleus_Otsu_erosion_inner_9x5_ch2',
                                'nucleus_Otsu_erosion_inner_9x5_ch3','nucleus_Otsu_erosion_outer_9x5_volume',
                                'nucleus_Otsu_erosion_outer_9x5_ch1','nucleus_Otsu_erosion_outer_9x5_ch2',
                                'nucleus_Otsu_erosion_outer_9x5_ch3','nucleus_Otsu_erosion_inner_13x8_volume',
                                'nucleus_Otsu_erosion_inner_13x8_ch1','nucleus_Otsu_erosion_inner_13x8_ch2',
                                'nucleus_Otsu_erosion_inner_13x8_ch3','nucleus_Otsu_erosion_outer_13x8_volume',
                                'nucleus_Otsu_erosion_outer_13x8_ch1','nucleus_Otsu_erosion_outer_13x8_ch2',
                                'nucleus_Otsu_erosion_outer_13x8_ch3'])

# %%
orgdata1=orgdata1.drop(columns=['Unnamed: 0','Unnamed: 0.1'])

# %%
orgdata2=orgdata2.drop(columns=['Unnamed: 0',
                                'nucleus_Otsu_inner_volume','nucleus_Otsu_inner_ch1','nucleus_Otsu_inner_ch2',
                                'nucleus_Otsu_inner_ch3','nucleus_Otsu_outer_volume','nucleus_Otsu_outer_ch1',
                                'nucleus_Otsu_outer_ch2','nucleus_Otsu_outer_ch3','HetChrom_erosion_inner_9x5_20_Volume',
                                'HetChrom_erosion_inner_9x5_20_ch1','HetChrom_erosion_inner_9x5_20_ch2',
                                'HetChrom_erosion_inner_9x5_20_ch3','HetChrom_erosion_outer_9x5_20_Volume',
                                'HetChrom_erosion_outer_9x5_20_ch1','HetChrom_erosion_outer_9x5_20_ch2',
                                'HetChrom_erosion_outer_9x5_20_ch3','HetChrom_erosion_inner_13x8_20_Volume',
                                'HetChrom_erosion_inner_13x8_20_ch1','HetChrom_erosion_inner_13x8_20_ch2',
                                'HetChrom_erosion_inner_13x8_20_ch3','HetChrom_erosion_outer_13x8_20_Volume',
                                'HetChrom_erosion_outer_13x8_20_ch1','HetChrom_erosion_outer_13x8_20_ch2',
                                'HetChrom_erosion_outer_13x8_20_ch3','nucleus_Otsu_erosion_inner_9x5_volume',
                                'nucleus_Otsu_erosion_inner_9x5_ch1','nucleus_Otsu_erosion_inner_9x5_ch2',
                                'nucleus_Otsu_erosion_inner_9x5_ch3','nucleus_Otsu_erosion_outer_9x5_volume',
                                'nucleus_Otsu_erosion_outer_9x5_ch1','nucleus_Otsu_erosion_outer_9x5_ch2',
                                'nucleus_Otsu_erosion_outer_9x5_ch3','nucleus_Otsu_erosion_inner_13x8_volume',
                                'nucleus_Otsu_erosion_inner_13x8_ch1','nucleus_Otsu_erosion_inner_13x8_ch2',
                                'nucleus_Otsu_erosion_inner_13x8_ch3','nucleus_Otsu_erosion_outer_13x8_volume',
                                'nucleus_Otsu_erosion_outer_13x8_ch1','nucleus_Otsu_erosion_outer_13x8_ch2',
                                'nucleus_Otsu_erosion_outer_13x8_ch3','nuc_vol_total','inner_vol_total','outer_vol_total',
                                 'nuc_mcm_total','inner_mcm_total','outer_mcm_total',
                                'nuc_vol_het','inner_vol_het','outer_vol_het',
                                 'nuc_mcm_het','inner_mcm_het','outer_mcm_het',
                                 'nuc_vol_eu','inner_vol_eu','outer_vol_eu',
                                'nuc_mcm_eu','inner_mcm_eu', 'outer_mcm_eu'])

# %%
orgdata1.head()
# Out:
#                    file original cell name  Amy_mod  \
# 0  20190625_cell-00.czi            7LE1(B)  1130/10
# 1  20190625_cell-01.czi           7L-E1(T)        0
# 2  20190625_cell-02.czi           7L-E2(B)        0
# 3  20190625_cell-03.czi           7L-E2(T)        0
# 4  20190625_cell-05.czi              7L-G2        0
#
#                          movie    x    y ab1 (heterochromatin)  ab1 ch  \
# 0  190619-cdc6-dhb-pcna002xy09  172  956                  HP1B       1
# 1  190619-cdc6-dhb-pcna002xy09  158  906                  HP1B       1
# 2  190619-cdc6-dhb-pcna002xy09  832  252                  HP1B       1
# 3  190619-cdc6-dhb-pcna002xy09  888  160                  HP1B       1
# 4  190619-cdc6-dhb-pcna002xy09  172  324                  HP1B       1
#
#   ab2 (MCM)  ab2 ch  ...  outer_vol_het  nuc_mcm_het inner_mcm_het  \
# 0      MCM3       2  ...        35278.0  339523731.0   221011475.0
# 1      MCM3       2  ...        33491.0  319244926.0   210020333.0
# ...

# %%
orgdata2.head()
# Out:
#                    file original cell name  Amy_mod  \
# 0  20190625_cell-00.czi            7LE1(B)  1130/10
# 1  20190625_cell-01.czi           7L-E1(T)        0
# 2  20190625_cell-02.czi           7L-E2(B)        0
# 3  20190625_cell-03.czi           7L-E2(T)        0
# 4  20190625_cell-05.czi              7L-G2        0
#
#                          movie    x    y ab1 (heterochromatin)  ab1 ch  \
# 0  190619-cdc6-dhb-pcna002xy09  172  956                  HP1B       1
# 1  190619-cdc6-dhb-pcna002xy09  158  906                  HP1B       1
# 2  190619-cdc6-dhb-pcna002xy09  832  252                  HP1B       1
# 3  190619-cdc6-dhb-pcna002xy09  888  160                  HP1B       1
# 4  190619-cdc6-dhb-pcna002xy09  172  324                  HP1B       1
#
#   ab2 (MCM)  ab2 ch  ...  molecularAge_mismatch  nuc_DAPI_total  \
# 0      MCM3       2  ...                    0.0    1.035133e+10
# 1      MCM3       2  ...                    0.0    1.057222e+10
# ...

# %%
merge_org=pd.merge(orgdata1,orgdata2, on=['file','original cell name','Amy_mod','movie','x','y',
                                          'ab1 (heterochromatin)','ab1 ch','ab2 (MCM)','ab2 ch','DAPI ch','DIC ch',
                                          'category','physical age [min]','molecular age','imaging core',
                                          'cell id for tracking','comment','dhb_tracking','exp','decon','track_cell_id',
                                          'dist','x_track','y_track','track_length','path','paired','DHB_nucleus','DHB_cyto',
                                          'DHB_ratio','DHB_len','physical_age_cleaned','physicalAgeMatch','time_mismatch',
                                          'track_vs_measure','molecularAgeMatch','molecularAge_mismatch'])

# %%
merge_org.head()
# Out:
#                    file original cell name Amy_mod  \
# 0  20190625_cell-01.czi           7L-E1(T)       0
# 1  20190625_cell-02.czi           7L-E2(B)       0
# 2  20190625_cell-03.czi           7L-E2(T)       0
# 3  20190625_cell-05.czi              7L-G2       0
# 4  20190625_cell-06.czi              7L-G3       0
#
#                          movie    x    y ab1 (heterochromatin)  ab1 ch  \
# 0  190619-cdc6-dhb-pcna002xy09  158  906                  HP1B       1
# 1  190619-cdc6-dhb-pcna002xy09  832  252                  HP1B       1
# 2  190619-cdc6-dhb-pcna002xy09  888  160                  HP1B       1
# 3  190619-cdc6-dhb-pcna002xy09  172  324                  HP1B       1
# 4  190619-cdc6-dhb-pcna002xy09  492  506                  HP1B       1
#
#   ab2 (MCM)  ab2 ch  ...  outer_mcm_eu  nuc_DAPI_total inner_DAPI_total  \
# 0      MCM3       2  ...   724433139.0    1.057222e+10     3.409277e+09
# 1      MCM3       2  ...   828654095.0    1.115069e+10     3.719191e+09
# ...

# %%
merge_org.loc[0,]
# Out:
# file                                                  20190625_cell-01.czi
# original cell name                                                7L-E1(T)
# Amy_mod                                                                  0
# movie                                          190619-cdc6-dhb-pcna002xy09
# x                                                                      158
# y                                                                      906
# ab1 (heterochromatin)                                                 HP1B
# ab1 ch                                                                   1
# ab2 (MCM)                                                             MCM3
# ab2 ch                                                                   2
# DAPI ch                                                                  3
# DIC ch                                                                   4
# ...

# %%
merge_org.to_csv(f'{bigDir}\signals_org_v3.csv')

# %% [markdown]
# ## merging two datasets - new and original datasets
# will be merging on file, category, decon, path, molecular age, physical age

# %%
orgdata=pd.read_csv(f'{bigDir}\signals_org_v3.csv')

# %%
newdata=pd.read_csv(f'{bigDir}\\new dataset\signals_new_v3.csv')

# %%
orgdata.head()
# Out:
#    Unnamed: 0                  file original cell name  Amy_mod  \
# 0           0  20190625_cell-01.czi           7L-E1(T)        0
# 1           1  20190625_cell-02.czi           7L-E2(B)        0
# 2           2  20190625_cell-03.czi           7L-E2(T)        0
# 3           3  20190625_cell-05.czi              7L-G2        0
# 4           4  20190625_cell-06.czi              7L-G3        0
#
#                          movie    x    y ab1 (heterochromatin)  ab1 ch  \
# 0  190619-cdc6-dhb-pcna002xy09  158  906                  HP1B       1
# 1  190619-cdc6-dhb-pcna002xy09  832  252                  HP1B       1
# 2  190619-cdc6-dhb-pcna002xy09  888  160                  HP1B       1
# 3  190619-cdc6-dhb-pcna002xy09  172  324                  HP1B       1
# 4  190619-cdc6-dhb-pcna002xy09  492  506                  HP1B       1
#
#   ab2 (MCM)  ...  outer_mcm_eu  nuc_DAPI_total  inner_DAPI_total  \
# 0      MCM3  ...   724433139.0    1.057222e+10      3.409277e+09
# ...

# %%
newdata.head()
# Out:
#    Unnamed: 0                  file original cell name  \
# 0           0  20191203_cell-01.czi     20191125-01-20
# 1           1  20191203_cell-03.czi     20191125-01-25
# 2           2  20191203_cell-05.czi     20191125-01-36
# 3           3  20191203_cell-08.czi     20191125-01-41
# 4           4  20191203_cell-11.czi     20191125-01-54
#
#                         movie  last frame movie position x  \
# 0  191125pcnat_dhbr_cdc6vxy01                     1552.152
# 1  191125pcnat_dhbr_cdc6vxy01                     1650.585
# 2  191125pcnat_dhbr_cdc6vxy01                     1705.099
# 3  191125pcnat_dhbr_cdc6vxy01                      332.674
# 4  191125pcnat_dhbr_cdc6vxy01                      647.356
#
#    last frame movie position y ab1 (MCM)  ab1 ch ab2 (heterochromatin)  \
# 0                      240.479      MCM3       1               HP1beta
# 1                      324.968      MCM3       1               HP1beta
# ...

# %%
orgdata=orgdata.drop(columns=['Unnamed: 0'])

# %%
newdata=newdata.drop(columns=['Unnamed: 0'])

# %%
newdata.columns & orgdata.columns
# Out:
# Index(['file', 'original cell name', 'movie', 'ab1 ch', 'ab2 ch', 'DAPI ch',
#        'DIC ch', 'category', 'physical age [min]', 'imaging core',
#        'cell id for tracking', 'comment', 'path', 'nuc_vol_total',
#        'inner_vol_total', 'outer_vol_total', 'nuc_mcm_total',
#        'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het', 'inner_vol_het',
#        'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het', 'outer_mcm_het',
#        'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu', 'nuc_mcm_eu',
#        'inner_mcm_eu', 'outer_mcm_eu', 'nuc_DAPI_total', 'inner_DAPI_total',
#        'outer_DAPI_total', 'nuc_DAPI_het', 'inner_DAPI_het', 'outer_DAPI_het',
#        'nuc_DAPI_eu', 'inner_DAPI_eu', 'outer_DAPI_eu'],
#       dtype='object')

# %%
newdata.dtypes
# Out:
# file                            object
# original cell name              object
# movie                           object
# last frame movie position x    float64
# last frame movie position y    float64
# ab1 (MCM)                       object
# ab1 ch                           int64
# ab2 (heterochromatin)           object
# ab2 ch                           int64
# DAPI ch                          int64
# DIC ch                           int64
# category                        object
# molecular age                  float64
# physical age [min]             float64
# imaging core                    object
# cell id for tracking             int64
# comment                         object
# molecular age 10               float64
# path                            object
# nuc_vol_total                  float64
# inner_vol_total                float64
# outer_vol_total                float64
# nuc_mcm_total                  float64
# inner_mcm_total                float64
# ...

# %%
orgdata.dtypes
# Out:
# file                      object
# original cell name        object
# Amy_mod                    int64
# movie                     object
# x                          int64
# y                          int64
# ab1 (heterochromatin)     object
# ab1 ch                     int64
# ab2 (MCM)                 object
# ab2 ch                     int64
# DAPI ch                    int64
# DIC ch                   float64
# category                  object
# physical age [min]        object
# molecular age            float64
# imaging core              object
# cell id for tracking     float64
# comment                   object
# dhb_tracking               int64
# exp                        int64
# decon                       bool
# track_cell_id              int64
# dist                     float64
# x_track                  float64
# y_track                  float64
# track_length               int64
# path                      object
# paired                      bool
# ...

# %%
mergedData=pd.concat([orgdata, newdata],ignore_index=True,join='inner')

# %%
mergedData.head()
# Out:
#                    file original cell name                        movie  \
# 0  20190625_cell-01.czi           7L-E1(T)  190619-cdc6-dhb-pcna002xy09
# 1  20190625_cell-02.czi           7L-E2(B)  190619-cdc6-dhb-pcna002xy09
# 2  20190625_cell-03.czi           7L-E2(T)  190619-cdc6-dhb-pcna002xy09
# 3  20190625_cell-05.czi              7L-G2  190619-cdc6-dhb-pcna002xy09
# 4  20190625_cell-06.czi              7L-G3  190619-cdc6-dhb-pcna002xy09
#
#    ab1 ch  ab2 ch  DAPI ch  DIC ch category physical age [min] imaging core  \
# 0       1       2        3     4.0  earlyG1                 30          HIC
# 1       1       2        3     4.0  earlyG1                110          HIC
# 2       1       2        3     4.0  earlyG1                110          HIC
# 3       1       2        3     4.0       G2               1160          HIC
# 4       1       2        3     4.0       G2               1120          HIC
#
#    ...  outer_mcm_eu nuc_DAPI_total inner_DAPI_total  outer_DAPI_total  \
# ...

# %%
mergedData.loc[0,]
# Out:
# file                                                 20190625_cell-01.czi
# original cell name                                               7L-E1(T)
# movie                                         190619-cdc6-dhb-pcna002xy09
# ab1 ch                                                                  1
# ab2 ch                                                                  2
# DAPI ch                                                                 3
# DIC ch                                                                  4
# category                                                          earlyG1
# physical age [min]                                                     30
# imaging core                                                          HIC
# cell id for tracking                                                    1
# comment                                                               NaN
# path                    Z:\CookLab\Liu\20190816_organizedData_MCM_load...
# ...

# %%
mergedData.to_csv(f'{bigDir}\signals_combined_v1.csv')

# %% [markdown]
# # csv files combination for 2020 dataset

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200207_new data'

# %%
file1=f'{bigDir}\\cellinfo_200203_v7.csv'
file2=f'{bigDir}\\cellinfo_200203_v8.csv'

# %%
data1=pd.read_csv(file1)
data2=pd.read_csv(file2)

# %%
data1=data1.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])

# %%
data1.head()
# Out:
#                    file        original cell name               movie  \
# 0  20200203_cell_00.ciz  20200203-06-13-63X 16bit  20200203 simcmxy06
# 1  20200203_cell_01.ciz  20200203-06-25-63X 16bit  20200203 simcmxy06
# 2  20200203_cell_02.ciz  20200203-06-27-63X 16bit  20200203 simcmxy06
# 3  20200203_cell_03.ciz  20200203-06-29-63X 16bit  20200203 simcmxy06
# 4  20200203_cell_04.ciz  20200203-06-51-63X 16bit  20200203 simcmxy06
#
#    last frame movie position x  last frame movie position y ab1 (MCM)  ab1 ch  \
# 0                      647.518                      153.039      MCM3     1.0
# 1                     1490.165                      332.591      MCM3     1.0
# 2                     1560.535                      380.034      MCM3     1.0
# 3                      930.763                      391.252      MCM3     1.0
# 4                     1653.035                      635.701      MCM3     1.0
#
# ...

# %%
data1.columns
# Out:
# Index(['file', 'original cell name', 'movie', 'last frame movie position x',
#        'last frame movie position y', 'ab1 (MCM)', 'ab1 ch',
#        'ab2 (heterochromatin)', 'ab2 ch', 'DAPI ch', 'category',
#        'molecular age ', 'physical age [min]', 'imaging core',
#        'cell id for tracking', 'group', 'path', 'nuc_vol_total',
#        'inner_vol_total', 'outer_vol_total', 'nuc_mcm_total',
#        'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het', 'inner_vol_het',
#        'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het', 'outer_mcm_het',
#        'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu', 'nuc_mcm_eu',
#        'inner_mcm_eu', 'outer_mcm_eu', 'nuc_DAPI_total', 'inner_DAPI_total',
#        'outer_DAPI_total', 'nuc_DAPI_het', 'inner_DAPI_het', 'outer_DAPI_het',
#        'nuc_DAPI_eu', 'inner_DAPI_eu', 'outer_DAPI_eu', 'day', 'physical_age',
#        'mol_age_mod', 'nuc_hp1b_total', 'inner_hp1b_total', 'outer_hp1b_total',
# ...

# %%
data1=data1.drop(columns=['nuc_DAPI_total', 'inner_DAPI_total',
       'outer_DAPI_total', 'nuc_DAPI_het', 'inner_DAPI_het', 'outer_DAPI_het',
       'nuc_DAPI_eu', 'inner_DAPI_eu', 'outer_DAPI_eu', 'day', 'physical_age',
       'mol_age_mod', 'nuc_hp1b_total', 'inner_hp1b_total', 'outer_hp1b_total',
       'nuc_hp1b_het', 'inner_hp1b_het', 'outer_hp1b_het', 'nuc_hp1b_eu',
       'inner_hp1b_eu', 'outer_hp1b_eu'])

# %%
data2=data2.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 
                                'file', 'original cell name', 'movie', 'last frame movie position x', 
                                    'last frame movie position y','ab1 (MCM)','ab1 ch','ab2 (heterochromatin)','ab2 ch',
                                    'DAPI ch','category','molecular age ','physical age [min]','imaging core',
                                    'cell id for tracking', 'group','path','nuc_vol_total','inner_vol_total','outer_vol_total',
                          'nuc_mcm_total','inner_mcm_total','outer_mcm_total','nuc_vol_het','inner_vol_het','outer_vol_het',
                          'nuc_mcm_het','inner_mcm_het','outer_mcm_het','nuc_vol_eu','inner_vol_eu','outer_vol_eu',
                          'nuc_mcm_eu','inner_mcm_eu','outer_mcm_eu','day', 'physical_age', 'mol_age_mod'])

# %%
data2.head()
# Out:
#    nuc_DAPI_total  inner_DAPI_total  outer_DAPI_total  nuc_DAPI_het  \
# 0      2783625433        1001813888        1781811545     966421592
# 1      2621936947         853108995        1768827952     919275246
# 2      2682125477         837272617        1844852860     941681000
# 3      2980599423         954344207        2026255216     964038860
# 4      3115203586        1056373016        2058830570     985103584
#
#    inner_DAPI_het  outer_DAPI_het  nuc_DAPI_eu  inner_DAPI_eu  outer_DAPI_eu  \
# 0       689108376       277313216   1817203841      312705512     1504498329
# 1       501442995       417832251   1702661701      351666000     1350995701
# 2       570863539       370817461   1740444477      266409078     1474035399
# 3       578364196       385674664   2016560563      375980011     1640580552
# 4       608502030       376601554   2130100002      447870986     1682229016
#
#    nuc_hp1b_total  inner_hp1b_total  outer_hp1b_total  nuc_hp1b_het  \
# ...

# %%
len(data2.index)
# Out:
# 146

# %%
data1=data1.join(data2)

# %%
len(data1.index)
# Out:
# 146

# %%
data1.head()
# Out:
#                    file        original cell name               movie  \
# 0  20200203_cell_00.ciz  20200203-06-13-63X 16bit  20200203 simcmxy06
# 1  20200203_cell_01.ciz  20200203-06-25-63X 16bit  20200203 simcmxy06
# 2  20200203_cell_02.ciz  20200203-06-27-63X 16bit  20200203 simcmxy06
# 3  20200203_cell_03.ciz  20200203-06-29-63X 16bit  20200203 simcmxy06
# 4  20200203_cell_04.ciz  20200203-06-51-63X 16bit  20200203 simcmxy06
#
#    last frame movie position x  last frame movie position y ab1 (MCM)  ab1 ch  \
# 0                      647.518                      153.039      MCM3     1.0
# 1                     1490.165                      332.591      MCM3     1.0
# 2                     1560.535                      380.034      MCM3     1.0
# 3                      930.763                      391.252      MCM3     1.0
# 4                     1653.035                      635.701      MCM3     1.0
#
# ...

# %%
data1.loc[0,]
# Out:
# file                                                        20200203_cell_00.ciz
# original cell name                                      20200203-06-13-63X 16bit
# movie                                                         20200203 simcmxy06
# last frame movie position x                                              647.518
# last frame movie position y                                              153.039
# ab1 (MCM)                                                                   MCM3
# ab1 ch                                                                         1
# ab2 (heterochromatin)                                                    HP1beta
# ab2 ch                                                                         2
# DAPI ch                                                                        3
# category                                                                 earlyG1
# molecular age                                                              0.225
# ...

# %%
data1.to_csv(file2)

# %% [markdown]
# # file combination for geminin dataset

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200217_geminin'

file1=f'{bigDir}\\200217_cellinfo_v4.csv'
file2=f'{bigDir}\\200217_cellinfo_v5.csv'

data1=pd.read_csv(file1)
data2=pd.read_csv(file2)

# %%
data1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                  file     original cell name  \
# 0           0             0  20200217_cell_00.ciz  2020024-19-21-63X.czi
# 1           1             1  20200217_cell_01.ciz  2020024-19-27-63X.czi
# 2           2             2  20200217_cell_02.ciz  2020024-19-39-63X.czi
# 3           3             3  20200217_cell_03.ciz  2020024-19-49-63X.czi
# 4           4             4  20200217_cell_04.ciz  2020024-19-51-63X.czi
#
#                           movie         x        y ab1 (MCM)  ab1 ch  \
# 0  20200217pinducer gemininxy19  1312.741  235.893      MCM3       1
# 1  20200217pinducer gemininxy19  1323.444  397.761      MCM3       1
# 2  20200217pinducer gemininxy19  1772.297  584.995      MCM3       1
# 3  20200217pinducer gemininxy19   163.044  727.256      MCM3       1
# 4  20200217pinducer gemininxy19  1791.955  755.367      MCM3       1
#
#   ab2 (heterochromatin)  ...  outer_vol_het  nuc_mcm_het  inner_mcm_het  \
# ...

# %%
data2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                  file  \
# 0           0             0               0  20200217_cell_00.ciz
# 1           1             1               1  20200217_cell_01.ciz
# 2           2             2               2  20200217_cell_02.ciz
# 3           3             3               3  20200217_cell_03.ciz
# 4           4             4               4  20200217_cell_04.ciz
#
#       original cell name                         movie         x        y  \
# 0  2020024-19-21-63X.czi  20200217pinducer gemininxy19  1312.741  235.893
# 1  2020024-19-27-63X.czi  20200217pinducer gemininxy19  1323.444  397.761
# 2  2020024-19-39-63X.czi  20200217pinducer gemininxy19  1772.297  584.995
# 3  2020024-19-49-63X.czi  20200217pinducer gemininxy19   163.044  727.256
# 4  2020024-19-51-63X.czi  20200217pinducer gemininxy19  1791.955  755.367
#
#   ab1 (MCM)  ab1 ch  ... outer_mcm_eu  nuc_DAPI_total  inner_DAPI_total  \
# ...

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'file', 'original cell name', 'movie',
#        'x', 'y', 'ab1 (MCM)', 'ab1 ch', 'ab2 (heterochromatin)', 'ab2 ch',
#        'DAPI ch', 'DIC ch', 'category', 'physical_age [min]',
#        'molecular_age_dhb', 'molecular_age_cdc6', 'group', 'imaging core',
#        'decon', 'path', 'nuc_vol_total', 'inner_vol_total', 'outer_vol_total',
#        'nuc_mcm_total', 'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het',
#        'inner_vol_het', 'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het',
#        'outer_mcm_het', 'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu',
#        'nuc_mcm_eu', 'inner_mcm_eu', 'outer_mcm_eu'],
#       dtype='object')

# %%
data2=data2.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 
                           'file', 'original cell name', 'movie',
                           'x', 'y', 'ab1 (MCM)', 'ab1 ch', 'ab2 (heterochromatin)', 'ab2 ch',
                           'DAPI ch', 'DIC ch', 'category', 'physical_age [min]',
                           'molecular_age_dhb', 'molecular_age_cdc6', 'group', 'imaging core',
                           'decon', 'path','nuc_vol_total', 'inner_vol_total', 'outer_vol_total',
       'nuc_mcm_total', 'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het',
       'inner_vol_het', 'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het',
       'outer_mcm_het', 'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu',
       'nuc_mcm_eu', 'inner_mcm_eu', 'outer_mcm_eu'])

# %%
data2.head()
# Out:
#    nuc_DAPI_total  inner_DAPI_total  outer_DAPI_total  nuc_DAPI_het  \
# 0    1.993300e+09      5.675023e+08      1.425797e+09  7.791948e+08
# 1    2.052561e+09      6.452571e+08      1.407304e+09  7.501514e+08
# 2    3.897188e+09      1.408300e+09      2.488888e+09  1.402612e+09
# 3    2.232935e+09      8.375793e+08      1.395355e+09  8.721556e+08
# 4    1.963245e+09      5.406746e+08      1.422570e+09  7.409389e+08
#
#    inner_DAPI_het  outer_DAPI_het   nuc_DAPI_eu  inner_DAPI_eu  outer_DAPI_eu
# 0    4.701984e+08     308996412.0  1.214105e+09     97303963.0   1.116801e+09
# 1    4.772260e+08     272925417.0  1.302409e+09    168031096.0   1.134378e+09
# 2    1.055936e+09     346675531.0  2.494576e+09    352363680.0   2.142212e+09
# 3    6.594996e+08     212655978.0  1.360779e+09    178079736.0   1.182699e+09
# 4    4.345226e+08     306416352.0  1.222306e+09    106151998.0   1.116154e+09

# %%
data1.join(data2)
# Out:
#      Unnamed: 0  Unnamed: 0.1                   file      original cell name  \
# 0             0             0   20200217_cell_00.ciz   2020024-19-21-63X.czi
# 1             1             1   20200217_cell_01.ciz   2020024-19-27-63X.czi
# 2             2             2   20200217_cell_02.ciz   2020024-19-39-63X.czi
# 3             3             3   20200217_cell_03.ciz   2020024-19-49-63X.czi
# 4             4             4   20200217_cell_04.ciz   2020024-19-51-63X.czi
# 5             5             5   20200217_cell_05.ciz   2020024-19-54-63X.czi
# 6             6             6   20200217_cell_06.ciz   2020024-19-55-63X.czi
# 7             7             7   20200217_cell_07.ciz   2020024-19-69-63X.czi
# 8             8             8   20200217_cell_08.ciz   2020024-19-78-63X.czi
# 9             9             9   20200217_cell_09.ciz   2020024-19-79-63X.czi
# 10           10            10   20200217_cell_10.ciz   2020024-19-89-63X.czi
# ...

# %%
data1
# Out:
#      Unnamed: 0  Unnamed: 0.1                   file      original cell name  \
# 0             0             0   20200217_cell_00.ciz   2020024-19-21-63X.czi
# 1             1             1   20200217_cell_01.ciz   2020024-19-27-63X.czi
# 2             2             2   20200217_cell_02.ciz   2020024-19-39-63X.czi
# 3             3             3   20200217_cell_03.ciz   2020024-19-49-63X.czi
# 4             4             4   20200217_cell_04.ciz   2020024-19-51-63X.czi
# 5             5             5   20200217_cell_05.ciz   2020024-19-54-63X.czi
# 6             6             6   20200217_cell_06.ciz   2020024-19-55-63X.czi
# 7             7             7   20200217_cell_07.ciz   2020024-19-69-63X.czi
# 8             8             8   20200217_cell_08.ciz   2020024-19-78-63X.czi
# 9             9             9   20200217_cell_09.ciz   2020024-19-79-63X.czi
# 10           10            10   20200217_cell_10.ciz   2020024-19-89-63X.czi
# ...

# %%
data1=data1.join(data2)

# %%
data1.iloc[0]
# Out:
# Unnamed: 0                                                               0
# Unnamed: 0.1                                                             0
# file                                                  20200217_cell_00.ciz
# original cell name                                   2020024-19-21-63X.czi
# movie                                         20200217pinducer gemininxy19
# x                                                                  1312.74
# y                                                                  235.893
# ab1 (MCM)                                                             MCM3
# ab1 ch                                                                   1
# ab2 (heterochromatin)                                                  HP1
# ab2 ch                                                                   2
# DAPI ch                                                                  3
# ...

# %%
data1=data1.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])

# %%
data1.to_csv(file2.replace('v5','v6'))

# %%
file2
# Out:
# 'Z:\\CookLab\\Liu\\20190816_organizedData_MCM_loading\\20200217_geminin\\200217_cellinfo_v5.csv'

# %% [markdown]
# ## h3k9me3

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200604_h3k9me3'

file1=f'{bigDir}\\cellinfo_200604v4.csv'
file2=f'{bigDir}\\cellinfo_200604v5.csv'

data1=pd.read_csv(file1)
data2=pd.read_csv(file2)

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'file', 'original_name', 'movie',
#        'last frame movie position x', 'last frame movie position y',
#        'ab1 (Heterochromatin)', 'ab1 ch', 'ab2 (MCM)', 'ab2 ch', 'DAPI ch',
#        'category', 'molecular age ', 'physical age [min]', 'imaging core',
#        'cell_id_last frame', 'cell id for tracking', 'path', 'physical_age',
#        'physical_age_liu', 'mol_age_mod', 'mol_age_mod_liu', 'nuc_vol_total',
#        'inner_vol_total', 'outer_vol_total', 'nuc_mcm_total',
#        'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het', 'inner_vol_het',
#        'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het', 'outer_mcm_het',
#        'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu', 'nuc_mcm_eu',
#        'inner_mcm_eu', 'outer_mcm_eu'],
#       dtype='object')

# %%
data2=data2.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'file', 'original_name', 'movie',
       'last frame movie position x', 'last frame movie position y',
       'ab1 (Heterochromatin)', 'ab1 ch', 'ab2 (MCM)', 'ab2 ch', 'DAPI ch',
       'category', 'molecular age ', 'physical age [min]', 'imaging core',
       'cell_id_last frame', 'cell id for tracking', 'path', 'physical_age',
       'physical_age_liu', 'mol_age_mod', 'mol_age_mod_liu', 'nuc_vol_total',
       'inner_vol_total', 'outer_vol_total', 'nuc_mcm_total',
       'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het', 'inner_vol_het',
       'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het', 'outer_mcm_het',
       'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu', 'nuc_mcm_eu',
       'inner_mcm_eu', 'outer_mcm_eu'])

# %%
data2.head()
# Out:
#    Unnamed: 0.1.1  nuc_DAPI_total  inner_DAPI_total  outer_DAPI_total  \
# 0               0    2.697250e+09       822467048.0      1.874783e+09
# 1               1    2.321032e+09       899578615.0      1.421453e+09
# 2               2    2.570708e+09       959263344.0      1.611445e+09
# 3               3    2.176022e+09       779353206.0      1.396669e+09
# 4               4    2.687250e+09       828964429.0      1.858286e+09
#
#    nuc_DAPI_het  inner_DAPI_het  outer_DAPI_het   nuc_DAPI_eu  inner_DAPI_eu  \
# 0  1.126944e+09     688993863.0     437950504.0  1.570306e+09    133473185.0
# 1  9.240528e+08     588082696.0     335970054.0  1.396979e+09    311495919.0
# 2  1.034817e+09     647156625.0     387659985.0  1.535892e+09    312106719.0
# 3  8.454837e+08     555806131.0     289677561.0  1.330538e+09    223547075.0
# 4  1.025013e+09     598365413.0     426648006.0  1.662237e+09    230599016.0
#
#    outer_DAPI_eu
# 0   1.436832e+09
# 1   1.085483e+09
# 2   1.223785e+09
# ...

# %%
data2=data2.drop(columns=['Unnamed: 0.1.1'])

# %%
data3=data1.join(data2)

# %%
data3.iloc[0]
# Out:
# Unnamed: 0                                                                     0
# Unnamed: 0.1                                                                   0
# file                                                        20200604_cell_00.ciz
# original_name                                               200604_09_15_63X.czi
# movie                                                                 200604xy09
# last frame movie position x                                              325.986
# last frame movie position y                                              135.825
# ab1 (Heterochromatin)                                                    H3K9Me3
# ab1 ch                                                                         1
# ab2 (MCM)                                                                   MCM2
# ab2 ch                                                                         2
# DAPI ch                                                                        3
# ...

# %%
data3.to_csv(file2.replace('v5','v6'))

# %% [markdown]
# # h3k9me3 2nd dataset

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\20200615_h3k9me3'

file1=f'{bigDir}\\cellinfo_200615v3.csv'
file2=f'{bigDir}\\cellinfo_200615v4.csv'

data1=pd.read_csv(file1)
data2=pd.read_csv(file2)

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'file', 'original_name', 'movie',
#        'last frame movie position x', 'last frame movie position y',
#        'ab1 (MCM)', 'ab1 ch', 'ab2 (heterochromatin)', 'ab2 ch', 'DAPI ch',
#        'category', 'molecular age ', 'physical age [min]', 'imaging core',
#        'cell_id_last frame', 'path', 'mol_age_mod', 'physical_age',
#        'nuc_vol_total', 'inner_vol_total', 'outer_vol_total', 'nuc_mcm_total',
#        'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het', 'inner_vol_het',
#        'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het', 'outer_mcm_het',
#        'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu', 'nuc_mcm_eu',
#        'inner_mcm_eu', 'outer_mcm_eu'],
#       dtype='object')

# %%
data2=data2.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'file', 'original_name', 'movie',
       'last frame movie position x', 'last frame movie position y',
       'ab1 (MCM)', 'ab1 ch', 'ab2 (heterochromatin)', 'ab2 ch', 'DAPI ch',
       'category', 'molecular age ', 'physical age [min]', 'imaging core',
       'cell_id_last frame', 'path', 'mol_age_mod', 'physical_age',
       'nuc_vol_total', 'inner_vol_total', 'outer_vol_total', 'nuc_mcm_total',
       'inner_mcm_total', 'outer_mcm_total', 'nuc_vol_het', 'inner_vol_het',
       'outer_vol_het', 'nuc_mcm_het', 'inner_mcm_het', 'outer_mcm_het',
       'nuc_vol_eu', 'inner_vol_eu', 'outer_vol_eu', 'nuc_mcm_eu',
       'inner_mcm_eu', 'outer_mcm_eu'])

# %%
data2.head()
# Out:
#    Unnamed: 0.1.1  nuc_DAPI_total  inner_DAPI_total  outer_DAPI_total  \
# 0               0    2.906368e+09      8.883452e+08      2.018023e+09
# 1               1    2.902209e+09      8.534346e+08      2.048775e+09
# 2               2    2.678936e+09      8.294657e+08      1.849470e+09
# 3               3    3.867871e+09      1.053710e+09      2.814161e+09
# 4               4    3.541353e+09      1.288501e+09      2.252852e+09
#
#    nuc_DAPI_het  inner_DAPI_het  outer_DAPI_het   nuc_DAPI_eu  inner_DAPI_eu  \
# 0  1.050492e+09     394953135.0     655538618.0  1.855876e+09    493392059.0
# 1  1.041396e+09     508400349.0     532995207.0  1.860814e+09    345034251.0
# 2  9.278681e+08     394764405.0     533103706.0  1.751068e+09    434701298.0
# 3  1.260399e+09     455969764.0     804429554.0  2.607472e+09    597740006.0
# 4  1.300548e+09     823831991.0     476715783.0  2.240805e+09    464669286.0
#
#    outer_DAPI_eu
# 0   1.362484e+09
# 1   1.515780e+09
# 2   1.316367e+09
# ...

# %%
data2=data2.drop(columns=['Unnamed: 0.1.1'])

# %%
data3=data1.join(data2)

# %%
data3.iloc[0]
# Out:
# Unnamed: 0                                                                     0
# Unnamed: 0.1                                                                   0
# file                                                        20200615_cell_00.ciz
# original_name                                             20200615_29_11_63x.czi
# movie                                                                 200614xy29
# last frame movie position x                                              1781.99
# last frame movie position y                                               159.93
# ab1 (MCM)                                                                H3K9Me3
# ab1 ch                                                                         1
# ab2 (heterochromatin)                                                       MCM2
# ab2 ch                                                                         2
# DAPI ch                                                                        3
# ...

# %%
data3.to_csv(file2.replace('v4','v5'))
