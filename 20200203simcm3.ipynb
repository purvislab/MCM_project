# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats

# %%
bigDir=r'D:\POST_DOC\python_practice 1\mcm3ko'

# %%
file=f'{bigDir}\cellinfo_200203_v6.csv'

# %%
data=pd.read_csv(file)

# %% [markdown]
# ### data visualizations

# %%
data.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  Unnamed: 0.1                   file  \
# 0             0             0   20200203_cell_00.ciz
# 1             1             1   20200203_cell_01.ciz
# 2             2             2   20200203_cell_02.ciz
# 3             3             3   20200203_cell_03.ciz
# 4             4             4   20200203_cell_04.ciz
# ..          ...           ...                    ...
# 141         141           141  20200203_cell_141.ciz
# 142         142           142  20200203_cell_142.ciz
# 143         143           143  20200203_cell_143.ciz
# 144         144           144  20200203_cell_144.ciz
# 145         145           145  20200203_cell_145.ciz
#
#             original cell name               movie  \
# 0     20200203-06-13-63X 16bit  20200203 simcmxy06
# 1     20200203-06-25-63X 16bit  20200203 simcmxy06
# 2     20200203-06-27-63X 16bit  20200203 simcmxy06
# 3     20200203-06-29-63X 16bit  20200203 simcmxy06
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  Unnamed: 0.1                   file  \
# 0             0             0   20200203_cell_00.ciz
# 1             1             1   20200203_cell_01.ciz
# 2             2             2   20200203_cell_02.ciz
# 3             3             3   20200203_cell_03.ciz
# 4             4             4   20200203_cell_04.ciz
# ..          ...           ...                    ...
# 141         141           141  20200203_cell_141.ciz
# 142         142           142  20200203_cell_142.ciz
# 143         143           143  20200203_cell_143.ciz
# 144         144           144  20200203_cell_144.ciz
# 145         145           145  20200203_cell_145.ciz
#
#             original cell name               movie  \
# 0     20200203-06-13-63X 16bit  20200203 simcmxy06
# 1     20200203-06-25-63X 16bit  20200203 simcmxy06
# 2     20200203-06-27-63X 16bit  20200203 simcmxy06
# 3     20200203-06-29-63X 16bit  20200203 simcmxy06
# ...

# %%
data['category'].value_counts()
# Out:
# middleG1    51
# earlyG1     46
# lateG1      34
# G2           8
# early S      2
# ES           2
# special      1
# early G1     1
# es           1
# Name: category, dtype: int64

# %%
dataluc = data.loc[(data['group'] == 'siLuc'), :]

# %%
dataluc
# Out:
#     Unnamed: 0  Unnamed: 0.1                  file         original cell name  \
# 0            0             0  20200203_cell_00.ciz   20200203-06-13-63X 16bit
# 1            1             1  20200203_cell_01.ciz   20200203-06-25-63X 16bit
# 2            2             2  20200203_cell_02.ciz   20200203-06-27-63X 16bit
# 3            3             3  20200203_cell_03.ciz   20200203-06-29-63X 16bit
# 4            4             4  20200203_cell_04.ciz   20200203-06-51-63X 16bit
# ..         ...           ...                   ...                        ...
# 69          69            69  20200203_cell_69.ciz  20200203-09-91 -63X 16bit
# 70          70            70  20200203_cell_70.ciz  20200203-09-112-63X 16bit
# 71          71            71  20200203_cell_71.ciz  20200203-09-120-63X 16bit
# 72          72            72  20200203_cell_72.ciz  20200203-09-123-63X 16bit
# 73          73            73  20200203_cell_73.ciz  20200203-09-132-63X 16bit
#
# ...

# %%
datamcm = data.loc[(data['group'] == 'siMCM3'), :]

# %%
datamcm
# Out:
#      Unnamed: 0  Unnamed: 0.1                   file  \
# 74           74            74   20200203_cell_74.ciz
# 75           75            75   20200203_cell_75.ciz
# 76           76            76   20200203_cell_76.ciz
# 77           77            77   20200203_cell_77.ciz
# 78           78            78   20200203_cell_78.ciz
# ..          ...           ...                    ...
# 141         141           141  20200203_cell_141.ciz
# 142         142           142  20200203_cell_142.ciz
# 143         143           143  20200203_cell_143.ciz
# 144         144           144  20200203_cell_144.ciz
# 145         145           145  20200203_cell_145.ciz
#
#             original cell name               movie  \
# 74     20200203-12-6-63X 16bit  20200203 simcmxy12
# 75     20200203-12-7-63X 16bit  20200203 simcmxy12
# 76    20200203-12-16-63X 16bit  20200203 simcmxy12
# 77    20200203-12-17-63X 16bit  20200203 simcmxy12
# 78    20200203-12-33-63X 16bit  20200203 simcmxy12
# ...

# %%
# %matplotlib notebook
sn.violinplot(x='group',y='nuc_mcm_total',data=data)
# Out:
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %%
# normalizes the mcm signal to the volume 
# %matplotlib notebook
sn.violinplot(x='group',y=data.nuc_mcm_total/data.nuc_vol_total,data=data)
# Out:
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %% [markdown]
# ### Why the knowckdown is not very effective?

# %%
dataluc['category'].value_counts()
# Out:
# earlyG1      23
# middleG1     16
# lateG1       14
# middel G1    10
# G2            8
# early S       2
# es            1
# Name: category, dtype: int64

# %%
datamcm = data.loc[(data['group'] == 'siMCM3'), :]

# %%
datamcm['category'].value_counts()
# Out:
# middleG1    25
# earlyG1     23
# lateG1      20
# ES           2
# special      1
# earlr G1     1
# Name: category, dtype: int64

# %%
dataluc['category'].value_counts().plot(kind='pie')

# %%
datamcm['category'].value_counts().plot(kind='pie')

# %%
# normalizes the mcm signal to the volume & only G1 cells 
# %matplotlib notebook
sn.violinplot(x='group',y=data.nuc_mcm_total/data.nuc_vol_total,data=data.loc[['G1' in x for x in data.category],:],)
# Out:
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %% [markdown]
# ### 1. How total MCM change in siluc and siMCM3 group with molecular age

# %%
# %matplotlib notebook
dataluc['temp']=dataluc.nuc_mcm_total
datamcm['temp2']=datamcm.nuc_mcm_total

sn.regplot(x='mol_age_mod', y = 'temp', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'temp2', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' MCM ')
plt.title('total MCM')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %% [markdown]
# ### 2.How total MCM density(per DAPI) change in siluc and siMCM3 group with molecular age

# %%
# %matplotlib notebook
dataluc['temp']=dataluc.nuc_mcm_total/dataluc.nuc_DAPI_total
datamcm['temp2']=datamcm.nuc_mcm_total/datamcm.nuc_DAPI_total

sn.regplot(x='mol_age_mod', y = 'temp', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'temp2', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' MCM/DAPI ')
plt.title('MCM density/DAPI')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %% [markdown]
# ### 3.How MCM density(per DAPI) on heterochromatin change in siluc and siMCM3 group with molecular age

# %%
# %matplotlib notebook
dataluc['temp']=dataluc.nuc_mcm_het/dataluc.nuc_DAPI_het
datamcm['temp2']=datamcm.nuc_mcm_het/datamcm.nuc_DAPI_het

sn.regplot(x='mol_age_mod', y = 'temp', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'temp2', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' MCM/DAPI[heterochromatin] ')
plt.title('MCM density/DAPI on heterochromatin pixles')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %% [markdown]
# ### 4.How MCM density(per DAPI) on euchromatin change in siluc and siMCM3 group with molecular age

# %%
# %matplotlib notebook
dataluc['temp']=dataluc.nuc_mcm_eu/dataluc.nuc_DAPI_eu
datamcm['temp2']=datamcm.nuc_mcm_eu/datamcm.nuc_DAPI_eu

sn.regplot(x='mol_age_mod', y = 'temp', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'temp2', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' MCM/DAPI[euchromatin] ')
plt.title('MCM density/DAPI on euchromatin pixles')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %% [markdown]
# ### 5.How MCM lodaind proportion change in siluc and siMCM3 group with molecular age

# %%
# %matplotlib notebook
dataluc['temp']=dataluc.nuc_mcm_het/dataluc.nuc_mcm_total
datamcm['temp2']=datamcm.nuc_mcm_het/datamcm.nuc_mcm_total

sn.regplot(x='mol_age_mod', y = 'temp', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'temp2', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' proportion of MCM on heterchromatin ')
plt.title('MCM proportion on heterochromatin pixles')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %%
# %matplotlib notebook
dataluc['temp']=dataluc.nuc_mcm_eu/dataluc.nuc_mcm_total
datamcm['temp2']=datamcm.nuc_mcm_eu/datamcm.nuc_mcm_total

sn.regplot(x='mol_age_mod', y = 'temp', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'temp2', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' proportion of MCM on euchromatin ')
plt.title('MCM proportion on euchromatin pixles')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %%
# %matplotlib notebook
data=dataluc.loc[(['G1' in x for x in dataluc.category]),:]
data['temp']=data.nuc_mcm_het/data.nuc_mcm_total
data['temp1']=data.nuc_mcm_eu/data.nuc_mcm_total
barhet = data.loc[:,'temp']
bareu = data.loc[:,'temp1']
xaxis=dataluc['category']
width = 0.35       # the width of the bars: can also be len(x) sequence

plt.figure(figsize=(3,5))

plt.bar(x=data['category'], height=barhet, width=0.35)
plt.bar(x=data['category'], height=bareu, width=0.35,bottom=barhet)

plt.xlabel('category')
plt.ylabel('propotion')
plt.title('MCM prototion in heterochromatin pixes and in euchromatin pixes ')
plt.show()
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# <img src="data:image/png;base64,..." width="299.68255329204226">

# %%
# %matplotlib notebook
dataluc['tempa']=(dataluc.nuc_mcm_het/dataluc.nuc_DAPI_het)/(dataluc.nuc_mcm_total/dataluc.nuc_DAPI_total)
datamcm['tempb']=(datamcm.nuc_mcm_het/datamcm.nuc_DAPI_het)/(datamcm.nuc_mcm_total/datamcm.nuc_DAPI_total)

sn.regplot(x='mol_age_mod', y = 'tempa', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'tempb', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' MCM/DAPI[het/nuc] ')
plt.title('MCM loading rate on heterochromatin to nucleus')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %%
# %matplotlib notebook
data['temp2']=(dataluc.nuc_mcm_het/dataluc.nuc_DAPI_het)/(dataluc.nuc_mcm_total/dataluc.nuc_DAPI_total)

sn.regplot(x='mol_age_mod', y = 'temp2', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')


plt.xlabel('Molecular age [DHB]')
plt.ylabel('MCM/DAPI[het/nuc]')
plt.title('MCM loading rate on heterochromatin to nucleus')
plt.legend(loc="upper left")
# Out:
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %% [markdown]
# ### 6. How DAPI change with molecular age

# %%
# %matplotlib notebook
data['temp']=dataluc.nuc_DAPI_het
sn.scatterplot(x='mol_age_mod',y='temp', data=dataluc.loc[(['G1' in x for x in dataluc.category]),:],hue='category')
plt.xlabel('Molecular age [DHB]')
plt.ylabel('DAPI [het]')
plt.title(' DAPI on heterochromatin VS Molecular age')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, ' DAPI on heterochromatin VS Molecular age')

# %%
# %matplotlib notebook
data['temp']=dataluc.nuc_DAPI_total
sn.scatterplot(x='mol_age_mod',y='temp', data=dataluc.loc[(['G1' in x for x in dataluc.category]),:],hue='category')
plt.xlabel('Molecular age [DHB]')
plt.ylabel('DAPI [total]')
plt.title(' DAPI VS Molecular age')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, ' DAPI VS Molecular age')

# %%
# %matplotlib notebook
dataluc['temp']=dataluc.nuc_DAPI_eu
sn.scatterplot(x='mol_age_mod',y='temp', data=dataluc.loc[(['G1' in x for x in dataluc.category]),:],hue='category')
plt.xlabel('Molecular age [DHB]')
plt.ylabel('DAPI [euchromatin]')
plt.title(' DAPI VS Molecular age')
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.3651084006071">
# Text(0.5, 1.0, ' DAPI VS Molecular age')

# %% [markdown]
# ### 7. How total MCM density(per volume) change in siluc and siMCM3 group with molecular age

# %%
# %matplotlib notebook
dataluc['tempa']=dataluc.nuc_mcm_total/dataluc.nuc_vol_total
datamcm['tempb']=datamcm.nuc_mcm_total/datamcm.nuc_vol_total

sn.regplot(x='mol_age_mod', y = 'tempa', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'tempb', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' MCM/volume ')
plt.title('MCM density(per volume) in nucleus')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %%
# %matplotlib notebook
dataluc['tempa']=dataluc.nuc_mcm_het/dataluc.nuc_vol_het
datamcm['tempb']=datamcm.nuc_mcm_het/datamcm.nuc_vol_het

sn.regplot(x='mol_age_mod', y = 'tempa', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'tempb', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' MCM/volume[het] ')
plt.title('MCM density per volume on heterochromatin')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %%
# %matplotlib notebook
dataluc['tempa']=(dataluc.nuc_mcm_het/dataluc.nuc_vol_het)/(dataluc.nuc_mcm_total/dataluc.nuc_vol_total)
datamcm['tempb']=(datamcm.nuc_mcm_het/datamcm.nuc_vol_het)/(datamcm.nuc_mcm_total/datamcm.nuc_vol_total)

sn.regplot(x='mol_age_mod', y = 'tempa', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'tempb', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' MCM/vulume[het/nuc] ')
plt.title('MCM loading rate on heterochromatin to nucleus')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">

# %%
# %matplotlib notebook
dataluc['tempa']=(dataluc.nuc_mcm_het/dataluc.nuc_vol_het)/(dataluc.nuc_mcm_total/dataluc.nuc_vol_total)
datamcm['tempb']=(datamcm.nuc_mcm_het/datamcm.nuc_vol_het)/(datamcm.nuc_mcm_total/datamcm.nuc_vol_total)

sn.regplot(x='mol_age_mod', y = 'tempa', data=dataluc.loc[['G1' in x for x in dataluc.category],:], 
           label = 'siluc')

sn.regplot(x='mol_age_mod', y = 'tempb', data=datamcm.loc[['G1' in x for x in datamcm.category],:], color="r",
           label = 'siMCM3')

plt.xlabel('Molecular age [DHB]')
plt.ylabel(' MCM/vulume[het/nuc] ')
plt.title('MCM loading rate on heterochromatin to nucleus')
plt.legend(loc="upper left")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.3651084006071">
