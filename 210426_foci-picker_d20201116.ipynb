# %%
import numpy as np
import pandas as pd
import scipy
from scipy import stats
import matplotlib.pyplot as plt
from skimage.external import tifffile
import seaborn as sns
from skimage.external.tifffile import imread
import os
from os import listdir
from os.path import isfile, join

# %%
bigDir=r'Z:\CookLab\Liu\DNAdamageAnalysis\20201116'
imageFolder=f'{bigDir}\\data_tiff'
dataFile=f'{bigDir}\\cellinfo_20201116_v9.csv'
data=pd.read_csv(dataFile)

# %%
for i, row in data.iterrows():
    data.loc[i,'path']=data.loc[i,'path'].replace('D:\\POST_DOC\\python_practice\\cyclinE_53bp1','Z:\\CookLab\\Liu\\DNAdamageAnalysis')

# %%
for i, row in data.iterrows():
    newSegFolder = os.path.dirname(row.path).replace('data_tiff',f'masked_image')

    try:
        os.mkdir(newSegFolder)
    except:
        pass
    
    img=imread(row.path)
    ch=img[:,1,:,:]
    
    maskpath=row.path.replace('data_tiff','segmentation_nucleus_Otsu')
    maskpath=maskpath.replace('.tif','_nucleus.tif')
    nucMask=imread(maskpath)
    nucMask=nucMask.astype(bool)
    ch[~nucMask]=0
    
    maskFile = os.path.basename(row.path).replace('.tif',f'_masked.tif')
    tifffile.imsave(os.path.join(newSegFolder,maskFile), ch)
# Out:
# (38, 4, 380, 380)
# (38, 380, 380)

# %%
data.to_csv(dataFile.replace('v9','v10'))

# %%
data=pd.read_csv(dataFile.replace('v9','v10'))

# %% [markdown]
# ## setting #1
#
# Backgroud Type=balanced <br/>
# UniformBackground = 7500.0 <br/>
# Auto-Background radius= 6 <br/>
# MinISetting = 0.5(RelativetoMaximum) <br/>
# ToleranceSetting = 45.0 <br/>
# Minimum Volume (Pixel number) = 20 <br/>
# Calibration of image: pixels per um <br/>
# VoxelX= 1.0 VoxelY= 1.0 VoxelZ = 1.0 <br/>
# ContrastBanlance = 0.25 <br/>
# Exclude spontaneous foci? --No <br/>
# Foci Shape Validation: No <br/>
# computing threads: n=1 <br/>

# %%
for i,row in data.iterrows():
    resultPath=data.loc[i,'path'].replace('data_tiff','foci-results1')
    resultPath=resultPath.replace('20201116_cell_','Results-')
    resultPath=resultPath.replace('.tif','.csv')
    try:
        resultsDF=pd.read_csv(resultPath)
        data.loc[i,'fociNo']=len(resultsDF.index)
    except:
        data.loc[i,'fociNo']=0

# %%
data.to_csv(dataFile.replace('7','10-1'))

# %%
# %matplotlib notebook
ax=sns.boxplot(data=data,x='group',y='fociNo', palette="deep")
ax.set(xlabel="Groups", ylabel="Number of Foci")
ax.set_title("Number of Foci per Group")
#sns.swarmplot(data=data,x='group',y='fociNo', color='black')
# Out:
# <img src="data:image/png;base64,..." width="NaN">
# Text(0.5, 1.0, 'Number of Foci per Group')

# %% [markdown]
# ## setting #2
#
# Backgroud Type=balanced <br/>
# UniformBackground = 6500.0 <br/>
# Auto-Background radius= 6 <br/>
# MinISetting = 0.5(RelativetoMaximum) <br/>
# ToleranceSetting = 45.0 <br/>
# Minimum Volume (Pixel number) = 20 <br/>
# Calibration of image: pixels per um <br/>
# VoxelX= 1.0 VoxelY= 1.0 VoxelZ = 1.0 <br/>
# ContrastBanlance = 0.0 <br/>
# Exclude spontaneous foci? --No <br/>
# Foci Shape Validation: No <br/>
# computing threads: n=1 <br/>

# %%
for i,row in data.iterrows():
    resultPath=data.loc[i,'path'].replace('data_tiff','foci-results2')
    resultPath=resultPath.replace('20201116_cell_','Results-')
    resultPath=resultPath.replace('.tif','.csv')
    try:
        resultsDF=pd.read_csv(resultPath)
        data.loc[i,'fociNo']=len(resultsDF.index)
    except:
        data.loc[i,'fociNo']=0

# %%
data.to_csv(dataFile.replace('v9','v10-2'))

# %%
# %matplotlib notebook
ax=sns.boxplot(data=data,x='group',y='fociNo', palette="deep")
ax.set(xlabel="Groups", ylabel="Number of Foci")
ax.set_title("Number of Foci per Group")
#sns.swarmplot(data=data,x='group',y='fociNo', color='black')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Number of Foci per Group')

# %% [markdown]
# ## setting #3
#
# Backgroud Type=balanced <br/>
# UniformBackground = 6500.0 <br/>
# Auto-Background radius= 6 <br/>
# MinISetting = 0.5(RelativetoMaximum) <br/>
# ToleranceSetting = 45.0 <br/>
# Minimum Volume (Pixel number) = 20 <br/>
# Calibration of image: pixels per um <br/>
# VoxelX= 1.0 VoxelY= 1.0 VoxelZ = 1.0 <br/>
# ContrastBanlance = 0.25 <br/>
# Exclude spontaneous foci? --No <br/>
# Foci Shape Validation: No <br/>
# computing threads: n=1 <br/>

# %%
for i,row in data.iterrows():
    resultPath=data.loc[i,'path'].replace('data_tiff','foci-results3')
    resultPath=resultPath.replace('20201116_cell_','Results-')
    resultPath=resultPath.replace('.tif','.csv')
    try:
        resultsDF=pd.read_csv(resultPath)
        data.loc[i,'fociNo']=len(resultsDF.index)
    except:
        data.loc[i,'fociNo']=0

# %%
data.to_csv(dataFile.replace('7','10-3'))

# %%
# %matplotlib notebook
ax=sns.boxplot(data=data,x='group',y='fociNo', palette="deep")
ax.set(xlabel="Groups", ylabel="Number of Foci")
ax.set_title("Number of Foci per Group")
#sns.swarmplot(data=data,x='group',y='fociNo', color='black')
# Out:
# <img src="data:image/png;base64,..." width="NaN">
# Text(0.5, 1.0, 'Number of Foci per Group')

# %% [markdown]
# ## setting #4
#
# Backgroud Type=balanced <br/>
# UniformBackground = 5000.0 <br/>
# Auto-Background radius= 6 <br/>
# MinISetting = 0.5(RelativetoMaximum) <br/>
# ToleranceSetting = 45.0 <br/>
# Minimum Volume (Pixel number) = 20 <br/>
# Calibration of image: pixels per um <br/>
# VoxelX= 1.0 VoxelY= 1.0 VoxelZ = 1.0 <br/>
# ContrastBanlance = 0.25 <br/>
# Exclude spontaneous foci? --No <br/>
# Foci Shape Validation: No <br/>
# computing threads: n=1 <br/>

# %%
for i,row in data.iterrows():
    resultPath=data.loc[i,'path'].replace('data_tiff','foci-results4')
    resultPath=resultPath.replace('20201116_cell_','Results-')
    resultPath=resultPath.replace('.tif','.csv')
    try:
        resultsDF=pd.read_csv(resultPath)
        data.loc[i,'fociNo']=len(resultsDF.index)
    except:
        data.loc[i,'fociNo']=0

# %%
data.to_csv(dataFile.replace('7','10-4'))

# %%
# %matplotlib notebook
ax=sns.boxplot(data=data,x='group',y='fociNo', palette="deep")
ax.set(xlabel="Groups", ylabel="Number of Foci")
ax.set_title("Number of Foci per Group")
#sns.swarmplot(data=data,x='group',y='fociNo', color='black')
# Out:
# <img src="data:image/png;base64,..." width="NaN">
# Text(0.5, 1.0, 'Number of Foci per Group')

# %% [markdown]
# ## setting #5
#
# Backgroud Type=balanced <br/>
# UniformBackground = 5000.0 <br/>
# Auto-Background radius= 6 <br/>
# MinISetting = 0.5(RelativetoMaximum) <br/>
# ToleranceSetting = 45.0 <br/>
# Minimum Volume (Pixel number) = 20 <br/>
# Calibration of image: pixels per um <br/>
# VoxelX= 1.0 VoxelY= 1.0 VoxelZ = 1.0 <br/>
# ContrastBanlance = 0.00 <br/>
# Exclude spontaneous foci? --No <br/>
# Foci Shape Validation: No <br/>
# computing threads: n=1 <br/>

# %%
for i,row in data.iterrows():
    resultPath=data.loc[i,'path'].replace('data_tiff','foci-results5')
    resultPath=resultPath.replace('20201116_cell_','Results-')
    resultPath=resultPath.replace('.tif','.csv')
    try:
        resultsDF=pd.read_csv(resultPath)
        data.loc[i,'fociNo']=len(resultsDF.index)
    except:
        data.loc[i,'fociNo']=0

# %%
data.to_csv(dataFile.replace('7','10-5'))

# %%
# %matplotlib notebook
ax=sns.boxplot(data=data,x='group',y='fociNo', palette="deep")
ax.set(xlabel="Groups", ylabel="Number of Foci")
ax.set_title("Number of Foci per Group")
#sns.swarmplot(data=data,x='group',y='fociNo', color='black')
# Out:
# <img src="data:image/png;base64,..." width="NaN">
# Text(0.5, 1.0, 'Number of Foci per Group')

# %% [markdown]
# ## setting #6
#
# Backgroud Type=balanced <br/>
# UniformBackground = 5000.0 <br/>
# Auto-Background radius= 6 <br/>
# MinISetting = 0.5(RelativetoMaximum) <br/>
# ToleranceSetting = 45.0 <br/>
# Minimum Volume (Pixel number) = 20 <br/>
# Calibration of image: pixels per um <br/>
# VoxelX= 1.0 VoxelY= 1.0 VoxelZ = 1.0 <br/>
# ContrastBanlance = 0.50 <br/>
# Exclude spontaneous foci? --No <br/>
# Foci Shape Validation: No <br/>
# computing threads: n=1 <br/>

# %%
for i,row in data.iterrows():
    resultPath=data.loc[i,'path'].replace('data_tiff','foci-results6')
    resultPath=resultPath.replace('20201116_cell_','Results-')
    resultPath=resultPath.replace('.tif','.csv')
    try:
        resultsDF=pd.read_csv(resultPath)
        data.loc[i,'fociNo']=len(resultsDF.index)
    except:
        data.loc[i,'fociNo']=0

# %%
data.to_csv(dataFile.replace('7','10-6'))

# %%
# %matplotlib notebook
ax=sns.boxplot(data=data,x='group',y='fociNo', palette="deep")
ax.set(xlabel="Groups", ylabel="Number of Foci")
ax.set_title("Number of Foci per Group")
#sns.swarmplot(data=data,x='group',y='fociNo', color='black')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Number of Foci per Group')
