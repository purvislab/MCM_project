# %%
import pandas as pd
from skimage.external import tifffile
import os
os.sys.path
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
import numpy as np
from skimage.external.tifffile import imread

# %%
bigDir=r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\new dataset'

# %%
myFile=f'{bigDir}\\cellinfo_191125_final.csv'

# %%
data=pd.read_csv(myFile)

# %%
data.head()
# Out:
#    Unnamed: 0                  file original cell name  \
# 0           1  20191203_cell-00.czi     20191125-01-17
# 1           2  20191203_cell-01.czi     20191125-01-20
# 2           3  20191203_cell-02.czi     20191125-01-23
# 3           4  20191203_cell-03.czi     20191125-01-25
# 4           5  20191203_cell-04.czi     20191125-01-32
#
#                         movie  last frame movie position x  \
# 0  191125pcnat_dhbr_cdc6vxy01                      678.301
# 1  191125pcnat_dhbr_cdc6vxy01                     1552.152
# 2  191125pcnat_dhbr_cdc6vxy01                     1131.436
# 3  191125pcnat_dhbr_cdc6vxy01                     1650.585
# 4  191125pcnat_dhbr_cdc6vxy01                     1466.687
#
#    last frame movie position y ab1 (MCM)  ab1 ch ab2 (heterochromatin)  \
# 0                      200.931      MCM3       1               HP1beta
# 1                      240.479      MCM3       1               HP1beta
# 2                      318.530      MCM3       1               HP1beta
# 3                      324.968      MCM3       1               HP1beta
# 4                      426.815      MCM3       1               HP1beta
#
#    ab2 ch  DAPI ch  DIC ch   category  molecular age   physical age [min]  \
# 0       2        3       4  middle G1           0.444               340.0
# 1       2        3       4         G2           1.373                 NaN
# 2       2        3       4         G2           1.371               910.0
# 3       2        3       4   early G1           0.704                30.0
# 4       2        3       4  middle G1           0.345               250.0
#
#   imaging core  cell id for tracking          comment  molecular age 10  \
# 0          HIC                    17              NaN             0.311
# 1          HIC                    20  110 min after s             2.036
# 2          HIC                    23   30 min after S             1.960
# 3          HIC                    25              NaN             0.632
# 4          HIC                    32              NaN             0.225
#
#                                                 path
# 0  Z:\CookLab\Liu\20190816_organizedData_MCM_load...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
data.loc[0,'path']
# Out:
# 'Z:\\CookLab\\Liu\\20190816_organizedData_MCM_loading\\new dataset\\20191203_cell\\data_tiff\\20191203_cell-00.tif'

# %%
for i, cell in data.iterrows():
    
    fileDir=cell.file.split("-")[0]
    fileName=cell.file.split(".")[0]
    
    data.at[i,'path']=f'{bigDir}\\{fileDir}\\data_tiff\\{fileName}.tif'

# %%
data.to_csv(f'{bigDir}\\cellinfo_191125_final.csv')
