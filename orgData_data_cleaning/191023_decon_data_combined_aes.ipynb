# %%
import pandas as pd
import numpy as np

# %%
deconFile = r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\decon_data_perChannel_v1.csv'

# %%
decondf = pd.read_csv(deconFile)

# %%
selcellFile = r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\sel_cells_v1.csv'

# %%
selcelldf = pd.read_csv(selcellFile)

# %%
mergedDF = selcelldf.merge(decondf, on = ['File'], how = 'left')

# %%
del mergedDF['Unnamed: 0_x']

# %%
del mergedDF['Unnamed: 0_y']

# %%
mergedDF
# Out:
#                             File original cell name  Amy_mod  \
# 0           20190625_cell-00.czi            7LE1(B)  1130/10
# 1           20190625_cell-01.czi           7L-E1(T)        0
# 2           20190625_cell-02.czi           7L-E2(B)        0
# 3           20190625_cell-03.czi           7L-E2(T)        0
# 4           20190625_cell-05.czi              7L-G2        0
# 5           20190625_cell-06.czi              7L-G3        0
# 6           20190625_cell-07.czi              7L-L1        0
# 7           20190625_cell-08.czi              7L-L2        0
# 8           20190625_cell-09.czi              7L-L3        0
# 9           20190625_cell-10.czi              7L-L4        0
# 10          20190625_cell-11.czi              7L-L5        0
# 11          20190625_cell-12.czi              7L-M1        0
# 12          20190625_cell-13.czi              7L-M2        0
# 13          20190625_cell-14.czi              7L-M3        0
# ...

# %%
mergedDF.to_csv(r'Z:\CookLab\Liu\20190816_organizedData_MCM_loading\decon_data_combined_v2.csv')
